# %% [markdown]
# # 🏛️ Harvard’s Artifacts Collection: ETL, SQL Analytics & Streamlit Showcase

# %% [markdown]
# ## Domain : Cultural Heritage Data Analytics / Museum Informatics

# %% [markdown]
# ## API Integration & Data Extraction

# %%
harvard_api='042c9b34-c6c5-4f1f-8bce-55ce15462072'
url='https://api.harvardartmuseums.org/classification'
import requests
parameters={'apikey':harvard_api,
           'size':100}
response= requests.get(url, parameters)
response
# Out:
# <Response [200]>

# %%
data=response.json()
data
# Out:
# {'info': {'totalrecordsperquery': 100,
#   'totalrecords': 64,
#   'pages': 1,
#   'page': 1,
#   'responsetime': '4 ms'},
#  'records': [{'objectcount': 1,
#    'name': 'Natural History Specimens',
#    'id': 1133,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 1133},
#   {'objectcount': 1,
#    'name': 'Paintings with Text',
#    'id': 197,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 197},
#   {'objectcount': 66,
#    'name': 'Performance Artifacts',
#    'id': 224,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 224},
#   {'objectcount': 1,
#    'name': 'Text',
#    'id': 204,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 204},
#   {'objectcount': 80,
#    'name': 'Tokens',
#    'id': 492,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 492},
#   {'objectcount': 62,
#    'name': 'Brick Stamps',
#    'id': 304,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 304},
#   {'objectcount': 46,
#    'name': 'Cameos',
#    'id': 1086,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 1086},
#   {'objectcount': 1,
#    'name': 'Casts',
#    'id': 1139,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 1139},
#   {'objectcount': 6,
#    'name': 'Containers',
#    'id': 1203,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 1203},
#   {'objectcount': 11,
#    'name': 'Frames',
#    'id': 1188,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 1188},
#   {'objectcount': 248,
#    'name': 'Gems',
#    'id': 1078,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 1078},
#   {'objectcount': 16,
#    'name': 'Graphic Design',
#    'id': 171,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 171},
#   {'objectcount': 69,
#    'name': 'Inscriptions',
#    'id': 344,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 344},
#   {'objectcount': 344,
#    'name': 'Material Specimens',
#    'id': 1075,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 1075},
#   {'objectcount': 470,
#    'name': 'Rubbings',
#    'id': 173,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 173},
#   {'objectcount': 351,
#    'name': '(not assigned)',
#    'id': 0,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 0},
#   {'objectcount': 2852,
#    'name': 'Accessories (non-art)',
#    'id': 2,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 2},
#   {'objectcount': 85764,
#    'name': 'Photographs',
#    'id': 17,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 17},
#   {'objectcount': 944,
#    'name': 'Jewelry',
#    'id': 19,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 19},
#   {'objectcount': 33972,
#    'name': 'Drawings',
#    'id': 21,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 21},
#   {'objectcount': 72330,
#    'name': 'Prints',
#    'id': 23,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 23},
#   {'objectcount': 6904,
#    'name': 'Paintings',
#    'id': 26,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 26},
#   {'objectcount': 6641,
#    'name': 'Sculpture',
#    'id': 30,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 30},
#   {'objectcount': 1416,
#    'name': 'Tools and Equipment',
#    'id': 32,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 32},
#   {'objectcount': 1288,
#    'name': 'Multiples',
#    'id': 43,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 43},
#   {'objectcount': 664,
#    'name': 'Lighting Devices',
#    'id': 45,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 45},
#   {'objectcount': 620,
#    'name': 'Books',
#    'id': 47,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 47},
#   {'objectcount': 20272,
#    'name': 'Coins',
#    'id': 50,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 50},
#   {'objectcount': 6223,
#    'name': 'Vessels',
#    'id': 57,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 57},
#   {'objectcount': 404,
#    'name': 'Plaques',
#    'id': 60,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 60},
#   {'objectcount': 3445,
#    'name': 'Textile Arts',
#    'id': 62,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 62},
#   {'objectcount': 15739,
#    'name': 'Archival Material',
#    'id': 64,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 64},
#   {'objectcount': 432,
#    'name': 'Audiovisual Works',
#    'id': 71,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 71},
#   {'objectcount': 616,
#    'name': 'Calligraphy',
#    'id': 75,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 75},
#   {'objectcount': 580,
#    'name': 'Furniture',
#    'id': 76,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 76},
#   {'objectcount': 155,
#    'name': 'Paintings with Calligraphy',
#    'id': 80,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 80},
#   {'objectcount': 88,
#    'name': 'Unidentified',
#    'id': 82,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 82},
#   {'objectcount': 335,
#    'name': 'Boxes',
#    'id': 85,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 85},
#   {'objectcount': 5218,
#    'name': 'Fragments',
#    'id': 94,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 94},
#   {'objectcount': 1536,
#    'name': "Artists' Tools",
#    'id': 97,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 97},
#   {'objectcount': 845,
#    'name': 'Medals and Medallions',
#    'id': 105,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 105},
#   {'objectcount': 57,
#    'name': 'Furnishings',
#    'id': 114,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 114},
#   {'objectcount': 1176,
#    'name': 'Architectural Elements',
#    'id': 133,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 133},
#   {'objectcount': 646,
#    'name': 'Timepieces',
#    'id': 139,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 139},
#   {'objectcount': 970,
#    'name': 'Ritual Implements',
#    'id': 146,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 146},
#   {'objectcount': 191,
#    'name': 'Mosaics',
#    'id': 149,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 149},
#   {'objectcount': 363,
#    'name': 'Weapons and Ammunition',
#    'id': 155,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 155},
#   {'objectcount': 48,
#    'name': 'Portfolios',
#    'id': 162,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 162},
#   {'objectcount': 134,
#    'name': 'Amulets',
#    'id': 180,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 180},
#   {'objectcount': 5001,
#    'name': 'Manuscripts',
#    'id': 185,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 185},
#   {'objectcount': 5899,
#    'name': 'Seals',
#    'id': 189,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 189},
#   {'objectcount': 63,
#    'name': 'Armor',
#    'id': 242,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 242},
#   {'objectcount': 181,
#    'name': 'Recreational Artifacts',
#    'id': 251,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 251},
#   {'objectcount': 171,
#    'name': 'Mirrors',
#    'id': 302,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 302},
#   {'objectcount': 70,
#    'name': 'Riding Equipment',
#    'id': 330,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 330},
#   {'objectcount': 32,
#    'name': 'Musical Instruments',
#    'id': 359,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 359},
#   {'objectcount': 77,
#    'name': 'Measuring Devices',
#    'id': 364,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 364},
#   {'objectcount': 49,
#    'name': 'Tablets',
#    'id': 381,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 381},
#   {'objectcount': 539,
#    'name': 'Albums',
#    'id': 384,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 384},
#   {'objectcount': 5128,
#    'name': 'Straus Materials',
#    'id': 959,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 959},
#   {'objectcount': 534,
#    'name': "Artists' Materials",
#    'id': 1012,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 1012},
#   {'objectcount': 64,
#    'name': 'Stained Glass',
#    'id': 1088,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 1088},
#   {'objectcount': 11,
#    'name': 'Models',
#    'id': 1137,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 1137},
#   {'objectcount': 3,
#    'name': 'Documents',
#    'id': 1185,
#    'lastupdate': '2025-10-02T04:03:39-04:00',
#    'classificationid': 1185}]}

# %%
classiresults= [record['name']
                for record in data['records']
                if record.get('objectcount',0) >= 2500]
print('name with object count >= 2500:')
for name in classiresults:
    print(name)
# Out:
# name with object count >= 2500:
# Accessories (non-art)
# Photographs
# Drawings
# Prints
# Paintings
# Sculpture
# Coins
# Vessels
# Textile Arts
# Archival Material
# Fragments
# Manuscripts
# Seals
# Straus Materials

# %%
classiresults
# Out:
# ['Accessories (non-art)',
#  'Photographs',
#  'Drawings',
#  'Prints',
#  'Paintings',
#  'Sculpture',
#  'Coins',
#  'Vessels',
#  'Textile Arts',
#  'Archival Material',
#  'Fragments',
#  'Manuscripts',
#  'Seals',
#  'Straus Materials']

# %%
url = 'https://api.harvardartmuseums.org/object'

all_records = []   

classifications = ["Paintings", "Sculpture", "Drawings", "Fragments", "Photographs"]

for classi in classifications:
    print(f"\nFetching classification: {classi}")
    for page in range(1, 26):   # 25 pages × 100 = 2500
        parameters = {
            'apikey': harvard_api,
            'size': 100,
            'page': page,
            'classification': classi
        }
        response = requests.get(url, parameters)
        data = response.json()
        all_records.extend(data['records'])
    print(f"Total collected so far: {len(all_records)}")
# Out:
# Fetching classification: Paintings
# Total collected so far: 2500
#
# Fetching classification: Sculpture
# Total collected so far: 5000
#
# Fetching classification: Drawings
# Total collected so far: 7500
#
# Fetching classification: Fragments
# Total collected so far: 10000
#
# Fetching classification: Photographs
# Total collected so far: 12500

# %%
data['records']
# Out:
# [{'copyright': None,
#   'contextualtextcount': 0,
#   'creditline': 'Harvard Art Museums/Fogg Museum, Purchase through the generosity of Melvin R. Seiden',
#   'accesslevel': 1,
#   'createdate': '1997-07-19T00:00:00-04:00',
#   'dateoflastpageview': '2025-07-30',
#   'classificationid': 17,
#   'division': 'European and American Art',
#   'markscount': 0,
#   'publicationcount': 0,
#   'totaluniquepageviews': 6,
#   'contact': 'am_europeanamerican@harvard.edu',
#   'colorcount': 6,
#   'rank': 254783,
#   'id': 283979,
#   'state': None,
#   'verificationleveldescription': 'Good. Object is well described and information is vetted',
#   'period': None,
#   'images': [{'date': '2004-12-14',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 86607,
#     'idsid': 17916268,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': None,
#     'renditionnumber': '76784',
#     'displayorder': 1,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:76784_dynmc',
#     'alttext': None,
#     'width': 1024,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/17916268',
#     'height': 748}],
#   'worktypes': [{'worktypeid': '268', 'worktype': 'photograph'}],
#   'imagecount': 1,
#   'totalpageviews': 8,
#   'accessionyear': None,
#   'standardreferencenumber': None,
#   'signed': None,
#   'classification': 'Photographs',
#   'relatedcount': 1,
#   'verificationlevel': 3,
#   'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:76784_dynmc',
#   'titlescount': 2,
#   'peoplecount': 1,
#   'style': None,
#   'lastupdate': '2025-10-01T04:29:15-04:00',
#   'commentary': None,
#   'periodid': None,
#   'technique': 'Albumen silver print',
#   'edition': None,
#   'description': None,
#   'medium': 'Hand-colored albumen silver print on card',
#   'lendingpermissionlevel': 0,
#   'title': 'Untitled (Japanese port)',
#   'accessionmethod': 'Purchase',
#   'colors': [{'color': '#c8af96',
#     'spectrum': '#e66c64',
#     'hue': 'Brown',
#     'percent': 0.35345565749235475,
#     'css3': '#d2b48c'},
#    {'color': '#967d64',
#     'spectrum': '#b65590',
#     'hue': 'Brown',
#     'percent': 0.22403669724770642,
#     'css3': '#808080'},
#    {'color': '#af967d',
#     'spectrum': '#c25687',
#     'hue': 'Brown',
#     'percent': 0.20807339449541284,
#     'css3': '#bc8f8f'},
#    {'color': '#7d644b',
#     'spectrum': '#b25593',
#     'hue': 'Yellow',
#     'percent': 0.12691131498470948,
#     'css3': '#696969'},
#    {'color': '#e1e1c8',
#     'spectrum': '#e9715f',
#     'hue': 'Green',
#     'percent': 0.06397553516819572,
#     'css3': '#dcdcdc'},
#    {'color': '#644b32',
#     'spectrum': '#59ba4a',
#     'hue': 'Brown',
#     'percent': 0.023547400611620795,
#     'css3': '#556b2f'}],
#   'provenance': 'Sotheby Parke Bernet & Co., New York, New York, sold to Seiden & de Cuevas Inc., 1980.\r\nSeiden & de Cuevas, Inc., New York, New York, purchased from Sotheby Parke Bernet, New York, N, 1980, Gift to the Fogg Art Museum, 1982. on Long Term Loan to the Fogg Art Museum from 1980 to 1982\r\n',
#   'groupcount': 0,
#   'dated': 'c. 1880-c. 1889',
#   'department': 'Department of Photographs',
#   'dateend': 1889,
#   'people': [{'role': 'Artist',
#     'birthplace': None,
#     'gender': 'unknown',
#     'displaydate': None,
#     'prefix': None,
#     'culture': None,
#     'displayname': 'Unidentified Artist',
#     'alphasort': 'Unidentified Artist',
#     'name': 'Unidentified Artist',
#     'personid': 34147,
#     'deathplace': None,
#     'displayorder': 1}],
#   'url': 'https://www.harvardartmuseums.org/collections/object/283979',
#   'dateoffirstpageview': '2009-07-20',
#   'century': '19th century',
#   'objectnumber': 'P1982.377.50',
#   'labeltext': None,
#   'datebegin': 1880,
#   'culture': 'Japanese',
#   'exhibitioncount': 0,
#   'imagepermissionlevel': 0,
#   'mediacount': 0,
#   'objectid': 283979,
#   'techniqueid': 110,
#   'dimensions': '9 x 13.8 cm (3 9/16 x 5 7/16 in.)',
#   'seeAlso': [{'id': 'https://iiif.harvardartmuseums.org/manifests/object/283979',
#     'type': 'IIIF Manifest',
#     'format': 'application/json',
#     'profile': 'http://iiif.io/api/presentation/2/context.json'}]},
#  {'copyright': None,
#   'contextualtextcount': 0,
#   'creditline': 'Harvard Art Museums/Fogg Museum, Purchase through the generosity of Melvin R. Seiden',
#   'accesslevel': 1,
#   'createdate': '1997-07-19T00:00:00-04:00',
#   'dateoflastpageview': '2025-06-16',
#   'classificationid': 17,
#   'division': 'Modern and Contemporary Art',
#   'markscount': 1,
#   'publicationcount': 0,
#   'totaluniquepageviews': 14,
#   'contact': 'am_moderncontemporary@harvard.edu',
#   'colorcount': 9,
#   'rank': 254255,
#   'id': 283980,
#   'state': None,
#   'verificationleveldescription': 'Adequate. Object is adequately described but information may not be vetted',
#   'period': None,
#   'images': [],
#   'worktypes': [{'worktypeid': '268', 'worktype': 'photograph'}],
#   'imagecount': 1,
#   'totalpageviews': 19,
#   'accessionyear': None,
#   'standardreferencenumber': None,
#   'signed': 'D. Curran',
#   'classification': 'Photographs',
#   'relatedcount': 0,
#   'verificationlevel': 2,
#   'primaryimageurl': None,
#   'titlescount': 1,
#   'peoplecount': 1,
#   'style': None,
#   'lastupdate': '2025-10-01T04:29:15-04:00',
#   'commentary': None,
#   'periodid': None,
#   'technique': 'Cyanotype',
#   'edition': None,
#   'description': None,
#   'medium': None,
#   'lendingpermissionlevel': 0,
#   'title': 'Delta Panorama Dipdych',
#   'accessionmethod': 'Purchase',
#   'colors': [{'color': '#e1c8c8',
#     'spectrum': '#c15689',
#     'hue': 'Orange',
#     'percent': 0.3782905982905983,
#     'css3': '#d8bfd8'},
#    {'color': '#c8c8af',
#     'spectrum': '#b55592',
#     'hue': 'Green',
#     'percent': 0.21777777777777776,
#     'css3': '#c0c0c0'},
#    {'color': '#003264',
#     'spectrum': '#1175bc',
#     'hue': 'Blue',
#     'percent': 0.11031339031339031,
#     'css3': '#191970'},
#    {'color': '#00194b',
#     'spectrum': '#1175bc',
#     'hue': 'Blue',
#     'percent': 0.0849002849002849,
#     'css3': '#191970'},
#    {'color': '#7d9696',
#     'spectrum': '#7069af',
#     'hue': 'Green',
#     'percent': 0.058062678062678064,
#     'css3': '#778899'},
#    {'color': '#afafaf',
#     'spectrum': '#8c5fa8',
#     'hue': 'Grey',
#     'percent': 0.05532763532763533,
#     'css3': '#a9a9a9'},
#    {'color': '#4b7d96',
#     'spectrum': '#536fb5',
#     'hue': 'Blue',
#     'percent': 0.04062678062678063,
#     'css3': '#4682b4'},
#    {'color': '#19647d',
#     'spectrum': '#00929e',
#     'hue': 'Blue',
#     'percent': 0.038176638176638175,
#     'css3': '#008080'},
#    {'color': '#194b64',
#     'spectrum': '#00929e',
#     'hue': 'Blue',
#     'percent': 0.016524216524216526,
#     'css3': '#2f4f4f'}],
#   'provenance': 'Seiden & de Cuevas, Inc., New York, New York, purchased from the artist, 1977, Gift to the Fogg Art Museum, 1982. on Long Term Loan at the Fogg Art Museum from 1977 to 1982\r\n',
#   'groupcount': 0,
#   'dated': '1976',
#   'department': 'Department of Photographs',
#   'dateend': 1976,
#   'people': [{'role': 'Artist',
#     'birthplace': 'Santa Barbara, California',
#     'gender': 'male',
#     'displaydate': 'born 1935',
#     'prefix': None,
#     'culture': 'American',
#     'displayname': 'Darryl J. Curran',
#     'alphasort': 'Curran, Darryl J.',
#     'name': 'Darryl J. Curran',
#     'personid': 34556,
#     'deathplace': None,
#     'displayorder': 1}],
#   'url': 'https://www.harvardartmuseums.org/collections/object/283980',
#   'dateoffirstpageview': '2010-01-14',
#   'century': '20th century',
#   'objectnumber': 'P1982.331.2',
#   'labeltext': None,
#   'datebegin': 1976,
#   'culture': 'American',
#   'exhibitioncount': 2,
#   'imagepermissionlevel': 1,
#   'mediacount': 0,
#   'objectid': 283980,
#   'techniqueid': 1022,
#   'dimensions': 'actual: 59 x 75.5 cm (23 1/4 x 29 3/4 in.)',
#   'seeAlso': [{'id': 'https://iiif.harvardartmuseums.org/manifests/object/283980',
#     'type': 'IIIF Manifest',
#     'format': 'application/json',
#     'profile': 'http://iiif.io/api/presentation/2/context.json'}]},
#  {'copyright': None,
#   'contextualtextcount': 0,
#   'creditline': 'Harvard Art Museums/Fogg Museum, Purchase through the generosity of Melvin R. Seiden',
#   'accesslevel': 1,
#   'createdate': '1997-07-19T00:00:00-04:00',
#   'dateoflastpageview': '2025-09-15',
#   'classificationid': 17,
#   'division': 'European and American Art',
#   'markscount': 0,
#   'publicationcount': 0,
#   'totaluniquepageviews': 163,
#   'contact': 'am_europeanamerican@harvard.edu',
#   'colorcount': 9,
#   'rank': 255301,
#   'id': 283981,
#   'state': None,
#   'verificationleveldescription': 'Good. Object is well described and information is vetted',
#   'period': None,
#   'images': [{'date': '2009-04-27',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 343833,
#     'idsid': 12922991,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': None,
#     'renditionnumber': 'INV211393',
#     'displayorder': 1,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:INV211393_dynmc',
#     'alttext': None,
#     'width': 1024,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/12922991',
#     'height': 800},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547636,
#     'idsid': 498080546,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787564',
#     'displayorder': 2,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787564',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498080546',
#     'height': 1987},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547637,
#     'idsid': 498095159,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787565',
#     'displayorder': 3,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787565',
#     'alttext': None,
#     'width': 2046,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498095159',
#     'height': 2550},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547638,
#     'idsid': 498095163,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787566',
#     'displayorder': 4,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787566',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498095163',
#     'height': 2135},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547639,
#     'idsid': 498095171,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787567',
#     'displayorder': 5,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787567',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498095171',
#     'height': 2285},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547640,
#     'idsid': 498095167,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787568',
#     'displayorder': 6,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787568',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498095167',
#     'height': 2247},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547641,
#     'idsid': 498095175,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787569',
#     'displayorder': 7,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787569',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498095175',
#     'height': 1945},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547642,
#     'idsid': 498095179,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787570',
#     'displayorder': 8,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787570',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498095179',
#     'height': 2123},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547643,
#     'idsid': 498095187,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787571',
#     'displayorder': 9,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787571',
#     'alttext': None,
#     'width': 1885,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498095187',
#     'height': 2550},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547644,
#     'idsid': 498095183,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787572',
#     'displayorder': 10,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787572',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498095183',
#     'height': 2368},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547645,
#     'idsid': 498095191,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787573',
#     'displayorder': 11,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787573',
#     'alttext': None,
#     'width': 1886,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498095191',
#     'height': 2550},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547646,
#     'idsid': 498095195,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787574',
#     'displayorder': 12,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787574',
#     'alttext': None,
#     'width': 1760,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498095195',
#     'height': 2550},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547647,
#     'idsid': 498095199,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787575',
#     'displayorder': 13,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787575',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498095199',
#     'height': 2227},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547648,
#     'idsid': 498095203,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787576',
#     'displayorder': 14,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787576',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498095203',
#     'height': 2146},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547649,
#     'idsid': 498095805,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787577',
#     'displayorder': 15,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787577',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498095805',
#     'height': 2103},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547650,
#     'idsid': 498095848,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787578',
#     'displayorder': 16,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787578',
#     'alttext': None,
#     'width': 2413,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498095848',
#     'height': 2550},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547651,
#     'idsid': 498095852,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787579',
#     'displayorder': 17,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787579',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498095852',
#     'height': 2499},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547652,
#     'idsid': 498095856,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787580',
#     'displayorder': 18,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787580',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498095856',
#     'height': 2355},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547653,
#     'idsid': 498095860,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787581',
#     'displayorder': 19,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787581',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498095860',
#     'height': 2389},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547654,
#     'idsid': 498095864,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787582',
#     'displayorder': 20,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787582',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498095864',
#     'height': 2406},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547655,
#     'idsid': 498095868,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787583',
#     'displayorder': 21,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787583',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498095868',
#     'height': 2058},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547656,
#     'idsid': 498095872,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787584',
#     'displayorder': 22,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787584',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498095872',
#     'height': 2081},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547657,
#     'idsid': 498095876,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787585',
#     'displayorder': 23,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787585',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498095876',
#     'height': 2154},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547658,
#     'idsid': 498095880,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787586',
#     'displayorder': 24,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787586',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498095880',
#     'height': 2233},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547659,
#     'idsid': 498095884,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787587',
#     'displayorder': 25,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787587',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498095884',
#     'height': 2124},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547660,
#     'idsid': 498095888,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787588',
#     'displayorder': 26,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787588',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498095888',
#     'height': 2063},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547661,
#     'idsid': 498096256,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787589',
#     'displayorder': 27,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787589',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498096256',
#     'height': 2035},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547662,
#     'idsid': 498096870,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787590',
#     'displayorder': 28,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787590',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498096870',
#     'height': 2184},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547663,
#     'idsid': 498096874,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787591',
#     'displayorder': 29,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787591',
#     'alttext': None,
#     'width': 1848,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498096874',
#     'height': 2550},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547664,
#     'idsid': 498096878,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787592',
#     'displayorder': 30,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787592',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498096878',
#     'height': 2123},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547666,
#     'idsid': 498096886,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787594',
#     'displayorder': 31,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787594',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498096886',
#     'height': 2106},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547667,
#     'idsid': 498096890,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787595',
#     'displayorder': 32,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787595',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498096890',
#     'height': 2218},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547668,
#     'idsid': 498096894,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787596',
#     'displayorder': 33,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787596',
#     'alttext': None,
#     'width': 1621,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498096894',
#     'height': 2550},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547669,
#     'idsid': 498096898,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787597',
#     'displayorder': 34,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787597',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498096898',
#     'height': 2295},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547670,
#     'idsid': 498096902,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787598',
#     'displayorder': 35,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787598',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498096902',
#     'height': 2126},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547671,
#     'idsid': 498096910,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787599',
#     'displayorder': 36,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787599',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498096910',
#     'height': 1500},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547672,
#     'idsid': 498096906,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787600',
#     'displayorder': 37,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787600',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498096906',
#     'height': 2101},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547673,
#     'idsid': 498096914,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787601',
#     'displayorder': 38,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787601',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498096914',
#     'height': 2243},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547674,
#     'idsid': 498096918,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787602',
#     'displayorder': 39,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787602',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498096918',
#     'height': 1461},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547675,
#     'idsid': 498096922,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787603',
#     'displayorder': 40,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787603',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498096922',
#     'height': 1957},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547676,
#     'idsid': 498096926,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787604',
#     'displayorder': 41,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787604',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498096926',
#     'height': 2049},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547677,
#     'idsid': 498096930,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787605',
#     'displayorder': 42,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787605',
#     'alttext': None,
#     'width': 1808,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498096930',
#     'height': 2550},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547678,
#     'idsid': 498096934,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787606',
#     'displayorder': 43,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787606',
#     'alttext': None,
#     'width': 1901,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498096934',
#     'height': 2550},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547679,
#     'idsid': 498096942,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787607',
#     'displayorder': 44,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787607',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498096942',
#     'height': 2110},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547680,
#     'idsid': 498096938,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787608',
#     'displayorder': 45,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787608',
#     'alttext': None,
#     'width': 1949,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498096938',
#     'height': 2550},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547681,
#     'idsid': 498096946,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787609',
#     'displayorder': 46,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787609',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498096946',
#     'height': 2119},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547683,
#     'idsid': 498096950,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787611',
#     'displayorder': 47,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787611',
#     'alttext': None,
#     'width': 1757,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498096950',
#     'height': 2550},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547684,
#     'idsid': 498096962,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787612',
#     'displayorder': 48,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787612',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498096962',
#     'height': 2148},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547686,
#     'idsid': 498096966,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787614',
#     'displayorder': 49,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787614',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498096966',
#     'height': 2174},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547687,
#     'idsid': 498096970,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787615',
#     'displayorder': 50,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787615',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498096970',
#     'height': 2055},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547688,
#     'idsid': 498096974,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787616',
#     'displayorder': 51,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787616',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498096974',
#     'height': 2144},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547689,
#     'idsid': 498096986,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787617',
#     'displayorder': 52,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787617',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498096986',
#     'height': 2140},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547690,
#     'idsid': 498096982,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787618',
#     'displayorder': 53,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787618',
#     'alttext': None,
#     'width': 2004,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498096982',
#     'height': 2550},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547691,
#     'idsid': 498096978,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787619',
#     'displayorder': 54,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787619',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498096978',
#     'height': 2162},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547692,
#     'idsid': 498096990,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787620',
#     'displayorder': 55,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787620',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498096990',
#     'height': 2217},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547693,
#     'idsid': 498096994,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787621',
#     'displayorder': 56,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787621',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498096994',
#     'height': 2112},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547694,
#     'idsid': 498096998,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787622',
#     'displayorder': 57,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787622',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498096998',
#     'height': 2164},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547695,
#     'idsid': 498097002,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787623',
#     'displayorder': 58,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787623',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498097002',
#     'height': 2362},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547696,
#     'idsid': 498097006,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787624',
#     'displayorder': 59,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787624',
#     'alttext': None,
#     'width': 2017,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498097006',
#     'height': 2550},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547697,
#     'idsid': 498097014,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787625',
#     'displayorder': 60,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787625',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498097014',
#     'height': 2360},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547698,
#     'idsid': 498097010,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787626',
#     'displayorder': 61,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787626',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498097010',
#     'height': 2215},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547699,
#     'idsid': 498097018,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787627',
#     'displayorder': 62,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787627',
#     'alttext': None,
#     'width': 2200,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498097018',
#     'height': 2550},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547700,
#     'idsid': 498097022,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787628',
#     'displayorder': 63,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787628',
#     'alttext': None,
#     'width': 2002,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498097022',
#     'height': 2550},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547701,
#     'idsid': 498097030,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787629',
#     'displayorder': 64,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787629',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498097030',
#     'height': 2100},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547702,
#     'idsid': 498097026,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787630',
#     'displayorder': 65,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787630',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498097026',
#     'height': 2070},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547703,
#     'idsid': 498097116,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787631',
#     'displayorder': 66,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787631',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498097116',
#     'height': 2106},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547704,
#     'idsid': 498097124,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787632',
#     'displayorder': 67,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787632',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498097124',
#     'height': 1410},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547705,
#     'idsid': 498097120,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787633',
#     'displayorder': 68,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787633',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498097120',
#     'height': 2287},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547706,
#     'idsid': 498097132,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787634',
#     'displayorder': 69,
#     'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:787634',
#     'alttext': None,
#     'width': 2550,
#     'publiccaption': None,
#     'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/498097132',
#     'height': 2097},
#    {'date': '2023-10-24',
#     'copyright': 'President and Fellows of Harvard College',
#     'imageid': 547708,
#     'idsid': 498097136,
#     'format': 'image/jpeg',
#     'description': None,
#     'technique': 'Make:SONY;Model:ILCE-7RM4;Orientation:1;Software:Adobe Photoshop 24.4 (Macintosh);',
#     'renditionnumber': '787636',
#     'displayorder': 70,
# ...
#     'displayorder': 2},
#    {'role': 'Publisher',
#     'birthplace': None,
#     'gender': 'unknown',
#     'displaydate': 'active 1876-1913',
#     'prefix': 'Published by',
#     'culture': 'French',
#     'displayname': 'Published by Ludovic Baschet',
#     'alphasort': 'Baschet, Ludovic',
#     'name': 'Ludovic Baschet',
#     'personid': 42872,
#     'deathplace': None,
#     'displayorder': 3},
#    {'role': 'Printer',
#     'birthplace': None,
#     'gender': 'unknown',
#     'displaydate': 'active c. 1850s-1890s',
#     'prefix': 'Printed by',
#     'culture': 'French',
#     'displayname': 'Printed by Goupil et Cie',
#     'alphasort': 'Goupil et Cie',
#     'name': 'Goupil et Cie',
#     'personid': 24847,
#     'deathplace': None,
#     'displayorder': 4}],
#   'url': 'https://www.harvardartmuseums.org/collections/object/284145',
#   'dateoffirstpageview': '2012-09-01',
#   'century': '19th century',
#   'objectnumber': 'P1982.110.5',
#   'labeltext': None,
#   'datebegin': 1876,
#   'culture': 'French',
#   'exhibitioncount': 0,
#   'imagepermissionlevel': 0,
#   'mediacount': 0,
#   'objectid': 284145,
#   'techniqueid': 259,
#   'dimensions': 'image: 11.2 x 8.7 cm (4 7/16 x 3 7/16 in.)\r\nmount: 34.7 x 26.7 cm (13 11/16 x 10 1/2 in.)'},
#  {'copyright': None,
#   'contextualtextcount': 0,
#   'creditline': 'Harvard Art Museums/Fogg Museum, Purchase through the generosity of Melvin R. Seiden',
#   'accesslevel': 1,
#   'createdate': '1997-07-19T00:00:00-04:00',
#   'dateoflastpageview': '2024-08-26',
#   'classificationid': 17,
#   'division': 'European and American Art',
#   'markscount': 1,
#   'publicationcount': 0,
#   'totaluniquepageviews': 3,
#   'contact': 'am_europeanamerican@harvard.edu',
#   'colorcount': 0,
#   'rank': 253679,
#   'id': 284146,
#   'state': None,
#   'verificationleveldescription': 'Good. Object is well described and information is vetted',
#   'period': None,
#   'worktypes': [{'worktypeid': '46', 'worktype': 'book page'},
#    {'worktypeid': '268', 'worktype': 'photograph'}],
#   'imagecount': 0,
#   'totalpageviews': 3,
#   'accessionyear': None,
#   'standardreferencenumber': None,
#   'signed': None,
#   'classification': 'Photographs',
#   'relatedcount': 1,
#   'verificationlevel': 3,
#   'titlescount': 2,
#   'peoplecount': 4,
#   'style': None,
#   'lastupdate': '2025-10-01T04:29:15-04:00',
#   'commentary': None,
#   'periodid': None,
#   'technique': 'Woodburytype',
#   'edition': None,
#   'description': None,
#   'medium': None,
#   'lendingpermissionlevel': 0,
#   'title': "Ravin d'Amélie",
#   'accessionmethod': 'Purchase',
#   'provenance': 'Seiden & de Cuevas, Inc., New York, New York. on Long Term Loan to the Fogg Art Museum from 1979 to 1982\r\n',
#   'groupcount': 0,
#   'dated': '1879-1884',
#   'department': 'Department of Photographs',
#   'dateend': 1884,
#   'people': [{'role': 'Artist',
#     'birthplace': None,
#     'gender': 'unknown',
#     'displaydate': None,
#     'prefix': None,
#     'culture': None,
#     'displayname': 'Unidentified Artist',
#     'alphasort': 'Unidentified Artist',
#     'name': 'Unidentified Artist',
#     'personid': 34147,
#     'deathplace': None,
#     'displayorder': 1},
#    {'role': 'Painter',
#     'birthplace': 'Magny-Vernois (Haute-Saône)',
#     'gender': 'unknown',
#     'displaydate': '1845 - 1932',
#     'prefix': 'Painted by',
#     'culture': 'French',
#     'displayname': 'Painted by Gustave Paul Robinet',
#     'alphasort': 'Robinet, Gustave Paul',
#     'name': 'Gustave Paul Robinet',
#     'personid': 54111,
#     'deathplace': None,
#     'displayorder': 2},
#    {'role': 'Publisher',
#     'birthplace': None,
#     'gender': 'unknown',
#     'displaydate': 'active 1876-1913',
#     'prefix': 'Published by',
#     'culture': 'French',
#     'displayname': 'Published by Ludovic Baschet',
#     'alphasort': 'Baschet, Ludovic',
#     'name': 'Ludovic Baschet',
#     'personid': 42872,
#     'deathplace': None,
#     'displayorder': 3},
#    {'role': 'Printer',
#     'birthplace': None,
#     'gender': 'unknown',
#     'displaydate': 'active c. 1850s-1890s',
#     'prefix': 'Printed by',
#     'culture': 'French',
#     'displayname': 'Printed by Goupil et Cie',
#     'alphasort': 'Goupil et Cie',
#     'name': 'Goupil et Cie',
#     'personid': 24847,
#     'deathplace': None,
#     'displayorder': 4}],
#   'url': 'https://www.harvardartmuseums.org/collections/object/284146',
#   'dateoffirstpageview': '2019-05-30',
#   'century': '19th century',
#   'objectnumber': 'P1982.110.6',
#   'labeltext': None,
#   'datebegin': 1879,
#   'culture': 'French',
#   'exhibitioncount': 0,
#   'imagepermissionlevel': 0,
#   'mediacount': 0,
#   'objectid': 284146,
#   'techniqueid': 259,
#   'dimensions': 'image: 17.7 x 23.4 cm (6 15/16 x 9 3/16 in.)\r\nmount: 33.9 x 25.6 cm (13 3/8 x 10 1/16 in.)'},
#  {'copyright': None,
#   'contextualtextcount': 0,
#   'creditline': 'Harvard Art Museums/Fogg Museum, Purchase through the generosity of Melvin R. Seiden',
#   'accesslevel': 1,
#   'createdate': '1997-07-19T00:00:00-04:00',
#   'dateoflastpageview': '2025-07-28',
#   'classificationid': 17,
#   'division': 'European and American Art',
#   'markscount': 1,
#   'publicationcount': 0,
#   'totaluniquepageviews': 12,
#   'contact': 'am_europeanamerican@harvard.edu',
#   'colorcount': 0,
#   'rank': 253680,
#   'id': 284147,
#   'state': None,
#   'verificationleveldescription': 'Good. Object is well described and information is vetted',
#   'period': None,
#   'worktypes': [{'worktypeid': '46', 'worktype': 'book page'},
#    {'worktypeid': '268', 'worktype': 'photograph'}],
#   'imagecount': 0,
#   'totalpageviews': 22,
#   'accessionyear': None,
#   'standardreferencenumber': None,
#   'signed': None,
#   'classification': 'Photographs',
#   'relatedcount': 1,
#   'verificationlevel': 3,
#   'titlescount': 2,
#   'peoplecount': 4,
#   'style': None,
#   'lastupdate': '2025-10-01T04:29:15-04:00',
#   'commentary': None,
#   'periodid': None,
#   'technique': 'Woodburytype',
#   'edition': None,
#   'description': None,
#   'medium': None,
#   'lendingpermissionlevel': 0,
#   'title': '"Lit du Vitznauerbach, Lac des Quatre-Cantons (Suisse)" (Riverbank at Vitznauerbach, Lake of the Four Cantons (Switzerland))',
#   'accessionmethod': 'Purchase',
#   'provenance': 'Seiden & de Cuevas, Inc., New York, New York. on Long Term Loan to the Fogg Art Museum from 1979 to 1982\r\n',
#   'groupcount': 0,
#   'dated': '1869-1884',
#   'department': 'Department of Photographs',
#   'dateend': 1884,
#   'people': [{'role': 'Artist',
#     'birthplace': None,
#     'gender': 'unknown',
#     'displaydate': None,
#     'prefix': None,
#     'culture': None,
#     'displayname': 'Unidentified Artist',
#     'alphasort': 'Unidentified Artist',
#     'name': 'Unidentified Artist',
#     'personid': 34147,
#     'deathplace': None,
#     'displayorder': 1},
#    {'role': 'Painter',
#     'birthplace': 'Magny-Vernois (Haute-Saône)',
#     'gender': 'unknown',
#     'displaydate': '1845 - 1932',
#     'prefix': 'Painted by',
#     'culture': 'French',
#     'displayname': 'Painted by Gustave Paul Robinet',
#     'alphasort': 'Robinet, Gustave Paul',
#     'name': 'Gustave Paul Robinet',
#     'personid': 54111,
#     'deathplace': None,
#     'displayorder': 2},
#    {'role': 'Publisher',
#     'birthplace': None,
#     'gender': 'unknown',
#     'displaydate': 'active 1876-1913',
#     'prefix': 'Published by',
#     'culture': 'French',
#     'displayname': 'Published by Ludovic Baschet',
#     'alphasort': 'Baschet, Ludovic',
#     'name': 'Ludovic Baschet',
#     'personid': 42872,
#     'deathplace': None,
#     'displayorder': 3},
#    {'role': 'Printer',
#     'birthplace': None,
#     'gender': 'unknown',
#     'displaydate': 'active c. 1850s-1890s',
#     'prefix': 'Printed by',
#     'culture': 'French',
#     'displayname': 'Printed by Goupil et Cie',
#     'alphasort': 'Goupil et Cie',
#     'name': 'Goupil et Cie',
#     'personid': 24847,
#     'deathplace': None,
#     'displayorder': 4}],
#   'url': 'https://www.harvardartmuseums.org/collections/object/284147',
#   'dateoffirstpageview': '2013-05-15',
#   'century': '19th century',
#   'objectnumber': 'P1982.110.7',
#   'labeltext': None,
#   'datebegin': 1869,
#   'culture': 'French',
#   'exhibitioncount': 0,
#   'imagepermissionlevel': 0,
#   'mediacount': 0,
#   'objectid': 284147,
#   'techniqueid': 259,
#   'dimensions': 'image: 24.2 x 19.4 cm (9 1/2 x 7 5/8 in.)\r\nmount: 33.7 x 25.6 cm (13 1/4 x 10 1/16 in.)'},
#  {'copyright': None,
#   'contextualtextcount': 0,
#   'creditline': 'Harvard Art Museums/Fogg Museum, Student Print Rental Program and a National Endowment for the Arts Grant',
#   'accesslevel': 1,
#   'createdate': '1997-07-19T00:00:00-04:00',
#   'dateoflastpageview': '2024-02-18',
#   'classificationid': 17,
#   'division': 'Modern and Contemporary Art',
#   'markscount': 1,
#   'publicationcount': 0,
#   'totaluniquepageviews': 16,
#   'contact': 'am_moderncontemporary@harvard.edu',
#   'colorcount': 10,
#   'rank': 252760,
#   'id': 284149,
#   'state': None,
#   'verificationleveldescription': 'Adequate. Object is adequately described but information may not be vetted',
#   'period': None,
#   'images': [],
#   'worktypes': [{'worktypeid': '268', 'worktype': 'photograph'},
#    {'worktypeid': '270', 'worktype': 'photomontage'}],
#   'imagecount': 1,
#   'totalpageviews': 17,
#   'accessionyear': 1974,
#   'standardreferencenumber': None,
#   'signed': 'D. Curran',
#   'classification': 'Photographs',
#   'relatedcount': 0,
#   'verificationlevel': 2,
#   'primaryimageurl': None,
#   'titlescount': 1,
#   'peoplecount': 1,
#   'style': None,
#   'lastupdate': '2025-10-01T04:29:15-04:00',
#   'commentary': None,
#   'periodid': None,
#   'technique': 'Mixed technique',
#   'edition': None,
#   'description': None,
#   'medium': 'Cyanotype, gum bichromate, and lacquer transfer',
#   'lendingpermissionlevel': 0,
#   'title': 'Untitled',
#   'accessionmethod': 'Purchase',
#   'colors': [{'color': '#e1c8c8',
#     'spectrum': '#c15689',
#     'hue': 'Orange',
#     'percent': 0.6445584045584045,
#     'css3': '#d8bfd8'},
#    {'color': '#c8af96',
#     'spectrum': '#e66c64',
#     'hue': 'Brown',
#     'percent': 0.17925925925925926,
#     'css3': '#d2b48c'},
#    {'color': '#96967d',
#     'spectrum': '#8e5ea7',
#     'hue': 'Green',
#     'percent': 0.07247863247863248,
#     'css3': '#808080'},
#    {'color': '#647d7d',
#     'spectrum': '#6c6ab0',
#     'hue': 'Blue',
#     'percent': 0.0211965811965812,
#     'css3': '#708090'},
#    {'color': '#4b7d64',
#     'spectrum': '#3db657',
#     'hue': 'Green',
#     'percent': 0.014700854700854702,
#     'css3': '#2e8b57'},
#    {'color': '#e16464',
#     'spectrum': '#e46867',
#     'hue': 'Red',
#     'percent': 0.0105982905982906,
#     'css3': '#cd5c5c'},
#    {'color': '#e1af00',
#     'spectrum': '#fdb912',
#     'hue': 'Yellow',
#     'percent': 0.010028490028490029,
#     'css3': '#ffa500'},
#    {'color': '#326464',
#     'spectrum': '#24b362',
#     'hue': 'Blue',
#     'percent': 0.007806267806267806,
#     'css3': '#2f4f4f'},
#    {'color': '#e1324b',
#     'spectrum': '#dd5872',
#     'hue': 'Red',
#     'percent': 0.006210826210826211,
#     'css3': '#dc143c'},
#    {'color': '#e1af19',
#     'spectrum': '#fcb41a',
#     'hue': 'Yellow',
#     'percent': 0.005868945868945869,
#     'css3': '#daa520'}],
#   'provenance': 'Darryl Curran, Los Angeles, California, sold to the Fogg Art Museum, 1974.\r\n',
#   'groupcount': 0,
#   'dated': '1973',
#   'department': 'Department of Photographs',
#   'dateend': 1973,
#   'people': [{'role': 'Artist',
#     'birthplace': 'Santa Barbara, California',
#     'gender': 'male',
#     'displaydate': 'born 1935',
#     'prefix': None,
#     'culture': 'American',
#     'displayname': 'Darryl J. Curran',
#     'alphasort': 'Curran, Darryl J.',
#     'name': 'Darryl J. Curran',
#     'personid': 34556,
#     'deathplace': None,
#     'displayorder': 1}],
#   'url': 'https://www.harvardartmuseums.org/collections/object/284149',
#   'dateoffirstpageview': '2012-12-24',
#   'century': '20th century',
#   'objectnumber': 'P1974.28',
#   'labeltext': None,
#   'datebegin': 1973,
#   'culture': 'American',
#   'exhibitioncount': 0,
#   'imagepermissionlevel': 1,
#   'mediacount': 0,
#   'objectid': 284149,
#   'techniqueid': 358,
#   'dimensions': 'actual: 74.9 x 58.4 cm (29 1/2 x 23 in.)',
#   'seeAlso': [{'id': 'https://iiif.harvardartmuseums.org/manifests/object/284149',
#     'type': 'IIIF Manifest',
#     'format': 'application/json',
#     'profile': 'http://iiif.io/api/presentation/2/context.json'}]},
#  {'copyright': None,
#   'contextualtextcount': 0,
#   'creditline': 'Harvard Art Museums/Fogg Museum, Student Print Rental Program and a National Endowment for the Arts Grant',
#   'accesslevel': 1,
#   'createdate': '1997-07-19T00:00:00-04:00',
#   'dateoflastpageview': '2023-03-15',
#   'classificationid': 17,
#   'division': 'Modern and Contemporary Art',
#   'markscount': 1,
#   'publicationcount': 0,
#   'totaluniquepageviews': 11,
#   'contact': 'am_moderncontemporary@harvard.edu',
#   'colorcount': 10,
#   'rank': 252759,
#   'id': 284150,
#   'state': None,
#   'verificationleveldescription': 'Adequate. Object is adequately described but information may not be vetted',
#   'period': None,
#   'images': [],
#   'worktypes': [{'worktypeid': '270', 'worktype': 'photomontage'},
#    {'worktypeid': '268', 'worktype': 'photograph'}],
#   'imagecount': 1,
#   'totalpageviews': 13,
#   'accessionyear': 1974,
#   'standardreferencenumber': None,
#   'signed': 'D. Curran',
#   'classification': 'Photographs',
#   'relatedcount': 0,
#   'verificationlevel': 2,
#   'primaryimageurl': None,
#   'titlescount': 1,
#   'peoplecount': 1,
#   'style': None,
#   'lastupdate': '2025-10-01T04:29:15-04:00',
#   'commentary': None,
#   'periodid': None,
#   'technique': 'Mixed technique',
#   'edition': None,
#   'description': None,
#   'medium': 'Cyanotype, gum bichromate, and lacquer transfer',
#   'lendingpermissionlevel': 0,
#   'title': 'Untitled',
#   'accessionmethod': 'Purchase',
#   'colors': [{'color': '#e1c8c8',
#     'spectrum': '#c15689',
#     'hue': 'Orange',
#     'percent': 0.8146438746438747,
#     'css3': '#d8bfd8'},
#    {'color': '#644b32',
#     'spectrum': '#59ba4a',
#     'hue': 'Brown',
#     'percent': 0.034074074074074076,
#     'css3': '#556b2f'},
#    {'color': '#e17d7d',
#     'spectrum': '#e36769',
#     'hue': 'Red',
#     'percent': 0.027122507122507123,
#     'css3': '#f08080'},
#    {'color': '#7d7d64',
#     'spectrum': '#6cbd45',
#     'hue': 'Yellow',
#     'percent': 0.023133903133903132,
#     'css3': '#808080'},
#    {'color': '#af967d',
#     'spectrum': '#c25687',
#     'hue': 'Brown',
#     'percent': 0.019088319088319088,
#     'css3': '#bc8f8f'},
#    {'color': '#64644b',
#     'spectrum': '#59ba4a',
#     'hue': 'Green',
#     'percent': 0.01886039886039886,
#     'css3': '#696969'},
#    {'color': '#4b3219',
#     'spectrum': '#4ab851',
#     'hue': 'Brown',
#     'percent': 0.014415954415954417,
#     'css3': '#556b2f'},
#    {'color': '#7daf96',
#     'spectrum': '#7069af',
#     'hue': 'Green',
#     'percent': 0.010313390313390314,
#     'css3': '#8fbc8f'},
#    {'color': '#e16432',
#     'spectrum': '#f17c4f',
#     'hue': 'Orange',
#     'percent': 0.008774928774928775,
#     'css3': '#d2691e'},
#    {'color': '#c84b4b',
#     'spectrum': '#dd5872',
#     'hue': 'Red',
#     'percent': 0.008205128205128205,
#     'css3': '#cd5c5c'}],
#   'provenance': 'Darryl Curran, Los Angeles, California, sold to the Fogg Art Museum, 1974.\r\n',
#   'groupcount': 0,
#   'dated': '1973',
#   'department': 'Department of Photographs',
#   'dateend': 1973,
#   'people': [{'role': 'Artist',
#     'birthplace': 'Santa Barbara, California',
#     'gender': 'male',
#     'displaydate': 'born 1935',
#     'prefix': None,
#     'culture': 'American',
#     'displayname': 'Darryl J. Curran',
#     'alphasort': 'Curran, Darryl J.',
#     'name': 'Darryl J. Curran',
#     'personid': 34556,
#     'deathplace': None,
#     'displayorder': 1}],
#   'url': 'https://www.harvardartmuseums.org/collections/object/284150',
#   'dateoffirstpageview': '2013-02-14',
#   'century': '20th century',
#   'objectnumber': 'P1974.27',
#   'labeltext': None,
#   'datebegin': 1973,
#   'culture': 'American',
#   'exhibitioncount': 0,
#   'imagepermissionlevel': 1,
#   'mediacount': 0,
#   'objectid': 284150,
#   'techniqueid': 358,
#   'dimensions': 'actual: 59.1 x 74.9 cm (23 1/4 x 29 1/2 in.)',
#   'seeAlso': [{'id': 'https://iiif.harvardartmuseums.org/manifests/object/284150',
#     'type': 'IIIF Manifest',
#     'format': 'application/json',
#     'profile': 'http://iiif.io/api/presentation/2/context.json'}]}]

# %%
print(type(data['records']))
# Out:
# <class 'list'>

# %%
data['records'][0]
# Out:
# {'copyright': None,
#  'contextualtextcount': 0,
#  'creditline': 'Harvard Art Museums/Fogg Museum, Purchase through the generosity of Melvin R. Seiden',
#  'accesslevel': 1,
#  'createdate': '1997-07-19T00:00:00-04:00',
#  'dateoflastpageview': '2025-07-30',
#  'classificationid': 17,
#  'division': 'European and American Art',
#  'markscount': 0,
#  'publicationcount': 0,
#  'totaluniquepageviews': 6,
#  'contact': 'am_europeanamerican@harvard.edu',
#  'colorcount': 6,
#  'rank': 254783,
#  'id': 283979,
#  'state': None,
#  'verificationleveldescription': 'Good. Object is well described and information is vetted',
#  'period': None,
#  'images': [{'date': '2004-12-14',
#    'copyright': 'President and Fellows of Harvard College',
#    'imageid': 86607,
#    'idsid': 17916268,
#    'format': 'image/jpeg',
#    'description': None,
#    'technique': None,
#    'renditionnumber': '76784',
#    'displayorder': 1,
#    'baseimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:76784_dynmc',
#    'alttext': None,
#    'width': 1024,
#    'publiccaption': None,
#    'iiifbaseuri': 'https://ids.lib.harvard.edu/ids/iiif/17916268',
#    'height': 748}],
#  'worktypes': [{'worktypeid': '268', 'worktype': 'photograph'}],
#  'imagecount': 1,
#  'totalpageviews': 8,
#  'accessionyear': None,
#  'standardreferencenumber': None,
#  'signed': None,
#  'classification': 'Photographs',
#  'relatedcount': 1,
#  'verificationlevel': 3,
#  'primaryimageurl': 'https://nrs.harvard.edu/urn-3:HUAM:76784_dynmc',
#  'titlescount': 2,
#  'peoplecount': 1,
#  'style': None,
#  'lastupdate': '2025-10-01T04:29:15-04:00',
#  'commentary': None,
#  'periodid': None,
#  'technique': 'Albumen silver print',
#  'edition': None,
#  'description': None,
#  'medium': 'Hand-colored albumen silver print on card',
#  'lendingpermissionlevel': 0,
#  'title': 'Untitled (Japanese port)',
#  'accessionmethod': 'Purchase',
#  'colors': [{'color': '#c8af96',
#    'spectrum': '#e66c64',
#    'hue': 'Brown',
#    'percent': 0.35345565749235475,
#    'css3': '#d2b48c'},
#   {'color': '#967d64',
#    'spectrum': '#b65590',
#    'hue': 'Brown',
#    'percent': 0.22403669724770642,
#    'css3': '#808080'},
#   {'color': '#af967d',
#    'spectrum': '#c25687',
#    'hue': 'Brown',
#    'percent': 0.20807339449541284,
#    'css3': '#bc8f8f'},
#   {'color': '#7d644b',
#    'spectrum': '#b25593',
#    'hue': 'Yellow',
#    'percent': 0.12691131498470948,
#    'css3': '#696969'},
#   {'color': '#e1e1c8',
#    'spectrum': '#e9715f',
#    'hue': 'Green',
#    'percent': 0.06397553516819572,
#    'css3': '#dcdcdc'},
#   {'color': '#644b32',
#    'spectrum': '#59ba4a',
#    'hue': 'Brown',
#    'percent': 0.023547400611620795,
#    'css3': '#556b2f'}],
#  'provenance': 'Sotheby Parke Bernet & Co., New York, New York, sold to Seiden & de Cuevas Inc., 1980.\r\nSeiden & de Cuevas, Inc., New York, New York, purchased from Sotheby Parke Bernet, New York, N, 1980, Gift to the Fogg Art Museum, 1982. on Long Term Loan to the Fogg Art Museum from 1980 to 1982\r\n',
#  'groupcount': 0,
#  'dated': 'c. 1880-c. 1889',
#  'department': 'Department of Photographs',
#  'dateend': 1889,
#  'people': [{'role': 'Artist',
#    'birthplace': None,
#    'gender': 'unknown',
#    'displaydate': None,
#    'prefix': None,
#    'culture': None,
#    'displayname': 'Unidentified Artist',
#    'alphasort': 'Unidentified Artist',
#    'name': 'Unidentified Artist',
#    'personid': 34147,
#    'deathplace': None,
#    'displayorder': 1}],
#  'url': 'https://www.harvardartmuseums.org/collections/object/283979',
#  'dateoffirstpageview': '2009-07-20',
#  'century': '19th century',
#  'objectnumber': 'P1982.377.50',
#  'labeltext': None,
#  'datebegin': 1880,
#  'culture': 'Japanese',
#  'exhibitioncount': 0,
#  'imagepermissionlevel': 0,
#  'mediacount': 0,
#  'objectid': 283979,
#  'techniqueid': 110,
#  'dimensions': '9 x 13.8 cm (3 9/16 x 5 7/16 in.)',
#  'seeAlso': [{'id': 'https://iiif.harvardartmuseums.org/manifests/object/283979',
#    'type': 'IIIF Manifest',
#    'format': 'application/json',
#    'profile': 'http://iiif.io/api/presentation/2/context.json'}]}

# %%
artifact_metadata = []
artifact_media = []
artifact_colors = []

for i in all_records:  
    artifact_metadata.append(dict(
        id = i['id'],
        title = i['title'],
        culture = i['culture'],
        period = i['period'],
        century = i['century'],
        medium = i['medium'],
        dimensions = i['dimensions'],
        description = i['description'],
        department = i['department'],
        classification = i['classification'],
        accessionyear = i['accessionyear'],
        accessionmethod = i['accessionmethod']))

    artifact_media.append(dict(
        objectid = i['objectid'],
        imagecount = i['imagecount'],
        mediacount = i['mediacount'],
        colorcount = i['colorcount'],
        rank_value = i['rank'],
        datebegin = i['datebegin'],
        dateend = i['dateend']))
    
    color_details = i.get('colors')   
    if color_details:
        for j in color_details:
            artifact_colors.append(dict(
                objectid = i['objectid'],
                color = j['color'],
                spectrum = j['spectrum'],
                hue = j['hue'],
                percent = j['percent'],
                css3 = j['css3']))

# %%
print("Metadata:", len(artifact_metadata))
print("Media:", len(artifact_media))
print("Colors:", len(artifact_colors))
# Out:
# Metadata: 12500
# Media: 12500
# Colors: 94090

# %%
from collections import Counter

counts = Counter([i['classification'] for i in artifact_metadata])
print(counts)
# Out:
# Counter({'Paintings': 2500, 'Sculpture': 2500, 'Drawings': 2500, 'Fragments': 2500, 'Photographs': 2500})

# %%
len(artifact_metadata)
# Out:
# 12500

# %%
len(artifact_media)
# Out:
# 12500

# %%
len(artifact_colors)
# Out:
# 95895

# %%
artifact_metadata
# Out:
# [{'id': 228185,
#   'title': 'Still Life with Peaches',
#   'culture': 'French',
#   'period': None,
#   'century': '19th century',
#   'medium': 'Oil on cradled panel',
#   'dimensions': '26 x 31.8 cm (10 1/4 x 12 1/2 in.)\r\nframe: 41.9 x 46.7 x 2.9 cm (16 1/2 x 18 3/8 x 1 1/8 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1958,
#   'accessionmethod': 'Gift'},
#  {'id': 228189,
#   'title': 'Walter Charles James and Charles Stewart Hardinge',
#   'culture': 'British',
#   'period': None,
#   'century': '19th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '127.5 x 86 cm (50 3/16 x 33 7/8 in.)\r\nframed: 151.5 x 126 cm (59 5/8 x 49 5/8 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1958,
#   'accessionmethod': 'Gift'},
#  {'id': 228190,
#   'title': 'Tap Dance Studio',
#   'culture': 'American',
#   'period': None,
#   'century': '20th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '71.1 x 76.2 cm (28 x 30 in.)',
#   'description': None,
#   'department': 'Department of American Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1962,
#   'accessionmethod': 'Gift'},
#  {'id': 228194,
#   'title': 'Nymph Tormented by Cupid',
#   'culture': 'French',
#   'period': None,
#   'century': '19th century',
#   'medium': 'Oil on panel',
#   'dimensions': '27.8 x 42 cm (10 15/16 x 16 9/16 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1963,
#   'accessionmethod': 'Gift'},
#  {'id': 228199,
#   'title': 'Study for "Charles I Demanding Impeachment of Five Members of The House of Commons"',
#   'culture': 'American',
#   'period': None,
#   'century': '18th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '64.1 x 76.5 cm (25 1/4 x 30 1/8 in.)\r\nframed: 75.9 x 88.3 x 7 cm (29 7/8 x 34 3/4 x 2 3/4 in.)',
#   'description': None,
#   'department': 'Department of American Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1957,
#   'accessionmethod': 'Gift'},
#  {'id': 228201,
#   'title': 'Susan M. Sherman Farrar (Mrs. Ezra Farrar)  (1821-1891)',
#   'culture': 'American',
#   'period': None,
#   'century': '19th century',
#   'medium': 'Watercolor on ivory',
#   'dimensions': '6 x 4.7 cm (2 3/8 x 1 7/8 in.)',
#   'description': None,
#   'department': 'Department of American Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1957,
#   'accessionmethod': 'Gift'},
#  {'id': 228202,
#   'title': 'Still Life with Apples, a Pear, and a Ceramic Portrait Jug',
#   'culture': 'French',
#   'period': None,
#   'century': '19th century',
#   'medium': 'Oil on paper mounted on panel',
#   'dimensions': '28.6 x 36.2 cm (11 1/4 x 14 1/4 in.)\r\nframe: 43.5 x 52.4 x 2.9 cm (17 1/8 x 20 5/8 x 1 1/8 in.)',
#   'description': 'The (cradled) panel is mahogany.',
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1958,
#   'accessionmethod': 'Gift'},
#  {'id': 228203,
#   'title': 'The Taj Mahal, Moonlit',
#   'culture': 'American',
#   'period': None,
#   'century': '20th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '123 x 198.2 cm (48 7/16 x 78 1/16 in.)\r\nframed: 150.8 x 226.1 x 3.8 cm (59 3/8 x 89 x 1 1/2 in.)',
#   'description': None,
#   'department': 'Department of American Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1962,
#   'accessionmethod': 'Transfer'},
#  {'id': 228204,
#   'title': 'Landscape',
#   'culture': 'American',
#   'period': None,
#   'century': '19th-20th century',
#   'medium': 'Oil on cardboard',
#   'dimensions': '30.5 × 30.5 cm (12 × 12 in.)\r\nframe: 33 × 33.2 × 2.7 cm (13 × 13 1/16 × 1 1/16 in.)',
#   'description': None,
#   'department': 'Department of Modern & Contemporary Art',
#   'classification': 'Paintings',
#   'accessionyear': 1958,
#   'accessionmethod': 'Gift'},
#  {'id': 228206,
#   'title': 'Composition',
#   'culture': 'American',
#   'period': None,
#   'century': '20th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '136.8 x 86 cm (53 7/8 x 33 7/8 in.)\r\nframed: 138.8 x 88 x 4.5 cm (54 5/8 x 34 5/8 x 1 3/4 in.)',
#   'description': None,
#   'department': 'Department of Modern & Contemporary Art',
#   'classification': 'Paintings',
#   'accessionyear': 1959,
#   'accessionmethod': 'Gift'},
#  {'id': 228209,
#   'title': 'Bright Day, Vermont',
#   'culture': 'American',
#   'period': None,
#   'century': '20th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '81.3 x 101.6 cm (32 x 40 in.)',
#   'description': None,
#   'department': 'Department of Modern & Contemporary Art',
#   'classification': 'Paintings',
#   'accessionyear': 1962,
#   'accessionmethod': 'Gift'},
#  {'id': 228210,
#   'title': 'Reading Girl',
#   'culture': 'American',
#   'period': None,
#   'century': '20th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '24.13 x 19.69 cm (9 1/2 x 7 3/4 in.)',
#   'description': None,
#   'department': 'Department of Modern & Contemporary Art',
#   'classification': 'Paintings',
#   'accessionyear': 1962,
#   'accessionmethod': 'Gift'},
#  {'id': 228213,
#   'title': 'A Family Group',
#   'culture': 'Dutch',
#   'period': None,
#   'century': '17th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '109.5 x 108.8 cm (43 1/8 x 42 13/16 in.)\r\nframed: 134.7 x 134.7 cm (53 1/16 x 53 1/16 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1957,
#   'accessionmethod': 'Purchase'},
#  {'id': 228214,
#   'title': 'A Fishing Boat, Honfleur',
#   'culture': 'French',
#   'period': None,
#   'century': '19th century',
#   'medium': 'Oil on paper laid down on ragboard',
#   'dimensions': 'sight: 23.2 x 31.1 cm (9 1/8 x 12 1/4 in.)\r\nframed: 41.5 x 50.5 cm (16 5/16 x 19 7/8 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1962,
#   'accessionmethod': 'Gift'},
#  {'id': 228218,
#   'title': 'Legno e rosso 3',
#   'culture': 'Italian',
#   'period': None,
#   'century': '20th century',
#   'medium': 'Painted canvas covered with lacquered bark',
#   'dimensions': '158.8 x 87.6 cm (62 1/2 x 34 1/2 in.)\r\nframed: 160 x 89.6 x 3.6 cm (63 x 35 1/4 x 1 7/16 in.)',
#   'description': None,
#   'department': 'Department of Modern & Contemporary Art',
#   'classification': 'Paintings',
#   'accessionyear': 1959,
#   'accessionmethod': 'Gift'},
#  {'id': 228219,
#   'title': 'Peasant Working in a Field',
#   'culture': 'Austrian',
#   'period': None,
#   'century': '19th-20th century',
#   'medium': 'Oil on board',
#   'dimensions': '44.8 x 36.8 cm (17 5/8 x 14 1/2 in.)\r\nframed: 66 x 58.4 x 7.6 cm (26 x 23 x 3 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1962,
#   'accessionmethod': 'Gift'},
#  {'id': 228220,
#   'title': 'Provincetown',
#   'culture': 'American',
#   'period': None,
#   'century': '19th-20th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '19.1 x 25.4 cm (7 1/2 x 10 in.)',
#   'description': None,
#   'department': 'Department of American Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1962,
#   'accessionmethod': 'Gift'},
#  {'id': 228222,
#   'title': 'Color Barrier',
#   'culture': 'American',
#   'period': None,
#   'century': '20th century',
#   'medium': 'Acrylic resin paint (magna) on canvas',
#   'dimensions': '232.4 x 152.7 cm (91 1/2 x 60 1/8 in.)\r\nframed: 235.6 x 155.6 x 3.8 cm (92 3/4 x 61 1/4 x 1 1/2 in.)',
#   'description': None,
#   'department': 'Department of Modern & Contemporary Art',
#   'classification': 'Paintings',
#   'accessionyear': 1963,
#   'accessionmethod': 'Purchase'},
#  {'id': 228227,
#   'title': 'Madonna and Child',
#   'culture': 'Italian',
#   'period': None,
#   'century': '14th century',
#   'medium': 'Tempera and gold on panel',
#   'dimensions': '128.3 × 64.5 cm (50 1/2 × 25 3/8 in.)\r\nframe: 140.5 × 78.5 × 7.5 cm (55 5/16 × 30 7/8 × 2 15/16 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1962,
#   'accessionmethod': 'Gift'},
#  {'id': 228228,
#   'title': 'Portrait of a Man in Armor',
#   'culture': 'Italian',
#   'period': None,
#   'century': '16th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '73.7 x 55.9 cm (29 x 22 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1962,
#   'accessionmethod': 'Gift'},
#  {'id': 228229,
#   'title': 'Virgin and Child',
#   'culture': 'Italian',
#   'period': None,
#   'century': '16th century',
#   'medium': 'Oil on panel',
#   'dimensions': 'sight: 56.8 × 43.8 cm (22 3/8 × 17 1/4 in.)\r\nframed: 71.4 × 57.8 × 8.6 cm (28 1/8 × 22 3/4 × 3 3/8 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1962,
#   'accessionmethod': 'Gift'},
#  {'id': 228230,
#   'title': '29 October 1955',
#   'culture': 'French',
#   'period': None,
#   'century': '20th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '161.9 x 113.6 cm (63 3/4 x 44 3/4 in.)',
#   'description': None,
#   'department': 'Department of Modern & Contemporary Art',
#   'classification': 'Paintings',
#   'accessionyear': 1962,
#   'accessionmethod': 'Gift'},
#  {'id': 228233,
#   'title': 'Christ on the Cross with Saints Margaret (?) Anthony Abbot, an unidentified deacon saint, Francis, Minias, and Dorothea',
#   'culture': 'Italian, Tuscan, Florentine',
#   'period': None,
#   'century': '14th-15th century',
#   'medium': 'Tempera (?) on panel',
#   'dimensions': '35.9 x 66.8 x 10.2 cm (14 1/8 x 26 5/16 x 4 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1962,
#   'accessionmethod': 'Bequest'},
#  {'id': 228234,
#   'title': 'Crucifix',
#   'culture': 'Italian, Tuscan, Florentine',
#   'period': None,
#   'century': '15th century',
#   'medium': 'Tempera on wood panel',
#   'dimensions': '63.3 x 41.7 x 2 cm (24 15/16 x 16 7/16 x 13/16 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1962,
#   'accessionmethod': 'Bequest'},
#  {'id': 228235,
#   'title': 'The Virgin and Child',
#   'culture': 'Italian',
#   'period': None,
#   'century': '13th century',
#   'medium': 'Tempera on panel',
#   'dimensions': '23.81 x 17.46 cm (9 3/8 x 6 7/8 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1962,
#   'accessionmethod': 'Bequest'},
#  {'id': 228236,
#   'title': 'Virgin and Child; Christ Blessing (pinnacle trefoil)',
#   'culture': 'Italian, Tuscan, Florentine',
#   'period': None,
#   'century': '14th century',
#   'medium': 'Tempera on wood panel',
#   'dimensions': '87.8 x 57.1 cm (34 9/16 x 22 1/2 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1962,
#   'accessionmethod': 'Bequest'},
#  {'id': 228237,
#   'title': 'Two Shutters with Four Painted Panels',
#   'culture': 'Byzantine',
#   'period': None,
#   'century': None,
#   'medium': 'Tempera on wood panel',
#   'dimensions': '127.3 x 78.8 x 12.5 cm (50 1/8 x 31 x 4 15/16 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1962,
#   'accessionmethod': 'Bequest'},
#  {'id': 228238,
#   'title': 'Virgin and Child',
#   'culture': 'Italian, Tuscan, Sienese',
#   'period': None,
#   'century': '15th-16th century',
#   'medium': 'Tempera on panel',
#   'dimensions': None,
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1962,
#   'accessionmethod': 'Bequest'},
#  {'id': 228239,
#   'title': 'Neeltje van der Cruysse',
#   'culture': 'Dutch',
#   'period': None,
#   'century': '17th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '84.5 x 66.2 cm (33 1/4 x 26 1/16 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1962,
#   'accessionmethod': 'Gift'},
#  {'id': 228240,
#   'title': 'Saint Cecilia',
#   'culture': 'Italian, Lombard',
#   'period': None,
#   'century': '16th century',
#   'medium': 'Oil on copper',
#   'dimensions': None,
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1962,
#   'accessionmethod': 'Gift'},
#  {'id': 228243,
#   'title': 'Katy',
#   'culture': 'Spanish',
#   'period': None,
#   'century': '20th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '161.93 x 129.86 cm (63 3/4 x 51 1/8 in.)',
#   'description': None,
#   'department': 'Department of Modern & Contemporary Art',
#   'classification': 'Paintings',
#   'accessionyear': 1962,
#   'accessionmethod': 'Gift'},
#  {'id': 228244,
#   'title': 'Christ on the Cross',
#   'culture': 'French',
#   'period': None,
#   'century': '20th century',
#   'medium': 'Oil on canvas',
#   'dimensions': 'sight: 44.77 x 36.35 cm (17 5/8 x 14 5/16 in.)',
#   'description': None,
#   'department': 'Department of Modern & Contemporary Art',
#   'classification': 'Paintings',
#   'accessionyear': 1962,
#   'accessionmethod': 'Gift'},
#  {'id': 228252,
#   'title': 'Alexander Pope (1688-1744)',
#   'culture': 'British',
#   'period': None,
#   'century': '18th century',
#   'medium': 'Oil applied to back of paper mounted on glass',
#   'dimensions': '36.51 x 26.51 cm (14 3/8 x 10 7/16 in.)\r\nframed: 40.32 x 32.54 cm (15 7/8 x 12 13/16 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1962,
#   'accessionmethod': 'Bequest'},
#  {'id': 228256,
#   'title': 'The Virgin Mary',
#   'culture': 'Italian',
#   'period': None,
#   'century': '15th century',
#   'medium': 'Tempera and mixed media on cradled panel',
#   'dimensions': '42 x 33.4 cm (16 9/16 x 13 1/8 in.)\r\nframe: 68.1 x 53.3 x 13.8 cm (26 13/16 x 21 x 5 7/16 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1962,
#   'accessionmethod': 'Gift'},
#  {'id': 228257,
#   'title': 'Bust of a Young Woman',
#   'culture': 'Italian, Venetian',
#   'period': None,
#   'century': '16th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '34.6 x 29.6 cm (13 5/8 x 11 5/8 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1962,
#   'accessionmethod': 'Gift'},
#  {'id': 228258,
#   'title': 'Still Life with Vase of Flowers',
#   'culture': 'Austrian',
#   'period': None,
#   'century': '20th century',
#   'medium': 'Oil on cardboard',
#   'dimensions': '65.1 x 49.2 cm (25 5/8 x 19 3/8 in.)',
#   'description': None,
#   'department': 'Department of Modern & Contemporary Art',
#   'classification': 'Paintings',
#   'accessionyear': 1962,
#   'accessionmethod': 'Gift'},
#  {'id': 228259,
#   'title': "Woman's Head",
#   'culture': 'French',
#   'period': None,
#   'century': '19th-20th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '29.4 x 33 cm (11 9/16 x 13 in.)\r\nframed: 47 x 50.7 x 3 cm (18 1/2 x 19 15/16 x 1 3/16 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1962,
#   'accessionmethod': 'Gift'},
#  {'id': 228261,
#   'title': 'Mrs. Robert Brudenell',
#   'culture': 'British',
#   'period': None,
#   'century': '18th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '75.57 x 63.5 cm (29 3/4 x 25 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1959,
#   'accessionmethod': 'Bequest'},
#  {'id': 228264,
#   'title': 'Saint Mary Magdalene and Saint Margaret',
#   'culture': 'Italian, Venetian',
#   'period': None,
#   'century': '14th century',
#   'medium': 'Tempera on panel',
#   'dimensions': '82.23 x 16.35 cm (32 3/8 x 6 7/16 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1962,
#   'accessionmethod': 'Gift'},
#  {'id': 228266,
#   'title': 'Madonna and Child',
#   'culture': 'Italian',
#   'period': None,
#   'century': '15th century',
#   'medium': 'Tempera on panel',
#   'dimensions': '69.3 x 52.3 cm (27 5/16 x 20 9/16 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1962,
#   'accessionmethod': 'Bequest'},
#  {'id': 228267,
#   'title': 'Processional Cross. Recto: Suffering Christ with Virgin, a Pelican Feeding her Young, and Saint John the Evangelist in the terminals. Verso: Christ Triumphant  with Saint Francis, God, Saint Louis of Toulouse and an Unidentified Saint in the terminals.',
#   'culture': 'Italian, Tuscan, Florentine',
#   'period': None,
#   'century': '15th century',
#   'medium': 'Tempera on wood panel',
#   'dimensions': '53.3 x 33.6 x 2.6 cm (21 x 13 1/4 x 1 in.)\r\nwith base: 59.3 cm (23 3/8 in.)\r\nwith loop for hanging: 55 cm (21 5/8 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1962,
#   'accessionmethod': 'Bequest'},
#  {'id': 228268,
#   'title': 'Virgin and Child with Saints John the Baptist and Anthony Abbot',
#   'culture': 'Italian, Tuscan, Florentine',
#   'period': None,
#   'century': '15th century',
#   'medium': 'Tempera on wood panel',
#   'dimensions': '85.8 x 48 cm (33 3/4 x 18 7/8 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1962,
#   'accessionmethod': 'Bequest'},
#  {'id': 228273,
#   'title': 'Hugh Scott of Arden',
#   'culture': 'British',
#   'period': None,
#   'century': '18th-19th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '76.84 x 64.14 cm (30 1/4 x 25 1/4 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1959,
#   'accessionmethod': 'Bequest'},
#  {'id': 228275,
#   'title': 'Allegorical Figure of a Woman Holding A Circle',
#   'culture': 'Italian, Emilian, Ferrarese',
#   'period': None,
#   'century': '15th-16th century',
#   'medium': 'Oil on panel',
#   'dimensions': '41.9 x 32.2 cm (16 1/2 x 12 11/16 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1962,
#   'accessionmethod': 'Gift'},
#  {'id': 228279,
#   'title': 'The Virgin and Child',
#   'culture': 'Italian, Tuscan, Florentine',
#   'period': None,
#   'century': '15th century',
#   'medium': 'Tempera on panel',
#   'dimensions': '40.32 x 30.8 cm (15 7/8 x 12 1/8 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1962,
#   'accessionmethod': 'Bequest'},
#  {'id': 228280,
#   'title': 'Armed Angel (Principatus)',
#   'culture': 'Italian',
#   'period': None,
#   'century': '14th century',
#   'medium': 'Tempera on panel',
#   'dimensions': '86.7 x 57.3 cm (34 1/8 x 22 9/16 in.)\r\nframe: 96 x 64.6 x 5.6 cm (37 13/16 x 25 7/16 x 2 3/16 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1962,
#   'accessionmethod': 'Bequest'},
#  {'id': 228281,
#   'title': 'Virgin and Child with Saints Jerome and Bernardino and Angels',
#   'culture': 'Italian',
#   'period': None,
#   'century': '15th century',
#   'medium': 'Tempera on panel',
#   'dimensions': 'sight: 64.77 x 42.55 cm (25 1/2 x 16 3/4 in.)\r\nframed: 83.19 x 60.33 x 9.21 cm (32 3/4 x 23 3/4 x 3 5/8 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1962,
#   'accessionmethod': 'Bequest'},
#  {'id': 228282,
#   'title': 'Madonna and Child',
#   'culture': 'Italian',
#   'period': None,
#   'century': '14th-15th century',
#   'medium': 'Tempera transferred from panel to canvas',
#   'dimensions': '83 x 42.7 cm (32 11/16 x 16 13/16 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1962,
#   'accessionmethod': 'Bequest'},
#  {'id': 228283,
#   'title': 'Fragment of an Altarpiece with two standing saints',
#   'culture': 'Spanish, Catalonian',
#   'period': None,
#   'century': None,
#   'medium': 'Tempera on wood panel',
#   'dimensions': '179.2 x 24.7 cm (70 9/16 x 9 3/4 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1962,
#   'accessionmethod': 'Bequest'},
#  {'id': 228284,
#   'title': 'Virgin Nursing the Child with Saint Anthony Abbot',
#   'culture': 'Italian, Venetian',
#   'period': None,
#   'century': '20th century',
#   'medium': 'Oil on panel',
#   'dimensions': None,
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1962,
#   'accessionmethod': 'Bequest'},
#  {'id': 228285,
#   'title': 'Madonna and Child',
#   'culture': 'Dalmatian',
#   'period': None,
#   'century': '15th century',
#   'medium': 'Tempera on panel',
#   'dimensions': '58.8 x 44.5 x 3.9 cm (23 1/8 x 17 1/2 x 1 9/16 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1962,
#   'accessionmethod': 'Bequest'},
#  {'id': 228288,
#   'title': 'Miss Elizabeth Beauclerc as Una with the Lion',
#   'culture': 'British',
#   'period': None,
#   'century': '18th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '76.2 x 63.5 cm (30 x 25 in.)\r\nframed: 104.5 x 91.5 cm (41 1/8 x 36 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1963,
#   'accessionmethod': 'Gift'},
#  {'id': 228289,
#   'title': 'Portrait of a Lady',
#   'culture': 'British',
#   'period': None,
#   'century': '18th-19th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '91.76 x 71.44 cm (36 1/8 x 28 1/8 in.)\r\nframed: 112.4 x 92.08 cm (44 1/4 x 36 1/4 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1963,
#   'accessionmethod': 'Gift'},
#  {'id': 228290,
#   'title': 'Violin and Glass',
#   'culture': 'Spanish',
#   'period': None,
#   'century': '20th century',
#   'medium': 'Oil on canvas',
#   'dimensions': 'sight: 91.44 x 59.69 cm (36 x 23 1/2 in.)',
#   'description': None,
#   'department': 'Department of Modern & Contemporary Art',
#   'classification': 'Paintings',
#   'accessionyear': 1963,
#   'accessionmethod': 'Gift'},
#  {'id': 228291,
#   'title': 'The Virgin and Child Enthroned with Angels',
#   'culture': 'Italian?',
#   'period': None,
#   'century': '19th-20th century',
#   'medium': 'Wood panel',
#   'dimensions': '120 x 60 cm (47 1/4 x 23 5/8 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1963,
#   'accessionmethod': 'Gift'},
#  {'id': 228292,
#   'title': 'Head of a Man',
#   'culture': 'Flemish',
#   'period': None,
#   'century': '16th century',
#   'medium': 'Oil on panel',
#   'dimensions': '14.2 x 12.8 cm (5 9/16 x 5 1/16 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1963,
#   'accessionmethod': 'Gift'},
#  {'id': 228293,
#   'title': 'Head of a Woman',
#   'culture': 'Flemish',
#   'period': None,
#   'century': '16th century',
#   'medium': 'Oil on panel',
#   'dimensions': '14.2 x 12.1 cm (5 9/16 x 4 3/4 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1963,
#   'accessionmethod': 'Gift'},
#  {'id': 228296,
#   'title': 'Crucifixion with the Virgin and Saint John; Above, in spandrel: Virgin of the Annunciation',
#   'culture': 'Italian, Tuscan, Sienese',
#   'period': None,
#   'century': '14th century',
#   'medium': 'Tempera on  panel',
#   'dimensions': '58.74 x 25.72 cm (23 1/8 x 10 1/8 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1965,
#   'accessionmethod': 'Gift'},
#  {'id': 228297,
#   'title': 'Saint Jerome in his Study',
#   'culture': 'Italian',
#   'period': None,
#   'century': '15th century',
#   'medium': 'Tempera and oil on panel',
#   'dimensions': 'sight: 163.4 x 118.2 cm (64 5/16 x 46 9/16 in.)\r\nframe: 184.5 x 136.4 x 12 cm (72 5/8 x 53 11/16 x 4 3/4 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1966,
#   'accessionmethod': 'Gift'},
#  {'id': 228298,
#   'title': 'Portrait of an Apostle (Saint Philip)',
#   'culture': 'Spanish',
#   'period': None,
#   'century': '16th-17th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '62.6 x 50.2 cm (24 5/8 x 19 3/4 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1966,
#   'accessionmethod': 'Bequest'},
#  {'id': 228314,
#   'title': 'The Nativity with the Infant Saint John the Baptist',
#   'culture': 'Italian, Tuscan, Florentine',
#   'period': None,
#   'century': '16th century',
#   'medium': 'Oil on panel',
#   'dimensions': '81.3 x 57.8 cm (32 x 22 3/4 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1962,
#   'accessionmethod': 'Bequest'},
#  {'id': 228315,
#   'title': 'Virgin and Child',
#   'culture': 'Italian',
#   'period': None,
#   'century': '15th century',
#   'medium': 'Oil on panel',
#   'dimensions': '73.03 x 41.28 cm (28 3/4 x 16 1/4 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1962,
#   'accessionmethod': 'Bequest'},
#  {'id': 228316,
#   'title': 'Crucifixion with Saints (Triptych)',
#   'culture': 'Italian',
#   'period': None,
#   'century': '14th century',
#   'medium': 'Oil on cradled panel',
#   'dimensions': '168.7 x 179.3 x 10.2 cm (66 7/16 x 70 9/16 x 4 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1962,
#   'accessionmethod': 'Bequest'},
#  {'id': 228317,
#   'title': 'Two Fragments of an Altarpiece',
#   'culture': 'Spanish',
#   'period': None,
#   'century': '15th-16th century',
#   'medium': 'Oil on panel',
#   'dimensions': '182.5 × 76 × 2.1 cm (71 7/8 × 29 15/16 × 13/16 in.)\r\nlower scene: 88 × 61.7 × 2.1 cm (34 5/8 × 24 5/16 × 13/16 in.)\r\nupper scene: 71 × 61.5 × 2.1 cm (27 15/16 × 24 3/16 × 13/16 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1962,
#   'accessionmethod': 'Bequest'},
#  {'id': 228318,
#   'title': 'Deposition (Icon)',
#   'culture': 'Unidentified culture',
#   'period': None,
#   'century': None,
#   'medium': 'Oil? on panel',
#   'dimensions': '43.2 x 28.6 x 1.5 cm (17 x 11 1/4 x 9/16 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1962,
#   'accessionmethod': 'Bequest'},
#  {'id': 228320,
#   'title': 'Rest on the Flight into Egypt',
#   'culture': 'Dutch',
#   'period': None,
#   'century': '17th century',
#   'medium': 'Oil on copper',
#   'dimensions': '34.1 x 43.9 cm (13 7/16 x 17 5/16 in.)\r\nframe: 50.9 x 60.6 x 4.9 cm (20 1/16 x 23 7/8 x 1 15/16 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1965,
#   'accessionmethod': 'Purchase'},
#  {'id': 228321,
#   'title': 'Saint Jerome in the Desert with Saints John the Baptist and Ansanus',
#   'culture': 'Italian',
#   'period': None,
#   'century': '15th century',
#   'medium': 'Tempera on panel',
#   'dimensions': '159.1 x 189.9 cm (62 5/8 x 74 3/4 in.)\r\nframed: 175 x 204 cm (68 7/8 x 80 5/16 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1963,
#   'accessionmethod': 'Gift'},
#  {'id': 228323,
#   'title': 'Portrait of A Lady',
#   'culture': 'French',
#   'period': None,
#   'century': '17th century',
#   'medium': 'Oil on panel',
#   'dimensions': '24.13 x 34.61 cm (9 1/2 x 13 5/8 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1966,
#   'accessionmethod': 'Gift'},
#  {'id': 228324,
#   'title': 'Portrait of a Young Woman with White Cap',
#   'culture': 'Dutch',
#   'period': None,
#   'century': '17th century',
#   'medium': 'Oil on panel',
#   'dimensions': '66.04 x 56.36 cm (26 x 22 3/16 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1966,
#   'accessionmethod': 'Purchase'},
#  {'id': 228325,
#   'title': 'Wooded Landscape with an Old Oak',
#   'culture': 'Dutch',
#   'period': None,
#   'century': '17th century',
#   'medium': 'Oil on cradled panel',
#   'dimensions': '47.4 x 63.6 cm (18 11/16 x 25 1/16 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1966,
#   'accessionmethod': 'Bequest'},
#  {'id': 228328,
#   'title': 'Descending Light',
#   'culture': 'Hungarian',
#   'period': None,
#   'century': '20th century',
#   'medium': 'Oil and sand on canvas',
#   'dimensions': '182.88 x 121.92 cm (72 x 48 in.)\r\nframed: 186.1 x 125.4 cm (73 1/4 x 49 3/8 in.)',
#   'description': None,
#   'department': 'Department of Modern & Contemporary Art',
#   'classification': 'Paintings',
#   'accessionyear': 1963,
#   'accessionmethod': 'Gift'},
#  {'id': 228330,
#   'title': 'Saint Catherine',
#   'culture': 'Byzantine',
#   'period': None,
#   'century': '15th-16th century',
#   'medium': 'Oil on panel',
#   'dimensions': '26.4 x 21 cm (10 3/8 x 8 1/4 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1962,
#   'accessionmethod': 'Bequest'},
#  {'id': 228331,
#   'title': 'Coronation of the Virgin',
#   'culture': 'Italian',
#   'period': None,
#   'century': '14th century',
#   'medium': 'Tempera on panel',
#   'dimensions': '88.27 x 50.96 x 5.08 cm (34 3/4 x 20 1/16 x 2 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1962,
#   'accessionmethod': 'Bequest'},
#  {'id': 228332,
#   'title': 'Madonna and Child Enthroned',
#   'culture': 'Italian, Marchigian',
#   'period': None,
#   'century': '15th century',
#   'medium': 'Tempera on wood panel',
#   'dimensions': '109.2 x 61.6 cm (43 x 24 1/4 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1965,
#   'accessionmethod': 'Bequest'},
#  {'id': 228333,
#   'title': 'Virgin and Child',
#   'culture': 'Italian, Tuscan, Florentine',
#   'period': None,
#   'century': '15th century',
#   'medium': 'Tempera on panel',
#   'dimensions': None,
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1965,
#   'accessionmethod': 'Bequest'},
#  {'id': 228335,
#   'title': 'Two Figures',
#   'culture': 'French',
#   'period': None,
#   'century': '20th century',
#   'medium': 'Oil on canvas',
#   'dimensions': 'sight: 20 x 27.62 cm (7 7/8 x 10 7/8 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1963,
#   'accessionmethod': 'Gift'},
#  {'id': 228339,
#   'title': 'The Cardinal',
#   'culture': 'Italian',
#   'period': None,
#   'century': '20th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '119.7 x 79.06 cm (47 1/8 x 31 1/8 in.)',
#   'description': None,
#   'department': 'Department of Modern & Contemporary Art',
#   'classification': 'Paintings',
#   'accessionyear': 1966,
#   'accessionmethod': 'Gift'},
#  {'id': 228341,
#   'title': 'Portrait of a Woman, said to be the Marquise de Chauvelin',
#   'culture': 'French',
#   'period': None,
#   'century': '18th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '48.3 x 42.2 cm (19 x 16 5/8 in.)\r\nframed: 66.4 x 60.3 x 9.2 cm (26 1/8 x 23 3/4 x 3 5/8 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1966,
#   'accessionmethod': 'Bequest'},
#  {'id': 228345,
#   'title': 'The Risen Christ Presenting the Redeemed of the Old Dispensation to his Mother',
#   'culture': 'Spanish',
#   'period': None,
#   'century': '16th century',
#   'medium': 'Tempera on panel',
#   'dimensions': '35.88 x 23.81 cm (14 1/8 x 9 3/8 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1965,
#   'accessionmethod': 'Bequest'},
#  {'id': 228346,
#   'title': 'The Virgin and Child',
#   'culture': 'Dalmatian',
#   'period': None,
#   'century': '15th century',
#   'medium': 'Tempera on panel',
#   'dimensions': '28.8 x 21.6 cm (11 5/16 x 8 1/2 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1965,
#   'accessionmethod': 'Bequest'},
#  {'id': 228347,
#   'title': 'Colonel John Lee (1695-1761)',
#   'culture': 'British',
#   'period': None,
#   'century': '18th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '77.5 x 64.6 cm (30 1/2 x 25 7/16 in.)\r\nframed: 94 x 81.3 cm (37 x 32 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1965,
#   'accessionmethod': 'Gift'},
#  {'id': 228348,
#   'title': 'Landscape near Menton',
#   'culture': 'French',
#   'period': None,
#   'century': '19th-20th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '27.62 x 35.88 cm (10 7/8 x 14 1/8 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1963,
#   'accessionmethod': 'Gift'},
#  {'id': 228349,
#   'title': 'Street Scene',
#   'culture': 'French',
#   'period': None,
#   'century': '20th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '49.85 x 64.77 cm (19 5/8 x 25 1/2 in.)',
#   'description': None,
#   'department': 'Department of Modern & Contemporary Art',
#   'classification': 'Paintings',
#   'accessionyear': 1963,
#   'accessionmethod': 'Gift'},
#  {'id': 228353,
#   'title': 'Portrait of an Elderly Man',
#   'culture': 'Spanish',
#   'period': None,
#   'century': '17th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '68 x 51.5 cm (26 3/4 x 20 1/4 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1966,
#   'accessionmethod': 'Bequest'},
#  {'id': 228358,
#   'title': 'Bust of the Virgin',
#   'culture': 'Italian',
#   'period': None,
#   'century': '19th-20th century',
#   'medium': 'Oil on panel',
#   'dimensions': '48.1 x 41.2 x 1.6 cm (18 15/16 x 16 1/4 x 5/8 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1962,
#   'accessionmethod': 'Bequest'},
#  {'id': 228362,
#   'title': 'John Ruskin (1819-1900)',
#   'culture': 'American',
#   'period': None,
#   'century': '19th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '54.6 x 38.1 cm (21 1/2 x 15 in.)\r\nframed: 72.4 x 55.9 x 4.5 cm (28 1/2 x 22 x 1 3/4 in.)',
#   'description': None,
#   'department': 'Department of American Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1965,
#   'accessionmethod': 'Bequest'},
#  {'id': 228364,
#   'title': 'Water Nymph',
#   'culture': 'American',
#   'period': None,
#   'century': '20th century',
#   'medium': 'Oil on cardboard',
#   'dimensions': '102.2 x 77.8 cm (40 1/4 x 30 5/8 in.)\r\nframed: 124.5 x 99.1 x 11.4 cm (49 x 39 x 4 1/2 in.)',
#   'description': None,
#   'department': 'Department of American Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1963,
#   'accessionmethod': 'Gift'},
#  {'id': 228365,
#   'title': 'Interior of Stable with Horses',
#   'culture': 'French',
#   'period': None,
#   'century': '19th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '50.17 x 61.28 cm (19 3/4 x 24 1/8 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1963,
#   'accessionmethod': 'Gift'},
#  {'id': 228366,
#   'title': 'Rue de Rivoli',
#   'culture': 'Norwegian',
#   'period': None,
#   'century': '19th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '81 x 65.1 cm (31 7/8 x 25 5/8 in.)\r\nframed: 95.9 x 80.3 x 3.8 cm (37 3/4 x 31 5/8 x 1 1/2 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1963,
#   'accessionmethod': 'Gift'},
#  {'id': 228367,
#   'title': 'Forest Landscape',
#   'culture': 'French',
#   'period': None,
#   'century': '19th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '48.5 x 32.4 x 4.7 cm (19 1/8 x 12 3/4 x 1 7/8 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1964,
#   'accessionmethod': 'Gift'},
#  {'id': 228368,
#   'title': 'Forest Landscape',
#   'culture': 'French',
#   'period': None,
#   'century': '19th century',
#   'medium': 'Oil on cradled panel',
#   'dimensions': '26.99 x 34.93 cm (10 5/8 x 13 3/4 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1965,
#   'accessionmethod': 'Gift'},
#  {'id': 228369,
#   'title': 'Portrait of a Boy with a Bird',
#   'culture': 'Spanish',
#   'period': None,
#   'century': '18th-19th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '104.14 x 66.99 cm (41 x 26 3/8 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1966,
#   'accessionmethod': 'Bequest'},
#  {'id': 228377,
#   'title': 'The Wedding',
#   'culture': 'Russian',
#   'period': None,
#   'century': '20th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '45.72 x 32.39 cm (18 x 12 3/4 in.)',
#   'description': None,
#   'department': 'Department of Modern & Contemporary Art',
#   'classification': 'Paintings',
#   'accessionyear': 1960,
#   'accessionmethod': 'Gift'},
#  {'id': 228378,
#   'title': 'Landscape (Composition Cubiste)',
#   'culture': 'French',
#   'period': None,
#   'century': '20th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '51.44 x 68.58 cm (20 1/4 x 27 in.)\r\nframed: 75 x 92.7 x 8.5 cm (29 1/2 x 36 1/2 x 3 3/8 in.)',
#   'description': None,
#   'department': 'Department of Modern & Contemporary Art',
#   'classification': 'Paintings',
#   'accessionyear': 1960,
#   'accessionmethod': 'Gift'},
#  {'id': 228379,
#   'title': 'Portrait of a Woman',
#   'culture': 'German',
#   'period': None,
#   'century': '16th century',
#   'medium': 'Oil on panel',
#   'dimensions': '48.2 x 35.5 cm (19 x 14 in.)\r\nframe: 62.6 x 50.5 x 5 cm (24 5/8 x 19 7/8 x 1 15/16 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1960,
#   'accessionmethod': 'Gift'},
#  {'id': 228381,
#   'title': 'Mural, March 20, 1961',
#   'culture': 'Spanish',
#   'period': None,
#   'century': '20th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '114.3 x 365.8 cm (45 x 144 in.)\r\nframed: 115.9 x 367 x 3.2 cm (45 5/8 x 144 1/2 x 1 1/4 in.)',
#   'description': None,
#   'department': 'Department of Modern & Contemporary Art',
#   'classification': 'Paintings',
#   'accessionyear': 1964,
#   'accessionmethod': 'Gift'},
#  {'id': 228384,
#   'title': 'Landscape with Sheep',
#   'culture': 'Italian',
#   'period': None,
#   'century': '17th-18th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '97 x 135 cm (38 3/16 x 53 1/8 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1961,
#   'accessionmethod': 'Gift'},
#  {'id': 228385,
#   'title': 'Saint Jerome in His Study',
#   'culture': 'Netherlandish',
#   'period': None,
#   'century': '16th century',
#   'medium': 'Oil on panel',
#   'dimensions': '99.7 × 83.8 cm (39 1/4 × 33 in.)\r\nframe: 123.8 × 106.7 × 6.4 cm (48 3/4 × 42 × 2 1/2 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1961,
#   'accessionmethod': 'Gift'},
#  {'id': 228394,
#   'title': 'Woman at a Piano',
#   'culture': 'French',
#   'period': None,
#   'century': '18th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '187.4 x 124.6 cm (73 3/4 x 49 1/16 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1960,
#   'accessionmethod': 'Gift'},
#  {'id': 228396,
#   'title': 'The Stigmatization of Saint Francis',
#   'culture': 'Italian, Roman',
#   'period': None,
#   'century': '17th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '108.6 x 132.1 cm (42 3/4 x 52 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1960,
#   'accessionmethod': 'Gift'},
#  {'id': 228397,
#   'title': 'Hagar and the Angel in the Wilderness',
#   'culture': 'Flemish',
#   'period': None,
#   'century': '17th century',
#   'medium': 'Oil on canvas',
#   'dimensions': 'sight: 131.8 x 239 cm (51 7/8 x 94 1/8 in.)\r\nframe: 163 x 269.5 x 13.5 cm (64 3/16 x 106 1/8 x 5 5/16 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1964,
#   'accessionmethod': 'Gift'},
#  {'id': 228399,
#   'title': 'Figure 130',
#   'culture': 'Polish',
#   'period': None,
#   'century': '20th century',
#   'medium': 'Oil and mastic collage on canvas',
#   'dimensions': '60.8 x 38.1 cm (23 15/16 x 15 in.)',
#   'description': None,
#   'department': 'Department of Modern & Contemporary Art',
#   'classification': 'Paintings',
#   'accessionyear': 1964,
#   'accessionmethod': 'Gift'},
#  {'id': 228400,
#   'title': 'Saint Catherine of Alexandria',
#   'culture': 'Italian, Lombard, Bergamasque',
#   'period': None,
#   'century': '16th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '58.74 x 47.31 cm (23 1/8 x 18 5/8 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1961,
#   'accessionmethod': 'Gift'},
#  {'id': 228407,
#   'title': 'Great Black-backed Gull, after Audubon',
#   'culture': 'American',
#   'period': None,
#   'century': '19th century',
#   'medium': 'Oil on wooden door panel',
#   'dimensions': '73.6 x 32.4 cm (29 x 12 3/4 in.)\r\nentire door: 195.6 x 61 x 2.5 cm (77 x 24 x 1 in.)',
#   'description': None,
#   'department': 'Department of American Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1963,
#   'accessionmethod': 'Transfer'},
#  {'id': 228408,
#   'title': 'Hover',
#   'culture': 'American',
#   'period': None,
#   'century': '20th century',
#   'medium': 'Acrylic resin paint (magna) on canvas',
#   'dimensions': '176.9 x 176.9 cm (69 5/8 x 69 5/8 in.)\r\nframed: 180.02 x 179.71 x 3.81 cm (70 7/8 x 70 3/4 x 1 1/2 in.)',
#   'description': None,
#   'department': 'Department of Modern & Contemporary Art',
#   'classification': 'Paintings',
#   'accessionyear': 1964,
#   'accessionmethod': 'Purchase'},
#  {'id': 228410,
#   'title': 'Plaster Cupid',
#   'culture': 'French',
#   'period': None,
#   'century': '19th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '44.5 × 30.8 cm (17 1/2 × 12 1/8 in.)\r\nframed: 61.9 × 48.3 × 7.6 cm (24 3/8 × 19 × 3 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1964,
#   'accessionmethod': 'Gift'},
#  {'id': 228413,
#   'title': 'The Gooseherd',
#   'culture': 'French',
#   'period': None,
#   'century': '19th century',
#   'medium': 'Oil on panel',
#   'dimensions': '32.39 x 24.13 cm (12 3/4 x 9 1/2 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1964,
#   'accessionmethod': 'Purchase'},
#  {'id': 228418,
#   'title': 'Saint Agnes, after Ambrogio Lorenzetti',
#   'culture': 'American',
#   'period': None,
#   'century': '20th century',
#   'medium': 'Tempera on panel',
#   'dimensions': 'sight: 34.3 x 23.2 cm (13 1/2 x 9 1/8 in.)',
#   'description': None,
#   'department': 'Department of American Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1954,
#   'accessionmethod': 'Gift'},
#  {'id': 228423,
#   'title': 'Bridge in a Landscape',
#   'culture': 'French',
#   'period': None,
#   'century': '19th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '73.34 x 54.29 cm (28 7/8 x 21 3/8 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1956,
#   'accessionmethod': 'Gift'},
#  {'id': 228426,
#   'title': 'Mother and Three Children',
#   'culture': 'American?',
#   'period': None,
#   'century': '18th-19th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '146.1 x 116.8 cm (57 1/2 x 46 in.)\r\nframed: 180.3 x 148.6 x 8.9 cm (71 x 58 1/2 x 3 1/2 in.)',
#   'description': None,
#   'department': 'Department of American Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1957,
#   'accessionmethod': 'Transfer'},
#  {'id': 228427,
#   'title': 'Loammi Baldwin, Jr. (1780-1838); verso: Study for Female Head',
#   'culture': 'American',
#   'period': None,
#   'century': '19th century',
#   'medium': 'Oil on composition board',
#   'dimensions': '59.5 x 49.4 cm (23 7/16 x 19 7/16 in.)\r\nframed: 79.4 x 70.5 x 5.7 cm (31 1/4 x 27 3/4 x 2 1/4 in.)',
#   'description': None,
#   'department': 'Department of American Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1955,
#   'accessionmethod': 'Gift'},
#  {'id': 228430,
#   'title': 'Untitled',
#   'culture': 'American',
#   'period': None,
#   'century': '20th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '65.4 x 101.3 cm (25 3/4 x 39 7/8 in.)\r\nframed: 67.3 x 103.5 x 5.1 cm (26 1/2 x 40 3/4 x 2 in.)',
# ...
#   'classification': 'Paintings',
#   'accessionyear': 1936,
#   'accessionmethod': 'Bequest'},
#  {'id': 230971,
#   'title': 'Portrait of a Shirtless Young Man',
#   'culture': 'American',
#   'period': None,
#   'century': '19th-20th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '35.6 x 25.4 cm (14 x 10 in.)',
#   'description': None,
#   'department': 'Department of American Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1936,
#   'accessionmethod': 'Bequest'},
#  {'id': 230972,
#   'title': 'Landscape with Mountain',
#   'culture': 'American',
#   'period': None,
#   'century': '19th-20th century',
#   'medium': 'Oil on canvasboard',
#   'dimensions': '25.4 x 35.6 cm (10 x 14 in.)\r\nframed: 27.9 x 30.2 x 1.3 cm (11 x 11 7/8 x 1/2 in.)',
#   'description': None,
#   'department': 'Department of American Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1936,
#   'accessionmethod': 'Bequest'},
#  {'id': 230973,
#   'title': 'Landscape with Rooftops and Mountains',
#   'culture': 'American',
#   'period': None,
#   'century': '19th-20th century',
#   'medium': 'Oil on canvasboard',
#   'dimensions': '35.6 x 25.4 cm (14 x 10 in.)',
#   'description': None,
#   'department': 'Department of American Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1936,
#   'accessionmethod': 'Bequest'},
#  {'id': 230974,
#   'title': 'Portrait of a Seated Young Man with Mirror',
#   'culture': 'American',
#   'period': None,
#   'century': '19th-20th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '35.9 x 25.7 cm (14 1/8 x 10 1/8 in.)',
#   'description': None,
#   'department': 'Department of American Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1936,
#   'accessionmethod': 'Bequest'},
#  {'id': 230975,
#   'title': 'Half-length Portrait of a Young Man',
#   'culture': 'American',
#   'period': None,
#   'century': '19th-20th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '57.8 x 39.7 cm (22 3/4 x 15 5/8 in.)',
#   'description': None,
#   'department': 'Department of American Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1936,
#   'accessionmethod': 'Bequest'},
#  {'id': 230976,
#   'title': 'View of the Canal, Venice',
#   'culture': 'American',
#   'period': None,
#   'century': '19th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '26 x 33 cm (10 1/4 x 13 in.)',
#   'description': None,
#   'department': 'Department of American Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1936,
#   'accessionmethod': 'Bequest'},
#  {'id': 230977,
#   'title': 'Portrait of David',
#   'culture': 'American',
#   'period': None,
#   'century': '19th-20th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '35.6 x 25.7 cm (14 x 10 1/8 in.)',
#   'description': None,
#   'department': 'Department of American Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1936,
#   'accessionmethod': 'Bequest'},
#  {'id': 230978,
#   'title': 'Portrait of a Young Man in Black Shirt',
#   'culture': 'American',
#   'period': None,
#   'century': '19th-20th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '35.9 x 25.4 cm (14 1/8 x 10 in.)',
#   'description': None,
#   'department': 'Department of American Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1936,
#   'accessionmethod': 'Bequest'},
#  {'id': 230979,
#   'title': 'Landscape with Road and Cottage',
#   'culture': 'American',
#   'period': None,
#   'century': '19th-20th century',
#   'medium': 'Oil on canvasboard',
#   'dimensions': '25.4 x 35.2 cm (10 x 13 7/8 in.)',
#   'description': None,
#   'department': 'Department of American Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1936,
#   'accessionmethod': 'Bequest'},
#  {'id': 230980,
#   'title': 'Louise Nathurst',
#   'culture': 'American',
#   'period': None,
#   'century': '19th century',
#   'medium': 'Oil on canvasboard',
#   'dimensions': '35.2 x 25.1 cm (13 7/8 x 9 7/8 in.)\r\nframed: 38.1 x 27.6 x 1.3 cm (15 x 10 7/8 x 1/2 in.)',
#   'description': 'Louise Nathurst was a cousin of the artist.',
#   'department': 'Department of American Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1936,
#   'accessionmethod': 'Bequest'},
#  {'id': 230981,
#   'title': 'Flowers',
#   'culture': 'American',
#   'period': None,
#   'century': '19th century',
#   'medium': 'Oil on canvasboard',
#   'dimensions': '35.6 x 25.4 cm (14 x 10 in.)',
#   'description': None,
#   'department': 'Department of American Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1936,
#   'accessionmethod': 'Bequest'},
#  {'id': 230995,
#   'title': 'Portrait of a Standing Young Man, Hands Behind Back',
#   'culture': 'American',
#   'period': None,
#   'century': '19th-20th century',
#   'medium': 'Oil on canvasboard',
#   'dimensions': '35.6 x 25.4 cm (14 x 10 in.)',
#   'description': None,
#   'department': 'Department of American Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1936,
#   'accessionmethod': 'Bequest'},
#  {'id': 230996,
#   'title': 'William J. Vincent',
#   'culture': 'American',
#   'period': None,
#   'century': '19th-20th century',
#   'medium': 'Oil on canvasboard',
#   'dimensions': '35.6 x 25.4 cm (14 x 10 in.)',
#   'description': None,
#   'department': 'Department of American Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1936,
#   'accessionmethod': 'Bequest'},
#  {'id': 230997,
#   'title': 'View of Venice',
#   'culture': 'American',
#   'period': None,
#   'century': '19th-20th century',
#   'medium': 'Oil on canvasboard',
#   'dimensions': '35.2 x 26.4 cm (13 7/8 x 10 3/8 in.)',
#   'description': None,
#   'department': 'Department of American Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1936,
#   'accessionmethod': 'Bequest'},
#  {'id': 230998,
#   'title': 'Flowers',
#   'culture': 'American',
#   'period': None,
#   'century': '19th-20th century',
#   'medium': 'Oil on canvasboard',
#   'dimensions': '35.6 x 25.4 cm (14 x 10 in.)\r\nframed: 38.1 x 27.6 x 1.3 cm (15 x 10 7/8 x 1/2 in.)',
#   'description': None,
#   'department': 'Department of American Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1936,
#   'accessionmethod': 'Bequest'},
#  {'id': 230999,
#   'title': "Edgartown, Martha's Vineyard",
#   'culture': 'American',
#   'period': None,
#   'century': '19th-20th century',
#   'medium': 'Oil on canvasboard',
#   'dimensions': '35.6 x 25.4 cm (14 x 10 in.)\r\nframed: 39.4 x 29.2 x 2.5 cm (15 1/2 x 11 1/2 x 1 in.)',
#   'description': None,
#   'department': 'Department of American Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1936,
#   'accessionmethod': 'Bequest'},
#  {'id': 231000,
#   'title': 'Canal Scene with Two Gondolas',
#   'culture': 'American',
#   'period': None,
#   'century': '19th-20th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '43.5 x 35.56 x 2.54 cm (17 1/8 x 14 x 1 in.)',
#   'description': None,
#   'department': 'Department of Modern & Contemporary Art',
#   'classification': 'Paintings',
#   'accessionyear': 1936,
#   'accessionmethod': 'Bequest'},
#  {'id': 231001,
#   'title': 'Maloja Pass above Chiavenna',
#   'culture': 'American',
#   'period': None,
#   'century': '19th century',
#   'medium': 'Oil on canvasboard',
#   'dimensions': '25.1 x 35.2 cm (9 7/8 x 13 7/8 in.)\r\nframed: 29.2 x 38.7 x 1.9 cm (11 1/2 x 15 1/4 x 3/4 in.)',
#   'description': None,
#   'department': 'Department of American Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1936,
#   'accessionmethod': 'Bequest'},
#  {'id': 231002,
#   'title': 'Three Figures in Procession, after Tintoretto',
#   'culture': 'American',
#   'period': None,
#   'century': '19th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '74 x 54.6 x 2.2 cm (29 1/8 x 21 1/2 x 7/8 in.)',
#   'description': None,
#   'department': 'Department of American Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1936,
#   'accessionmethod': 'Bequest'},
#  {'id': 231003,
#   'title': 'Landscape with Trees, after Dodge MacKnight',
#   'culture': 'American',
#   'period': None,
#   'century': '19th-20th century',
#   'medium': 'Oil on canvasboard',
#   'dimensions': '25.4 x 35.2 cm (10 x 13 7/8 in.)',
#   'description': None,
#   'department': 'Department of American Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1936,
#   'accessionmethod': 'Bequest'},
#  {'id': 231004,
#   'title': 'Louise Nathurst',
#   'culture': 'American',
#   'period': None,
#   'century': '19th-20th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '35.2 x 27.3 cm (13 7/8 x 10 3/4 in.)',
#   'description': 'Louise Nathurst was a cousin of the artist.',
#   'department': 'Department of American Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1936,
#   'accessionmethod': 'Bequest'},
#  {'id': 231005,
#   'title': 'Portrait of a Boy with Book on Lap',
#   'culture': 'American',
#   'period': None,
#   'century': '19th-20th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '38.4 x 28.9 cm (15 1/8 x 11 3/8 in.)',
#   'description': None,
#   'department': 'Department of American Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1936,
#   'accessionmethod': 'Bequest'},
#  {'id': 231006,
#   'title': 'Portrait of a Boy in Maroon Sweater',
#   'culture': 'American',
#   'period': None,
#   'century': '19th-20th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '35.6 x 25.4 cm (14 x 10 in.)',
#   'description': None,
#   'department': 'Department of American Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1936,
#   'accessionmethod': 'Bequest'},
#  {'id': 231007,
#   'title': 'Portrait of a Young Man with Hands Behind his Back',
#   'culture': 'American',
#   'period': None,
#   'century': '19th-20th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '92.1 x 68.9 cm (36 1/4 x 27 1/8 in.)',
#   'description': None,
#   'department': 'Department of American Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1936,
#   'accessionmethod': 'Bequest'},
#  {'id': 231008,
#   'title': 'Portrait of a Man',
#   'culture': 'French',
#   'period': None,
#   'century': '19th century',
#   'medium': 'Pastel on canvas',
#   'dimensions': '55.3 x 35.2 cm (21 3/4 x 13 7/8 in.)',
#   'description': None,
#   'department': 'Department of Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1934,
#   'accessionmethod': 'Bequest'},
#  {'id': 231009,
#   'title': 'York Harbor, Maine',
#   'culture': 'American',
#   'period': None,
#   'century': '19th century',
#   'medium': 'Oil on canvasboard',
#   'dimensions': '25.4 x 35.2 cm (10 x 13 7/8 in.)\r\nframed: 27.9 x 38.1 x 1.3 cm (11 x 15 x 1/2 in.)',
#   'description': None,
#   'department': 'Department of American Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1936,
#   'accessionmethod': 'Bequest'},
#  {'id': 231010,
#   'title': 'Louise Nathurst',
#   'culture': 'American',
#   'period': None,
#   'century': '19th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '39.1 x 29.2 cm (15 3/8 x 11 1/2 in.)',
#   'description': 'Louise Nathurst was a cousin of the artist.',
#   'department': 'Department of American Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1936,
#   'accessionmethod': 'Bequest'},
#  {'id': 231011,
#   'title': 'Portrait of a Young Man with Black Jacket',
#   'culture': 'American',
#   'period': None,
#   'century': '19th-20th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '40 x 30.2 cm (15 3/4 x 11 7/8 in.)',
#   'description': None,
#   'department': 'Department of American Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1936,
#   'accessionmethod': 'Bequest'},
#  {'id': 231012,
#   'title': 'Portrait of a Young Boy with Red Hair',
#   'culture': 'American',
#   'period': None,
#   'century': '19th-20th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '35.6 x 25.4 cm (14 x 10 in.)',
#   'description': None,
#   'department': 'Department of American Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1936,
#   'accessionmethod': 'Bequest'},
#  {'id': 231013,
#   'title': 'Count-Duke of Olivares on Horseback, after Velazquez',
#   'culture': 'American',
#   'period': None,
#   'century': '19th-20th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '95.9 x 71.8 cm (37 3/4 x 28 1/4 in.)',
#   'description': "Copy after Velazquez's original at the Prado, Madrid, dated c. 1638.",
#   'department': 'Department of American Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1936,
#   'accessionmethod': 'Bequest'},
#  {'id': 231014,
#   'title': 'Portrait of a Young Man',
#   'culture': 'American',
#   'period': None,
#   'century': '19th-20th century',
#   'medium': 'Oil on canvasboard',
#   'dimensions': '34.9 x 26.7 cm (13 3/4 x 10 1/2 in.)',
#   'description': None,
#   'department': 'Department of American Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1936,
#   'accessionmethod': 'Bequest'},
#  {'id': 231015,
#   'title': 'Portrait of a Young Man with Hand at Chin',
#   'culture': 'American',
#   'period': None,
#   'century': '19th-20th century',
#   'medium': 'Oil on canvasboard',
#   'dimensions': '34.9 x 26.7 cm (13 3/4 x 10 1/2 in.)',
#   'description': None,
#   'department': 'Department of American Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1936,
#   'accessionmethod': 'Bequest'},
#  {'id': 231016,
#   'title': 'Orizaba, Mexico',
#   'culture': 'American',
#   'period': None,
#   'century': '19th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '38.1 x 28.3 cm (15 x 11 1/8 in.)',
#   'description': None,
#   'department': 'Department of American Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1936,
#   'accessionmethod': 'Bequest'},
#  {'id': 231017,
#   'title': 'Portrait of a Boy Holding a Book',
#   'culture': 'American',
#   'period': None,
#   'century': '19th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '35.6 x 25.4 cm (14 x 10 in.)',
#   'description': None,
#   'department': 'Department of American Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1936,
#   'accessionmethod': 'Bequest'},
#  {'id': 231018,
#   'title': 'Profile Portrait of a Boy in Suit and Tie',
#   'culture': 'American',
#   'period': None,
#   'century': '19th-20th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '35.9 x 25.1 cm (14 1/8 x 9 7/8 in.)',
#   'description': None,
#   'department': 'Department of American Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1936,
#   'accessionmethod': 'Bequest'},
#  {'id': 231019,
#   'title': 'Portrait of a Boy in Suit and Tie',
#   'culture': 'American',
#   'period': None,
#   'century': '19th-20th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '35.6 x 25.4 cm (14 x 10 in.)',
#   'description': None,
#   'department': 'Department of American Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1936,
#   'accessionmethod': 'Bequest'},
#  {'id': 231020,
#   'title': 'Portrait of a Young Boy in a Brown Suit',
#   'culture': 'American',
#   'period': None,
#   'century': '19th-20th century',
#   'medium': 'Oil on canvas',
#   'dimensions': '35.6 x 26.4 cm (14 x 10 3/8 in.)',
#   'description': None,
#   'department': 'Department of American Paintings, Sculpture & Decorative Arts',
#   'classification': 'Paintings',
#   'accessionyear': 1936,
#   'accessionmethod': 'Bequest'},
#  ...]

# %%
artifact_media
# Out:
# [{'objectid': 228185,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 83344,
#   'datebegin': 1884,
#   'dateend': 1894},
#  {'objectid': 228189,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 83354,
#   'datebegin': 1829,
#   'dateend': 1829},
#  {'objectid': 228190,
#   'imagecount': 0,
#   'mediacount': 0,
#   'colorcount': 0,
#   'rank_value': 85666,
#   'datebegin': 1925,
#   'dateend': 1935},
#  {'objectid': 228194,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 86001,
#   'datebegin': 1853,
#   'dateend': 1853},
#  {'objectid': 228199,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 82964,
#   'datebegin': 1780,
#   'dateend': 1790},
#  {'objectid': 228201,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 82766,
#   'datebegin': 1846,
#   'dateend': 1846},
#  {'objectid': 228202,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank_value': 83345,
#   'datebegin': 1889,
#   'dateend': 1889},
#  {'objectid': 228203,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 85584,
#   'datebegin': 1900,
#   'dateend': 1900},
#  {'objectid': 228204,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 83358,
#   'datebegin': 1905,
#   'dateend': 1915},
#  {'objectid': 228206,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 83388,
#   'datebegin': 1952,
#   'dateend': 1952},
#  {'objectid': 228209,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank_value': 85651,
#   'datebegin': 1940,
#   'dateend': 1940},
#  {'objectid': 228210,
#   'imagecount': 0,
#   'mediacount': 0,
#   'colorcount': 0,
#   'rank_value': 85682,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228213,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 82813,
#   'datebegin': 1675,
#   'dateend': 1685},
#  {'objectid': 228214,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank_value': 85495,
#   'datebegin': 1825,
#   'dateend': 1835},
#  {'objectid': 228218,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 83390,
#   'datebegin': 1956,
#   'dateend': 1956},
#  {'objectid': 228219,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 85631,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228220,
#   'imagecount': 0,
#   'mediacount': 0,
#   'colorcount': 0,
#   'rank_value': 85686,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228222,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 86052,
#   'datebegin': 1961,
#   'dateend': 1961},
#  {'objectid': 228227,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 85600,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228228,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 85601,
#   'datebegin': 1510,
#   'dateend': 1520},
#  {'objectid': 228229,
#   'imagecount': 3,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank_value': 85603,
#   'datebegin': 1515,
#   'dateend': 1525},
#  {'objectid': 228230,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 85622,
#   'datebegin': 1955,
#   'dateend': 1955},
#  {'objectid': 228233,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank_value': 85781,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228234,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank_value': 85783,
#   'datebegin': 1400,
#   'dateend': 1425},
#  {'objectid': 228235,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 85785,
#   'datebegin': 1290,
#   'dateend': 1300},
#  {'objectid': 228236,
#   'imagecount': 3,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 85791,
#   'datebegin': 1375,
#   'dateend': 1385},
#  {'objectid': 228237,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 85794,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228238,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 85800,
#   'datebegin': 1485,
#   'dateend': 1495},
#  {'objectid': 228239,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 85592,
#   'datebegin': 1669,
#   'dateend': 1670},
#  {'objectid': 228240,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 85597,
#   'datebegin': 1567,
#   'dateend': 1599},
#  {'objectid': 228243,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank_value': 85648,
#   'datebegin': 1959,
#   'dateend': 1959},
#  {'objectid': 228244,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 85654,
#   'datebegin': 1943,
#   'dateend': 1953},
#  {'objectid': 228252,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank_value': 85849,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228256,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 85602,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228257,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 85605,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228258,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 85629,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228259,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 85667,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228261,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank_value': 83526,
#   'datebegin': 1760,
#   'dateend': 1760},
#  {'objectid': 228264,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank_value': 85844,
#   'datebegin': 1370,
#   'dateend': 1380},
#  {'objectid': 228266,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 85779,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228267,
#   'imagecount': 14,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank_value': 85784,
#   'datebegin': 1430,
#   'dateend': 1470},
#  {'objectid': 228268,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 85792,
#   'datebegin': 1400,
#   'dateend': 1425},
#  {'objectid': 228273,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 83528,
#   'datebegin': 1783,
#   'dateend': 1793},
#  {'objectid': 228275,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank_value': 85845,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228279,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 85780,
#   'datebegin': 1425,
#   'dateend': 1435},
#  {'objectid': 228280,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank_value': 85782,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228281,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 85787,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228282,
#   'imagecount': 4,
#   'mediacount': 0,
#   'colorcount': 0,
#   'rank_value': 85790,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228283,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 85796,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228284,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank_value': 85806,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228285,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 85804,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228288,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank_value': 86055,
#   'datebegin': 1777,
#   'dateend': 1777},
#  {'objectid': 228289,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 86056,
#   'datebegin': 1795,
#   'dateend': 1805},
#  {'objectid': 228290,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 86063,
#   'datebegin': 1915,
#   'dateend': 1915},
#  {'objectid': 228291,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank_value': 86074,
#   'datebegin': 1875,
#   'dateend': 1925},
#  {'objectid': 228292,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank_value': 86147,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228293,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank_value': 86149,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228296,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 87521,
#   'datebegin': 1395,
#   'dateend': 1405},
#  {'objectid': 228297,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 87552,
#   'datebegin': 1482,
#   'dateend': 1482},
#  {'objectid': 228298,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank_value': 87581,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228314,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 85793,
#   'datebegin': 1500,
#   'dateend': 1532},
#  {'objectid': 228315,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 85795,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228316,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 85797,
#   'datebegin': 1350,
#   'dateend': 1362},
#  {'objectid': 228317,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank_value': 85802,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228318,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 85803,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228320,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 87478,
#   'datebegin': 1630,
#   'dateend': 1640},
#  {'objectid': 228321,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 86057,
#   'datebegin': 1450,
#   'dateend': 1460},
#  {'objectid': 228323,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank_value': 87553,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228324,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 87574,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228325,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 87582,
#   'datebegin': 1650,
#   'dateend': 1653},
#  {'objectid': 228328,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 85886,
#   'datebegin': 1960,
#   'dateend': 1960},
#  {'objectid': 228330,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank_value': 85799,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228331,
#   'imagecount': 3,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 85807,
#   'datebegin': 1350,
#   'dateend': 1375},
#  {'objectid': 228332,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank_value': 87027,
#   'datebegin': 1485,
#   'dateend': 1495},
#  {'objectid': 228333,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 87410,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228335,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 86072,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228339,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 87550,
#   'datebegin': 1957,
#   'dateend': 1957},
#  {'objectid': 228341,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 87599,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228345,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 87028,
#   'datebegin': 1301,
#   'dateend': 1425},
#  {'objectid': 228346,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 87411,
#   'datebegin': 1430,
#   'dateend': 1440},
#  {'objectid': 228347,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 87500,
#   'datebegin': 1744,
#   'dateend': 1744},
#  {'objectid': 228348,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 86073,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228349,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 86153,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228353,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank_value': 87580,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228358,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank_value': 85805,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228362,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank_value': 87398,
#   'datebegin': 1871,
#   'dateend': 1881},
#  {'objectid': 228364,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 86069,
#   'datebegin': 1919,
#   'dateend': 1919},
#  {'objectid': 228365,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank_value': 86075,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228366,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank_value': 86152,
#   'datebegin': 1891,
#   'dateend': 1891},
#  {'objectid': 228367,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 86434,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228368,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 87522,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228369,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 87600,
#   'datebegin': 1795,
#   'dateend': 1805},
#  {'objectid': 228377,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 85079,
#   'datebegin': 1945,
#   'dateend': 1955},
#  {'objectid': 228378,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 85084,
#   'datebegin': 1912,
#   'dateend': 1912},
#  {'objectid': 228379,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 85091,
#   'datebegin': 1535,
#   'dateend': 1540},
#  {'objectid': 228381,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 86461,
#   'datebegin': 1961,
#   'dateend': 1961},
#  {'objectid': 228384,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 85137,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228385,
#   'imagecount': 3,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 453,
#   'datebegin': 1521,
#   'dateend': 1521},
#  {'objectid': 228394,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 85095,
#   'datebegin': 1790,
#   'dateend': 1800},
#  {'objectid': 228396,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 85122,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228397,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 86513,
#   'datebegin': 1660,
#   'dateend': 1660},
#  {'objectid': 228399,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank_value': 86640,
#   'datebegin': 1962,
#   'dateend': 1962},
#  {'objectid': 228400,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 85138,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228407,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 86193,
#   'datebegin': 1853,
#   'dateend': 1853},
#  {'objectid': 228408,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank_value': 86444,
#   'datebegin': 1963,
#   'dateend': 1963},
#  {'objectid': 228410,
#   'imagecount': 3,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank_value': 86518,
#   'datebegin': 1894,
#   'dateend': 1895},
#  {'objectid': 228413,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 86533,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228418,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 82064,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228423,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank_value': 82524,
#   'datebegin': 1868,
#   'dateend': 1878},
#  {'objectid': 228426,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 82863,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228427,
#   'imagecount': 3,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank_value': 82376,
#   'datebegin': 1823,
#   'dateend': 1823},
#  {'objectid': 228430,
#   'imagecount': 0,
#   'mediacount': 0,
#   'colorcount': 0,
#   'rank_value': 84037,
#   'datebegin': 1955,
#   'dateend': 1955},
#  {'objectid': 228437,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 82467,
#   'datebegin': 1350,
#   'dateend': 1399},
#  {'objectid': 228438,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 83596,
#   'datebegin': 1570,
#   'dateend': 1579},
#  {'objectid': 228439,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 83597,
#   'datebegin': 1875,
#   'dateend': 1925},
#  {'objectid': 228440,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank_value': 83621,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228441,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 84044,
#   'datebegin': 1953,
#   'dateend': 1953},
#  {'objectid': 228442,
#   'imagecount': 0,
#   'mediacount': 0,
#   'colorcount': 0,
#   'rank_value': 84053,
#   'datebegin': 1959,
#   'dateend': 1959},
#  {'objectid': 228445,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 82883,
#   'datebegin': 1625,
#   'dateend': 1650},
#  {'objectid': 228449,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 82978,
#   'datebegin': 1764,
#   'dateend': 1765},
#  {'objectid': 228453,
#   'imagecount': 4,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 154040,
#   'datebegin': 1765,
#   'dateend': 1790},
#  {'objectid': 228454,
#   'imagecount': 4,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 154035,
#   'datebegin': 1765,
#   'dateend': 1790},
#  {'objectid': 228460,
#   'imagecount': 4,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 54474,
#   'datebegin': 1355,
#   'dateend': 1365},
#  {'objectid': 228467,
#   'imagecount': 6,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 49826,
#   'datebegin': 1445,
#   'dateend': 1455},
#  {'objectid': 228468,
#   'imagecount': 6,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 50957,
#   'datebegin': 1334,
#   'dateend': 1334},
#  {'objectid': 228469,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank_value': 55664,
#   'datebegin': 1500,
#   'dateend': 1510},
#  {'objectid': 228470,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 55672,
#   'datebegin': 1485,
#   'dateend': 1490},
#  {'objectid': 228471,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 64516,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228483,
#   'imagecount': 3,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 83644,
#   'datebegin': 1950,
#   'dateend': 1950},
#  {'objectid': 228487,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 82557,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228488,
#   'imagecount': 5,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank_value': 82914,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228491,
#   'imagecount': 0,
#   'mediacount': 0,
#   'colorcount': 0,
#   'rank_value': 82632,
#   'datebegin': 1927,
#   'dateend': 1927},
#  {'objectid': 228493,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank_value': 82686,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228497,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 83005,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228498,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 83018,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228499,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 83076,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228500,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 83323,
#   'datebegin': 1957,
#   'dateend': 1957},
#  {'objectid': 228501,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 83325,
#   'datebegin': 1954,
#   'dateend': 1954},
#  {'objectid': 228502,
#   'imagecount': 3,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 83328,
#   'datebegin': 1601,
#   'dateend': 1602},
#  {'objectid': 228507,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 82902,
#   'datebegin': 1863,
#   'dateend': 1873},
#  {'objectid': 228509,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank_value': 82966,
#   'datebegin': 1782,
#   'dateend': 1794},
#  {'objectid': 228512,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank_value': 82667,
#   'datebegin': 1844,
#   'dateend': 1845},
#  {'objectid': 228517,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 81949,
#   'datebegin': 1625,
#   'dateend': 1635},
#  {'objectid': 228518,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 81967,
#   'datebegin': 1689,
#   'dateend': 1689},
#  {'objectid': 228521,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 72891,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228527,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank_value': 82063,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228531,
#   'imagecount': 0,
#   'mediacount': 0,
#   'colorcount': 0,
#   'rank_value': 82381,
#   'datebegin': 1904,
#   'dateend': 1906},
#  {'objectid': 228533,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 82108,
#   'datebegin': 1884,
#   'dateend': 1884},
#  {'objectid': 228534,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 82148,
#   'datebegin': 1940,
#   'dateend': 1950},
#  {'objectid': 228536,
#   'imagecount': 3,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 82456,
#   'datebegin': 1883,
#   'dateend': 1893},
#  {'objectid': 228537,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 82463,
#   'datebegin': 1820,
#   'dateend': 1820},
#  {'objectid': 228545,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 82404,
#   'datebegin': 1375,
#   'dateend': 1399},
#  {'objectid': 228546,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 82441,
#   'datebegin': 1930,
#   'dateend': 1930},
#  {'objectid': 228548,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 83571,
#   'datebegin': 1370,
#   'dateend': 1375},
#  {'objectid': 228549,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 83636,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228551,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 84043,
#   'datebegin': 1959,
#   'dateend': 1959},
#  {'objectid': 228556,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 82938,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228558,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 82710,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228567,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 82649,
#   'datebegin': 1800,
#   'dateend': 1850},
#  {'objectid': 228568,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank_value': 47,
#   'datebegin': 1811,
#   'dateend': 1821},
#  {'objectid': 228577,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 83353,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228579,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 83405,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228580,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 83407,
#   'datebegin': 1500,
#   'dateend': 1520},
#  {'objectid': 228586,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank_value': 82779,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228587,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 83318,
#   'datebegin': 1956,
#   'dateend': 1956},
#  {'objectid': 228588,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 83319,
#   'datebegin': 1955,
#   'dateend': 1955},
#  {'objectid': 228589,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 83322,
#   'datebegin': 1957,
#   'dateend': 1957},
#  {'objectid': 228590,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 83336,
#   'datebegin': 1468,
#   'dateend': 1470},
#  {'objectid': 228593,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 85591,
#   'datebegin': 1675,
#   'dateend': 1675},
#  {'objectid': 228594,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 83406,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228604,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 82986,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228606,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank_value': 83014,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228607,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 83038,
#   'datebegin': 1615,
#   'dateend': 1618},
#  {'objectid': 228608,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 83156,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228610,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 83349,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228612,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 85504,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228614,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 82761,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228615,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 82762,
#   'datebegin': 1690,
#   'dateend': 1700},
#  {'objectid': 228616,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 82781,
#   'datebegin': 1585,
#   'dateend': 1595},
#  {'objectid': 228617,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 83017,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228621,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 83348,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228622,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 83352,
#   'datebegin': 1943,
#   'dateend': 1943},
#  {'objectid': 228627,
#   'imagecount': 3,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank_value': 85585,
#   'datebegin': 1500,
#   'dateend': 1532},
#  {'objectid': 228633,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 85590,
#   'datebegin': 1675,
#   'dateend': 1675},
#  {'objectid': 228634,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 83370,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228635,
#   'imagecount': 0,
#   'mediacount': 0,
#   'colorcount': 0,
#   'rank_value': 83386,
#   'datebegin': 1957,
#   'dateend': 1957},
#  {'objectid': 228639,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 85606,
#   'datebegin': 1635,
#   'dateend': 1645},
#  {'objectid': 228641,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 85630,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228644,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 82745,
#   'datebegin': 1897,
#   'dateend': 1897},
#  {'objectid': 228645,
#   'imagecount': 0,
#   'mediacount': 0,
#   'colorcount': 0,
#   'rank_value': 82763,
#   'datebegin': 1910,
#   'dateend': 1920},
#  {'objectid': 228647,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 83074,
#   'datebegin': 1956,
#   'dateend': 1956},
#  {'objectid': 228648,
#   'imagecount': 4,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 81077,
#   'datebegin': 1929,
#   'dateend': 1929},
#  {'objectid': 228649,
#   'imagecount': 3,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank_value': 81082,
#   'datebegin': 1877,
#   'dateend': 1877},
#  {'objectid': 228650,
#   'imagecount': 4,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 81083,
#   'datebegin': 1875,
#   'dateend': 1875},
#  {'objectid': 228651,
#   'imagecount': 4,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 81088,
#   'datebegin': 1883,
#   'dateend': 1884},
#  {'objectid': 228652,
#   'imagecount': 3,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 81098,
#   'datebegin': 1873,
#   'dateend': 1883},
#  {'objectid': 228653,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank_value': 72872,
#   'datebegin': 1911,
#   'dateend': 1911},
#  {'objectid': 228662,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank_value': 81210,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228695,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank_value': 81473,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228697,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 81905,
#   'datebegin': 1873,
#   'dateend': 1883},
#  {'objectid': 228700,
#   'imagecount': 0,
#   'mediacount': 0,
#   'colorcount': 0,
#   'rank_value': 81547,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228704,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 82248,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228709,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 81467,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228710,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank_value': 81475,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228715,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 82006,
#   'datebegin': 1824,
#   'dateend': 1824},
#  {'objectid': 228716,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank_value': 72926,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228717,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 72955,
#   'datebegin': 1929,
#   'dateend': 1929},
#  {'objectid': 228718,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 72960,
#   'datebegin': 1945,
#   'dateend': 1945},
#  {'objectid': 228719,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 73215,
#   'datebegin': 1815,
#   'dateend': 1825},
#  {'objectid': 228720,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 82057,
#   'datebegin': 1877,
#   'dateend': 1877},
#  {'objectid': 228721,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 82111,
#   'datebegin': 1817,
#   'dateend': 1817},
#  {'objectid': 228729,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 81211,
#   'datebegin': 1520,
#   'dateend': 1530},
#  {'objectid': 228736,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank_value': 82374,
#   'datebegin': 1525,
#   'dateend': 1535},
#  {'objectid': 228737,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 81996,
#   'datebegin': 1941,
#   'dateend': 1951},
#  {'objectid': 228738,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank_value': 72893,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228739,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank_value': 81052,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228740,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 81053,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228742,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank_value': 72869,
#   'datebegin': 1862,
#   'dateend': 1872},
#  {'objectid': 228744,
#   'imagecount': 4,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank_value': 81096,
#   'datebegin': 1886,
#   'dateend': 1887},
#  {'objectid': 228747,
#   'imagecount': 4,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 81506,
#   'datebegin': 1898,
#   'dateend': 1901},
#  {'objectid': 228748,
#   'imagecount': 3,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 82236,
#   'datebegin': 1882,
#   'dateend': 1882},
#  {'objectid': 228755,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank_value': 81213,
#   'datebegin': 1407,
#   'dateend': 1417},
#  {'objectid': 228761,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 81851,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228767,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 81530,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228773,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 82007,
#   'datebegin': 1824,
#   'dateend': 1824},
#  {'objectid': 228774,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 82044,
#   'datebegin': 1865,
#   'dateend': 1875},
#  {'objectid': 228775,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 72885,
#   'datebegin': 1848,
#   'dateend': 1858},
#  {'objectid': 228776,
#   'imagecount': 3,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 72887,
#   'datebegin': 1795,
#   'dateend': 1805},
#  {'objectid': 228778,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 72892,
#   'datebegin': 1945,
#   'dateend': 1947},
#  {'objectid': 228781,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank_value': 73217,
#   'datebegin': 1950,
#   'dateend': 1950},
#  {'objectid': 228782,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 81484,
#   'datebegin': 1400,
#   'dateend': 1499},
#  {'objectid': 228795,
#   'imagecount': 8,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 72954,
#   'datebegin': 1485,
#   'dateend': 1495},
#  {'objectid': 228810,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 81954,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228817,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 82161,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228822,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 82379,
#   'datebegin': 1927,
#   'dateend': 1927},
#  {'objectid': 228823,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 82390,
#   'datebegin': 1500,
#   'dateend': 1530},
#  {'objectid': 228824,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 82391,
#   'datebegin': 1500,
#   'dateend': 1530},
#  {'objectid': 228825,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 81099,
#   'datebegin': 1923,
#   'dateend': 1923},
#  {'objectid': 228828,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank_value': 81219,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228829,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 81301,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228830,
#   'imagecount': 3,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 81302,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228833,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 3,
#   'rank_value': 81906,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228839,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 81474,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228840,
#   'imagecount': 0,
#   'mediacount': 0,
#   'colorcount': 0,
#   'rank_value': 81478,
#   'datebegin': 1320,
#   'dateend': 1330},
#  {'objectid': 228841,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank_value': 81739,
#   'datebegin': 1784,
#   'dateend': 1794},
#  {'objectid': 228844,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 81849,
#   'datebegin': 1675,
#   'dateend': 1725},
#  {'objectid': 228849,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 81531,
#   'datebegin': 1668,
#   'dateend': 1668},
#  {'objectid': 228851,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 82373,
#   'datebegin': 1546,
#   'dateend': 1546},
#  {'objectid': 228852,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 81912,
#   'datebegin': 1901,
#   'dateend': 1901},
#  {'objectid': 228853,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 81919,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228858,
#   'imagecount': 3,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 72886,
#   'datebegin': 1796,
#   'dateend': 1806},
#  {'objectid': 228859,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 72956,
#   'datebegin': 1931,
#   'dateend': 1931},
#  {'objectid': 228860,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank_value': 72957,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228861,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 72963,
#   'datebegin': 1942,
#   'dateend': 1942},
#  {'objectid': 228862,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 72964,
#   'datebegin': 1946,
#   'dateend': 1948},
#  {'objectid': 228865,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 73216,
#   'datebegin': 1815,
#   'dateend': 1825},
#  {'objectid': 228866,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 82841,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228867,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 82377,
#   'datebegin': 1647,
#   'dateend': 1662},
#  {'objectid': 228870,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 83635,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228871,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 83645,
#   'datebegin': 1948,
#   'dateend': 1948},
#  {'objectid': 228872,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 83650,
#   'datebegin': 1470,
#   'dateend': 1480},
#  {'objectid': 228873,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 84046,
#   'datebegin': 1953,
#   'dateend': 1953},
#  {'objectid': 228876,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank_value': 82864,
#   'datebegin': 15,
#   'dateend': 16},
#  {'objectid': 228877,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank_value': 82885,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228878,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank_value': 82918,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228879,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 82939,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228896,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 81039,
#   'datebegin': 1700,
#   'dateend': 1750},
#  {'objectid': 228897,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 81041,
#   'datebegin': 1830,
#   'dateend': 1850},
#  {'objectid': 228898,
#   'imagecount': 6,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank_value': 65775,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228906,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 55502,
#   'datebegin': 1826,
#   'dateend': 1826},
#  {'objectid': 228907,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 55654,
#   'datebegin': 1767,
#   'dateend': 1799},
#  {'objectid': 228911,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 72284,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228916,
#   'imagecount': 8,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 73360,
#   'datebegin': 1395,
#   'dateend': 1405},
#  {'objectid': 228918,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 81046,
#   'datebegin': 1567,
#   'dateend': 1599},
#  {'objectid': 228919,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 81048,
#   'datebegin': 1600,
#   'dateend': 1650},
#  {'objectid': 228920,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 81051,
#   'datebegin': 1850,
#   'dateend': 1899},
#  {'objectid': 228921,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 81056,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228928,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 81040,
#   'datebegin': 1350,
#   'dateend': 1400},
#  {'objectid': 228930,
#   'imagecount': 5,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank_value': 52656,
#   'datebegin': 1470,
#   'dateend': 1480},
#  {'objectid': 228934,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 81042,
#   'datebegin': 1460,
#   'dateend': 1470},
#  {'objectid': 228942,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 73412,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 228943,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank_value': 73414,
#   'datebegin': 1485,
#   'dateend': 1495},
#  {'objectid': 228952,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 72570,
#   'datebegin': 1948,
#   'dateend': 1948},
#  {'objectid': 228953,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 72595,
#   'datebegin': 1823,
#   'dateend': 1833},
#  {'objectid': 228962,
#   'imagecount': 0,
#   'mediacount': 0,
#   'colorcount': 0,
#   'rank_value': 73391,
#   'datebegin': 1933,
#   'dateend': 1933},
#  {'objectid': 228963,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 72867,
#   'datebegin': 1894,
#   'dateend': 1894},
#  {'objectid': 228990,
#   'imagecount': 3,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank_value': 72345,
#   'datebegin': 1923,
#   'dateend': 1923},
#  {'objectid': 228991,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 72360,
#   'datebegin': 1840,
#   'dateend': 1849},
#  {'objectid': 228997,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank_value': 72599,
#   'datebegin': 1945,
#   'dateend': 1945},
#  {'objectid': 228998,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 72613,
#   'datebegin': 1796,
#   'dateend': 1796},
#  {'objectid': 229003,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank_value': 62422,
#   'datebegin': 1901,
#   'dateend': 1901},
#  {'objectid': 229004,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank_value': 62454,
#   'datebegin': 1932,
#   'dateend': 1932},
#  {'objectid': 229005,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 72342,
#   'datebegin': 1896,
#   'dateend': 1906},
#  {'objectid': 229019,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 72572,
#   'datebegin': 1947,
#   'dateend': 1947},
#  {'objectid': 229027,
#   'imagecount': 0,
#   'mediacount': 0,
#   'colorcount': 0,
#   'rank_value': 81057,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 229043,
#   'imagecount': 3,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank_value': 81078,
#   'datebegin': 1896,
#   'dateend': 1896},
#  {'objectid': 229044,
#   'imagecount': 3,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 81080,
#   'datebegin': 1916,
#   'dateend': 1916},
#  {'objectid': 229045,
#   'imagecount': 4,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 81081,
#   'datebegin': 1910,
#   'dateend': 1910},
#  {'objectid': 229046,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 81084,
#   'datebegin': 1901,
#   'dateend': 1901},
#  {'objectid': 229047,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 81085,
#   'datebegin': 1901,
#   'dateend': 1901},
#  {'objectid': 229048,
#   'imagecount': 3,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank_value': 81089,
#   'datebegin': 1908,
#   'dateend': 1908},
#  {'objectid': 229049,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 424,
#   'datebegin': 1884,
#   'dateend': 1885},
#  {'objectid': 229052,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 81190,
#   'datebegin': 1939,
#   'dateend': 1939},
#  {'objectid': 229054,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 81466,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 229056,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 1,
#   'rank_value': 72876,
#   'datebegin': 1869,
#   'dateend': 1869},
#  {'objectid': 229058,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 81600,
#   'datebegin': 1859,
#   'dateend': 1859},
#  {'objectid': 229059,
#   'imagecount': 3,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 81087,
#   'datebegin': 1897,
#   'dateend': 1897},
#  {'objectid': 229060,
#   'imagecount': 5,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank_value': 81093,
#   'datebegin': 1887,
#   'dateend': 1889},
#  {'objectid': 229061,
#   'imagecount': 3,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 81094,
#   'datebegin': 1881,
#   'dateend': 1881},
#  {'objectid': 229065,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank_value': 81746,
#   'datebegin': 1874,
#   'dateend': 1874},
#  {'objectid': 229073,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 68848,
#   'datebegin': 1773,
#   'dateend': 1783},
#  {'objectid': 229079,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 64519,
#   'datebegin': 1770,
#   'dateend': 1780},
#  {'objectid': 229080,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 73413,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 229083,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 81044,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 229099,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank_value': 73404,
#   'datebegin': 1830,
#   'dateend': 1839},
#  {'objectid': 229100,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 72866,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 229107,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank_value': 72236,
#   'datebegin': 1916,
#   'dateend': 1916},
#  {'objectid': 229110,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 72318,
#   'datebegin': 1904,
#   'dateend': 1904},
#  {'objectid': 229112,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 62425,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 229113,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 62427,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 229114,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 62428,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 229115,
#   'imagecount': 5,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 53953,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 229121,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 71998,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 229123,
#   'imagecount': 0,
#   'mediacount': 0,
#   'colorcount': 0,
#   'rank_value': 72209,
#   'datebegin': 1335,
#   'dateend': 1345},
#  {'objectid': 229124,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 72210,
#   'datebegin': 1918,
#   'dateend': 1928},
#  {'objectid': 229128,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 55495,
#   'datebegin': 1775,
#   'dateend': 1800},
#  {'objectid': 229134,
#   'imagecount': 3,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank_value': 71566,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 229135,
#   'imagecount': 4,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank_value': 71574,
#   'datebegin': 1769,
#   'dateend': 1769},
#  {'objectid': 229136,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 56460,
#   'datebegin': 1640,
#   'dateend': 1649},
#  {'objectid': 229142,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 53412,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 229143,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank_value': 53844,
#   'datebegin': 1524,
#   'dateend': 1544},
#  {'objectid': 229145,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 55493,
#   'datebegin': 1750,
#   'dateend': 1800},
#  {'objectid': 229150,
#   'imagecount': 0,
#   'mediacount': 0,
#   'colorcount': 0,
#   'rank_value': 72039,
#   'datebegin': 1615,
#   'dateend': 1625},
#  {'objectid': 229151,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 72262,
#   'datebegin': 1401,
#   'dateend': 1500},
#  {'objectid': 229163,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 70713,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 229164,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 70714,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 229166,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank_value': 71809,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 229167,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 71811,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 229175,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 72347,
#   'datebegin': 1923,
#   'dateend': 1923},
#  {'objectid': 229182,
# ...
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 62530,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230864,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 62535,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230865,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 62539,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230866,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 62504,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230867,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 61957,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230868,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 61960,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230869,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 61971,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230870,
#   'imagecount': 0,
#   'mediacount': 0,
#   'colorcount': 0,
#   'rank_value': 61978,
#   'datebegin': 1897,
#   'dateend': 1897},
#  {'objectid': 230871,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank_value': 61985,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230872,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 61988,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230873,
#   'imagecount': 0,
#   'mediacount': 0,
#   'colorcount': 0,
#   'rank_value': 61989,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230874,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank_value': 62543,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230875,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 62544,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230876,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank_value': 62545,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230877,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank_value': 62546,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230878,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank_value': 62005,
#   'datebegin': 1898,
#   'dateend': 1898},
#  {'objectid': 230879,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank_value': 61984,
#   'datebegin': 1901,
#   'dateend': 1901},
#  {'objectid': 230880,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank_value': 62532,
#   'datebegin': 1932,
#   'dateend': 1932},
#  {'objectid': 230881,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank_value': 62537,
#   'datebegin': 1933,
#   'dateend': 1933},
#  {'objectid': 230882,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank_value': 62977,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230883,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 64147,
#   'datebegin': 1400,
#   'dateend': 1432},
#  {'objectid': 230884,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 64162,
#   'datebegin': 1349,
#   'dateend': 1359},
#  {'objectid': 230886,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 64522,
#   'datebegin': 1767,
#   'dateend': 1799},
#  {'objectid': 230887,
#   'imagecount': 6,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 64557,
#   'datebegin': 1305,
#   'dateend': 1315},
#  {'objectid': 230890,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 64382,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230891,
#   'imagecount': 0,
#   'mediacount': 0,
#   'colorcount': 0,
#   'rank_value': 64673,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230894,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank_value': 61979,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230895,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 61980,
#   'datebegin': 1902,
#   'dateend': 1902},
#  {'objectid': 230896,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank_value': 61998,
#   'datebegin': 1898,
#   'dateend': 1898},
#  {'objectid': 230897,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank_value': 62003,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230898,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 62515,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230899,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 62516,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230900,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 62517,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230901,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank_value': 62525,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230902,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank_value': 62531,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230903,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 62538,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230904,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank_value': 62004,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230905,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 62017,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230906,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 62023,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230907,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 62565,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230908,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank_value': 62566,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230909,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank_value': 64144,
#   'datebegin': 1874,
#   'dateend': 1874},
#  {'objectid': 230917,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank_value': 62042,
#   'datebegin': 1891,
#   'dateend': 1891},
#  {'objectid': 230918,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank_value': 62043,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230919,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank_value': 62013,
#   'datebegin': 1891,
#   'dateend': 1891},
#  {'objectid': 230920,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 62014,
#   'datebegin': 1894,
#   'dateend': 1894},
#  {'objectid': 230921,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 62015,
#   'datebegin': 1894,
#   'dateend': 1894},
#  {'objectid': 230922,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 62022,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230923,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 62024,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230924,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 62029,
#   'datebegin': 1894,
#   'dateend': 1894},
#  {'objectid': 230929,
#   'imagecount': 3,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 49732,
#   'datebegin': 1375,
#   'dateend': 1385},
#  {'objectid': 230930,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 61880,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230931,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank_value': 61884,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230932,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank_value': 61596,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230933,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 61597,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230934,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 61602,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230935,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank_value': 61608,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230936,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 61610,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230937,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 61615,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230938,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 61616,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230939,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank_value': 61624,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230940,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 61636,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230941,
#   'imagecount': 6,
#   'mediacount': 0,
#   'colorcount': 12,
#   'rank_value': 60290,
#   'datebegin': 1878,
#   'dateend': 1878},
#  {'objectid': 230942,
#   'imagecount': 3,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 60294,
#   'datebegin': 1889,
#   'dateend': 1889},
#  {'objectid': 230943,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 61555,
#   'datebegin': 1872,
#   'dateend': 1882},
#  {'objectid': 230944,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 61565,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230945,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 61567,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230946,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 61570,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230947,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 61574,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230948,
#   'imagecount': 0,
#   'mediacount': 0,
#   'colorcount': 0,
#   'rank_value': 61802,
#   'datebegin': 1935,
#   'dateend': 1935},
#  {'objectid': 230950,
#   'imagecount': 2,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank_value': 61862,
#   'datebegin': 1897,
#   'dateend': 1897},
#  {'objectid': 230951,
#   'imagecount': 0,
#   'mediacount': 0,
#   'colorcount': 0,
#   'rank_value': 61865,
#   'datebegin': 1897,
#   'dateend': 1897},
#  {'objectid': 230952,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 61871,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230953,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 61872,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230954,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 61875,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230955,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 61885,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230969,
#   'imagecount': 0,
#   'mediacount': 0,
#   'colorcount': 0,
#   'rank_value': 61780,
#   'datebegin': 1900,
#   'dateend': 1912},
#  {'objectid': 230970,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 61866,
#   'datebegin': 1898,
#   'dateend': 1898},
#  {'objectid': 230971,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank_value': 61867,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230972,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 61868,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230973,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 61869,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230974,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 61870,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230975,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 61878,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230976,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank_value': 61881,
#   'datebegin': 1896,
#   'dateend': 1896},
#  {'objectid': 230977,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 61882,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230978,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 7,
#   'rank_value': 61883,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230979,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 61603,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230980,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 61604,
#   'datebegin': 1898,
#   'dateend': 1898},
#  {'objectid': 230981,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 61613,
#   'datebegin': 1891,
#   'dateend': 1891},
#  {'objectid': 230995,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 61594,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230996,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 61595,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230997,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank_value': 61620,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230998,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 61623,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 230999,
#   'imagecount': 0,
#   'mediacount': 0,
#   'colorcount': 0,
#   'rank_value': 61627,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 231000,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 61633,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 231001,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 61637,
#   'datebegin': 1894,
#   'dateend': 1894},
#  {'objectid': 231002,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 61907,
#   'datebegin': 1896,
#   'dateend': 1896},
#  {'objectid': 231003,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 62053,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 231004,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank_value': 62059,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 231005,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank_value': 62066,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 231006,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank_value': 62067,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 231007,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 61894,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 231008,
#   'imagecount': 3,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 60295,
#   'datebegin': 1875,
#   'dateend': 1885},
#  {'objectid': 231009,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 62052,
#   'datebegin': 1894,
#   'dateend': 1894},
#  {'objectid': 231010,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank_value': 62062,
#   'datebegin': 1897,
#   'dateend': 1897},
#  {'objectid': 231011,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank_value': 62065,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 231012,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 61886,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 231013,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 9,
#   'rank_value': 61895,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 231014,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank_value': 61899,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 231015,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 8,
#   'rank_value': 61900,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 231016,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 10,
#   'rank_value': 62466,
#   'datebegin': 1891,
#   'dateend': 1891},
#  {'objectid': 231017,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 6,
#   'rank_value': 62073,
#   'datebegin': 1897,
#   'dateend': 1897},
#  {'objectid': 231018,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 5,
#   'rank_value': 62074,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 231019,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 3,
#   'rank_value': 62075,
#   'datebegin': 0,
#   'dateend': 0},
#  {'objectid': 231020,
#   'imagecount': 1,
#   'mediacount': 0,
#   'colorcount': 4,
#   'rank_value': 62076,
#   'datebegin': 0,
#   'dateend': 0},
#  ...]

# %%
artifact_colors
# Out:
# [{'objectid': 228185,
#   'color': '#7d6432',
#   'spectrum': '#6cbd45',
#   'hue': 'Yellow',
#   'percent': 0.21123359580052495,
#   'css3': '#a0522d'},
#  {'objectid': 228185,
#   'color': '#323232',
#   'spectrum': '#2eb45d',
#   'hue': 'Grey',
#   'percent': 0.12813648293963253,
#   'css3': '#2f4f4f'},
#  {'objectid': 228185,
#   'color': '#afafaf',
#   'spectrum': '#8c5fa8',
#   'hue': 'Grey',
#   'percent': 0.1068241469816273,
#   'css3': '#a9a9a9'},
#  {'objectid': 228185,
#   'color': '#324b4b',
#   'spectrum': '#2eb45d',
#   'hue': 'Grey',
#   'percent': 0.0941732283464567,
#   'css3': '#2f4f4f'},
#  {'objectid': 228185,
#   'color': '#644b32',
#   'spectrum': '#59ba4a',
#   'hue': 'Brown',
#   'percent': 0.08887139107611548,
#   'css3': '#556b2f'},
#  {'objectid': 228185,
#   'color': '#c8af7d',
#   'spectrum': '#e9715f',
#   'hue': 'Brown',
#   'percent': 0.06062992125984252,
#   'css3': '#d2b48c'},
#  {'objectid': 228185,
#   'color': '#4b6464',
#   'spectrum': '#5e6db3',
#   'hue': 'Blue',
#   'percent': 0.04482939632545932,
#   'css3': '#696969'},
#  {'objectid': 228185,
#   'color': '#af4b32',
#   'spectrum': '#d75776',
#   'hue': 'Orange',
#   'percent': 0.044146981627296585,
#   'css3': '#a0522d'},
#  {'objectid': 228185,
#   'color': '#969696',
#   'spectrum': '#8761aa',
#   'hue': 'Grey',
#   'percent': 0.041259842519685036,
#   'css3': '#a9a9a9'},
#  {'objectid': 228185,
#   'color': '#c8c8af',
#   'spectrum': '#b55592',
#   'hue': 'Green',
#   'percent': 0.03165354330708661,
#   'css3': '#c0c0c0'},
#  {'objectid': 228189,
#   'color': '#323219',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.6263305322128851,
#   'css3': '#2f4f4f'},
#  {'objectid': 228189,
#   'color': '#4b3232',
#   'spectrum': '#4ab851',
#   'hue': 'Red',
#   'percent': 0.1345658263305322,
#   'css3': '#2f4f4f'},
#  {'objectid': 228189,
#   'color': '#644b32',
#   'spectrum': '#59ba4a',
#   'hue': 'Brown',
#   'percent': 0.07871148459383753,
#   'css3': '#556b2f'},
#  {'objectid': 228189,
#   'color': '#7d644b',
#   'spectrum': '#b25593',
#   'hue': 'Yellow',
#   'percent': 0.042296918767507005,
#   'css3': '#696969'},
#  {'objectid': 228189,
#   'color': '#967d64',
#   'spectrum': '#b65590',
#   'hue': 'Brown',
#   'percent': 0.041176470588235294,
#   'css3': '#808080'},
#  {'objectid': 228189,
#   'color': '#7d3232',
#   'spectrum': '#bd558b',
#   'hue': 'Red',
#   'percent': 0.0407843137254902,
#   'css3': '#8b4513'},
#  {'objectid': 228189,
#   'color': '#af967d',
#   'spectrum': '#c25687',
#   'hue': 'Brown',
#   'percent': 0.01619047619047619,
#   'css3': '#bc8f8f'},
#  {'objectid': 228189,
#   'color': '#c8af96',
#   'spectrum': '#e66c64',
#   'hue': 'Brown',
#   'percent': 0.014565826330532213,
#   'css3': '#d2b48c'},
#  {'objectid': 228189,
#   'color': '#e1c8af',
#   'spectrum': '#e9715f',
#   'hue': 'Orange',
#   'percent': 0.005378151260504202,
#   'css3': '#f5deb3'},
#  {'objectid': 228194,
#   'color': '#4b4b4b',
#   'spectrum': '#3db657',
#   'hue': 'Grey',
#   'percent': 0.15988795518207283,
#   'css3': '#2f4f4f'},
#  {'objectid': 228194,
#   'color': '#646464',
#   'spectrum': '#7866ad',
#   'hue': 'Grey',
#   'percent': 0.13495798319327731,
#   'css3': '#696969'},
#  {'objectid': 228194,
#   'color': '#969696',
#   'spectrum': '#8761aa',
#   'hue': 'Grey',
#   'percent': 0.12829131652661063,
#   'css3': '#a9a9a9'},
#  {'objectid': 228194,
#   'color': '#323232',
#   'spectrum': '#2eb45d',
#   'hue': 'Grey',
#   'percent': 0.12549019607843137,
#   'css3': '#2f4f4f'},
#  {'objectid': 228194,
#   'color': '#7d7d7d',
#   'spectrum': '#8362aa',
#   'hue': 'Grey',
#   'percent': 0.12358543417366946,
#   'css3': '#808080'},
#  {'objectid': 228194,
#   'color': '#afafaf',
#   'spectrum': '#8c5fa8',
#   'hue': 'Grey',
#   'percent': 0.08873949579831933,
#   'css3': '#a9a9a9'},
#  {'objectid': 228194,
#   'color': '#191919',
#   'spectrum': '#1eb264',
#   'hue': 'Grey',
#   'percent': 0.0695798319327731,
#   'css3': '#000000'},
#  {'objectid': 228194,
#   'color': '#c8c8c8',
#   'spectrum': '#8c5fa8',
#   'hue': 'Grey',
#   'percent': 0.06857142857142857,
#   'css3': '#c0c0c0'},
#  {'objectid': 228194,
#   'color': '#e1e1e1',
#   'spectrum': '#955ba5',
#   'hue': 'Grey',
#   'percent': 0.05378151260504202,
#   'css3': '#dcdcdc'},
#  {'objectid': 228194,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.039831932773109244,
#   'css3': '#000000'},
#  {'objectid': 228199,
#   'color': '#4b3219',
#   'spectrum': '#4ab851',
#   'hue': 'Brown',
#   'percent': 0.2731733333333333,
#   'css3': '#556b2f'},
#  {'objectid': 228199,
#   'color': '#644b19',
#   'spectrum': '#64bc46',
#   'hue': 'Orange',
#   'percent': 0.18181333333333333,
#   'css3': '#8b4513'},
#  {'objectid': 228199,
#   'color': '#7d6432',
#   'spectrum': '#6cbd45',
#   'hue': 'Yellow',
#   'percent': 0.12949333333333332,
#   'css3': '#a0522d'},
#  {'objectid': 228199,
#   'color': '#967d4b',
#   'spectrum': '#7fc241',
#   'hue': 'Brown',
#   'percent': 0.0984,
#   'css3': '#a0522d'},
#  {'objectid': 228199,
#   'color': '#c8af7d',
#   'spectrum': '#e9715f',
#   'hue': 'Brown',
#   'percent': 0.0896,
#   'css3': '#d2b48c'},
#  {'objectid': 228199,
#   'color': '#af9664',
#   'spectrum': '#e9715f',
#   'hue': 'Yellow',
#   'percent': 0.08032,
#   'css3': '#bdb76b'},
#  {'objectid': 228199,
#   'color': '#321900',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.07733333333333334,
#   'css3': '#000000'},
#  {'objectid': 228199,
#   'color': '#e1c896',
#   'spectrum': '#ed765a',
#   'hue': 'Yellow',
#   'percent': 0.05914666666666667,
#   'css3': '#deb887'},
#  {'objectid': 228199,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.006986666666666667,
#   'css3': '#000000'},
#  {'objectid': 228199,
#   'color': '#e1e1c8',
#   'spectrum': '#e9715f',
#   'hue': 'Green',
#   'percent': 0.0037333333333333333,
#   'css3': '#dcdcdc'},
#  {'objectid': 228201,
#   'color': '#fafafa',
#   'spectrum': '#955ba5',
#   'hue': 'White',
#   'percent': 0.45933993399339934,
#   'css3': '#fffafa'},
#  {'objectid': 228201,
#   'color': '#323232',
#   'spectrum': '#2eb45d',
#   'hue': 'Grey',
#   'percent': 0.20554455445544553,
#   'css3': '#2f4f4f'},
#  {'objectid': 228201,
#   'color': '#c8af96',
#   'spectrum': '#e66c64',
#   'hue': 'Brown',
#   'percent': 0.07762376237623762,
#   'css3': '#d2b48c'},
#  {'objectid': 228201,
#   'color': '#191932',
#   'spectrum': '#1eb264',
#   'hue': 'Blue',
#   'percent': 0.07333333333333333,
#   'css3': '#000000'},
#  {'objectid': 228201,
#   'color': '#af7d64',
#   'spectrum': '#c85783',
#   'hue': 'Brown',
#   'percent': 0.06006600660066007,
#   'css3': '#cd5c5c'},
#  {'objectid': 228201,
#   'color': '#7d644b',
#   'spectrum': '#b25593',
#   'hue': 'Yellow',
#   'percent': 0.05333333333333334,
#   'css3': '#696969'},
#  {'objectid': 228201,
#   'color': '#af967d',
#   'spectrum': '#c25687',
#   'hue': 'Brown',
#   'percent': 0.020066006600660068,
#   'css3': '#bc8f8f'},
#  {'objectid': 228201,
#   'color': '#e1e1e1',
#   'spectrum': '#955ba5',
#   'hue': 'Grey',
#   'percent': 0.01485148514851485,
#   'css3': '#dcdcdc'},
#  {'objectid': 228201,
#   'color': '#7d7d7d',
#   'spectrum': '#8362aa',
#   'hue': 'Grey',
#   'percent': 0.013795379537953796,
#   'css3': '#808080'},
#  {'objectid': 228201,
#   'color': '#c8c8c8',
#   'spectrum': '#8c5fa8',
#   'hue': 'Grey',
#   'percent': 0.011353135313531354,
#   'css3': '#c0c0c0'},
#  {'objectid': 228202,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.30887005649717514,
#   'css3': '#556b2f'},
#  {'objectid': 228202,
#   'color': '#323232',
#   'spectrum': '#2eb45d',
#   'hue': 'Grey',
#   'percent': 0.26887005649717516,
#   'css3': '#2f4f4f'},
#  {'objectid': 228202,
#   'color': '#967d64',
#   'spectrum': '#b65590',
#   'hue': 'Brown',
#   'percent': 0.18028248587570622,
#   'css3': '#808080'},
#  {'objectid': 228202,
#   'color': '#64644b',
#   'spectrum': '#59ba4a',
#   'hue': 'Green',
#   'percent': 0.09819209039548023,
#   'css3': '#696969'},
#  {'objectid': 228202,
#   'color': '#191919',
#   'spectrum': '#1eb264',
#   'hue': 'Grey',
#   'percent': 0.07943502824858757,
#   'css3': '#000000'},
#  {'objectid': 228202,
#   'color': '#96967d',
#   'spectrum': '#8e5ea7',
#   'hue': 'Green',
#   'percent': 0.042768361581920905,
#   'css3': '#808080'},
#  {'objectid': 228202,
#   'color': '#641900',
#   'spectrum': '#c65684',
#   'hue': 'Red',
#   'percent': 0.013672316384180792,
#   'css3': '#800000'},
#  {'objectid': 228202,
#   'color': '#966419',
#   'spectrum': '#7fc241',
#   'hue': 'Brown',
#   'percent': 0.007909604519774011,
#   'css3': '#a0522d'},
#  {'objectid': 228203,
#   'color': '#4b7d96',
#   'spectrum': '#536fb5',
#   'hue': 'Blue',
#   'percent': 0.32415770609318995,
#   'css3': '#4682b4'},
#  {'objectid': 228203,
#   'color': '#323232',
#   'spectrum': '#2eb45d',
#   'hue': 'Grey',
#   'percent': 0.2910394265232975,
#   'css3': '#2f4f4f'},
#  {'objectid': 228203,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.09577060931899642,
#   'css3': '#556b2f'},
#  {'objectid': 228203,
#   'color': '#191919',
#   'spectrum': '#1eb264',
#   'hue': 'Grey',
#   'percent': 0.09476702508960573,
#   'css3': '#000000'},
#  {'objectid': 228203,
#   'color': '#afafaf',
#   'spectrum': '#8c5fa8',
#   'hue': 'Grey',
#   'percent': 0.04408602150537634,
#   'css3': '#a9a9a9'},
#  {'objectid': 228203,
#   'color': '#64644b',
#   'spectrum': '#59ba4a',
#   'hue': 'Green',
#   'percent': 0.036845878136200716,
#   'css3': '#696969'},
#  {'objectid': 228203,
#   'color': '#969696',
#   'spectrum': '#8761aa',
#   'hue': 'Grey',
#   'percent': 0.03634408602150538,
#   'css3': '#a9a9a9'},
#  {'objectid': 228203,
#   'color': '#7d96af',
#   'spectrum': '#7069af',
#   'hue': 'Blue',
#   'percent': 0.0339068100358423,
#   'css3': '#778899'},
#  {'objectid': 228203,
#   'color': '#969664',
#   'spectrum': '#84c441',
#   'hue': 'Green',
#   'percent': 0.014408602150537634,
#   'css3': '#808080'},
#  {'objectid': 228203,
#   'color': '#af967d',
#   'spectrum': '#c25687',
#   'hue': 'Brown',
#   'percent': 0.011612903225806452,
#   'css3': '#bc8f8f'},
#  {'objectid': 228204,
#   'color': '#644b32',
#   'spectrum': '#59ba4a',
#   'hue': 'Brown',
#   'percent': 0.31355704697986575,
#   'css3': '#556b2f'},
#  {'objectid': 228204,
#   'color': '#191932',
#   'spectrum': '#1eb264',
#   'hue': 'Blue',
#   'percent': 0.10662192393736018,
#   'css3': '#000000'},
#  {'objectid': 228204,
#   'color': '#c8c8af',
#   'spectrum': '#b55592',
#   'hue': 'Green',
#   'percent': 0.07919463087248323,
#   'css3': '#c0c0c0'},
#  {'objectid': 228204,
#   'color': '#323232',
#   'spectrum': '#2eb45d',
#   'hue': 'Grey',
#   'percent': 0.07883668903803132,
#   'css3': '#2f4f4f'},
#  {'objectid': 228204,
#   'color': '#c8967d',
#   'spectrum': '#e66c64',
#   'hue': 'Grey',
#   'percent': 0.07136465324384787,
#   'css3': '#bc8f8f'},
#  {'objectid': 228204,
#   'color': '#af9696',
#   'spectrum': '#ae5596',
#   'hue': 'Brown',
#   'percent': 0.06626398210290828,
#   'css3': '#bc8f8f'},
#  {'objectid': 228204,
#   'color': '#19324b',
#   'spectrum': '#00929e',
#   'hue': 'Blue',
#   'percent': 0.06389261744966443,
#   'css3': '#2f4f4f'},
#  {'objectid': 228204,
#   'color': '#646464',
#   'spectrum': '#7866ad',
#   'hue': 'Grey',
#   'percent': 0.03919463087248322,
#   'css3': '#696969'},
#  {'objectid': 228204,
#   'color': '#967d7d',
#   'spectrum': '#955ba5',
#   'hue': 'Brown',
#   'percent': 0.03776286353467562,
#   'css3': '#808080'},
#  {'objectid': 228204,
#   'color': '#7d3232',
#   'spectrum': '#bd558b',
#   'hue': 'Red',
#   'percent': 0.03758389261744966,
#   'css3': '#8b4513'},
#  {'objectid': 228206,
#   'color': '#e1c8c8',
#   'spectrum': '#c15689',
#   'hue': 'Orange',
#   'percent': 0.3865277777777778,
#   'css3': '#d8bfd8'},
#  {'objectid': 228206,
#   'color': '#323232',
#   'spectrum': '#2eb45d',
#   'hue': 'Grey',
#   'percent': 0.21166666666666667,
#   'css3': '#2f4f4f'},
#  {'objectid': 228206,
#   'color': '#fae1c8',
#   'spectrum': '#ed765a',
#   'hue': 'Yellow',
#   'percent': 0.15819444444444444,
#   'css3': '#ffe4c4'},
#  {'objectid': 228206,
#   'color': '#191919',
#   'spectrum': '#1eb264',
#   'hue': 'Grey',
#   'percent': 0.09506944444444444,
#   'css3': '#000000'},
#  {'objectid': 228206,
#   'color': '#4b4b4b',
#   'spectrum': '#3db657',
#   'hue': 'Grey',
#   'percent': 0.03666666666666667,
#   'css3': '#2f4f4f'},
#  {'objectid': 228206,
#   'color': '#967d7d',
#   'spectrum': '#955ba5',
#   'hue': 'Brown',
#   'percent': 0.030555555555555555,
#   'css3': '#808080'},
#  {'objectid': 228206,
#   'color': '#af9696',
#   'spectrum': '#ae5596',
#   'hue': 'Brown',
#   'percent': 0.026805555555555555,
#   'css3': '#bc8f8f'},
#  {'objectid': 228206,
#   'color': '#646464',
#   'spectrum': '#7866ad',
#   'hue': 'Grey',
#   'percent': 0.026805555555555555,
#   'css3': '#696969'},
#  {'objectid': 228206,
#   'color': '#7d4b32',
#   'spectrum': '#c25687',
#   'hue': 'Brown',
#   'percent': 0.012361111111111111,
#   'css3': '#8b4513'},
#  {'objectid': 228206,
#   'color': '#000019',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.005,
#   'css3': '#000000'},
#  {'objectid': 228209,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.7798333333333334,
#   'css3': '#556b2f'},
#  {'objectid': 228209,
#   'color': '#afaf96',
#   'spectrum': '#8e5ea7',
#   'hue': 'Green',
#   'percent': 0.114,
#   'css3': '#a9a9a9'},
#  {'objectid': 228209,
#   'color': '#96967d',
#   'spectrum': '#8e5ea7',
#   'hue': 'Green',
#   'percent': 0.10355555555555555,
#   'css3': '#808080'},
#  {'objectid': 228209,
#   'color': '#c8c8af',
#   'spectrum': '#b55592',
#   'hue': 'Green',
#   'percent': 0.0015555555555555555,
#   'css3': '#c0c0c0'},
#  {'objectid': 228209,
#   'color': '#191919',
#   'spectrum': '#1eb264',
#   'hue': 'Grey',
#   'percent': 0.0010555555555555555,
#   'css3': '#000000'},
#  {'objectid': 228213,
#   'color': '#191919',
#   'spectrum': '#1eb264',
#   'hue': 'Grey',
#   'percent': 0.5071140939597315,
#   'css3': '#000000'},
#  {'objectid': 228213,
#   'color': '#4b3219',
#   'spectrum': '#4ab851',
#   'hue': 'Brown',
#   'percent': 0.17829977628635346,
#   'css3': '#556b2f'},
#  {'objectid': 228213,
#   'color': '#193232',
#   'spectrum': '#1eb264',
#   'hue': 'Green',
#   'percent': 0.047740492170022374,
#   'css3': '#2f4f4f'},
#  {'objectid': 228213,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.0429082774049217,
#   'css3': '#556b2f'},
#  {'objectid': 228213,
#   'color': '#7d7d64',
#   'spectrum': '#6cbd45',
#   'hue': 'Yellow',
#   'percent': 0.0425503355704698,
#   'css3': '#808080'},
#  {'objectid': 228213,
#   'color': '#96967d',
#   'spectrum': '#8e5ea7',
#   'hue': 'Green',
#   'percent': 0.03973154362416107,
#   'css3': '#808080'},
#  {'objectid': 228213,
#   'color': '#64644b',
#   'spectrum': '#59ba4a',
#   'hue': 'Green',
#   'percent': 0.0370917225950783,
#   'css3': '#696969'},
#  {'objectid': 228213,
#   'color': '#7d4b19',
#   'spectrum': '#6cbd45',
#   'hue': 'Brown',
#   'percent': 0.03400447427293065,
#   'css3': '#8b4513'},
#  {'objectid': 228213,
#   'color': '#324b4b',
#   'spectrum': '#2eb45d',
#   'hue': 'Grey',
#   'percent': 0.022774049217002237,
#   'css3': '#2f4f4f'},
#  {'objectid': 228213,
#   'color': '#afaf96',
#   'spectrum': '#8e5ea7',
#   'hue': 'Green',
#   'percent': 0.018344519015659956,
#   'css3': '#a9a9a9'},
#  {'objectid': 228214,
#   'color': '#64644b',
#   'spectrum': '#59ba4a',
#   'hue': 'Green',
#   'percent': 0.3576991150442478,
#   'css3': '#696969'},
#  {'objectid': 228214,
#   'color': '#7d9696',
#   'spectrum': '#7069af',
#   'hue': 'Green',
#   'percent': 0.14766961651917404,
#   'css3': '#778899'},
#  {'objectid': 228214,
#   'color': '#7d7d7d',
#   'spectrum': '#8362aa',
#   'hue': 'Grey',
#   'percent': 0.14749262536873156,
#   'css3': '#808080'},
#  {'objectid': 228214,
#   'color': '#967d64',
#   'spectrum': '#b65590',
#   'hue': 'Brown',
#   'percent': 0.14460176991150442,
#   'css3': '#808080'},
#  {'objectid': 228214,
#   'color': '#afaf96',
#   'spectrum': '#8e5ea7',
#   'hue': 'Green',
#   'percent': 0.1400589970501475,
#   'css3': '#a9a9a9'},
#  {'objectid': 228214,
#   'color': '#96967d',
#   'spectrum': '#8e5ea7',
#   'hue': 'Green',
#   'percent': 0.0528023598820059,
#   'css3': '#808080'},
#  {'objectid': 228214,
#   'color': '#191919',
#   'spectrum': '#1eb264',
#   'hue': 'Grey',
#   'percent': 0.009616519174041297,
#   'css3': '#000000'},
#  {'objectid': 228214,
#   'color': '#001900',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 5.899705014749263e-05,
#   'css3': '#000000'},
#  {'objectid': 228218,
#   'color': '#967d32',
#   'spectrum': '#86c440',
#   'hue': 'Yellow',
#   'percent': 0.5065060240963856,
#   'css3': '#a0522d'},
#  {'objectid': 228218,
#   'color': '#af7d4b',
#   'spectrum': '#e9715f',
#   'hue': 'Yellow',
#   'percent': 0.30819277108433735,
#   'css3': '#cd853f'},
#  {'objectid': 228218,
#   'color': '#323232',
#   'spectrum': '#2eb45d',
#   'hue': 'Grey',
#   'percent': 0.06369477911646586,
#   'css3': '#2f4f4f'},
#  {'objectid': 228218,
#   'color': '#644b32',
#   'spectrum': '#59ba4a',
#   'hue': 'Brown',
#   'percent': 0.04232931726907631,
#   'css3': '#556b2f'},
#  {'objectid': 228218,
#   'color': '#e1e1c8',
#   'spectrum': '#e9715f',
#   'hue': 'Green',
#   'percent': 0.034377510040160646,
#   'css3': '#dcdcdc'},
#  {'objectid': 228218,
#   'color': '#191919',
#   'spectrum': '#1eb264',
#   'hue': 'Grey',
#   'percent': 0.024738955823293173,
#   'css3': '#000000'},
#  {'objectid': 228218,
#   'color': '#c8af7d',
#   'spectrum': '#e9715f',
#   'hue': 'Brown',
#   'percent': 0.011244979919678716,
#   'css3': '#d2b48c'},
#  {'objectid': 228218,
#   'color': '#e1c8af',
#   'spectrum': '#e9715f',
#   'hue': 'Orange',
#   'percent': 0.005060240963855421,
#   'css3': '#f5deb3'},
#  {'objectid': 228218,
#   'color': '#7d7d64',
#   'spectrum': '#6cbd45',
#   'hue': 'Yellow',
#   'percent': 0.0038554216867469878,
#   'css3': '#808080'},
#  {'objectid': 228219,
#   'color': '#644b19',
#   'spectrum': '#64bc46',
#   'hue': 'Orange',
#   'percent': 0.305959595959596,
#   'css3': '#8b4513'},
#  {'objectid': 228219,
#   'color': '#321900',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.2130808080808081,
#   'css3': '#000000'},
#  {'objectid': 228219,
#   'color': '#4b3200',
#   'spectrum': '#59ba4a',
#   'hue': 'Brown',
#   'percent': 0.14242424242424243,
#   'css3': '#8b4513'},
#  {'objectid': 228219,
#   'color': '#191919',
#   'spectrum': '#1eb264',
#   'hue': 'Grey',
#   'percent': 0.06474747474747475,
#   'css3': '#000000'},
#  {'objectid': 228219,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.06161616161616162,
#   'css3': '#556b2f'},
#  {'objectid': 228219,
#   'color': '#7d7d7d',
#   'spectrum': '#8362aa',
#   'hue': 'Grey',
#   'percent': 0.04606060606060606,
#   'css3': '#808080'},
#  {'objectid': 228219,
#   'color': '#64644b',
#   'spectrum': '#59ba4a',
#   'hue': 'Green',
#   'percent': 0.04040404040404041,
#   'css3': '#696969'},
#  {'objectid': 228219,
#   'color': '#7d9696',
#   'spectrum': '#7069af',
#   'hue': 'Green',
#   'percent': 0.028484848484848484,
#   'css3': '#778899'},
#  {'objectid': 228219,
#   'color': '#af7d32',
#   'spectrum': '#f17c4f',
#   'hue': 'Yellow',
#   'percent': 0.027373737373737373,
#   'css3': '#cd853f'},
#  {'objectid': 228219,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.026464646464646465,
#   'css3': '#000000'},
#  {'objectid': 228222,
#   'color': '#e1c8af',
#   'spectrum': '#e9715f',
#   'hue': 'Orange',
#   'percent': 0.679047619047619,
#   'css3': '#f5deb3'},
#  {'objectid': 228222,
#   'color': '#c81932',
#   'spectrum': '#dd5872',
#   'hue': 'Red',
#   'percent': 0.057755102040816325,
#   'css3': '#dc143c'},
#  {'objectid': 228222,
#   'color': '#fac800',
#   'spectrum': '#ffcc08',
#   'hue': 'Yellow',
#   'percent': 0.05489795918367347,
#   'css3': '#ffd700'},
#  {'objectid': 228222,
#   'color': '#323232',
#   'spectrum': '#2eb45d',
#   'hue': 'Grey',
#   'percent': 0.051564625850340134,
#   'css3': '#2f4f4f'},
#  {'objectid': 228222,
#   'color': '#fa6419',
#   'spectrum': '#f58444',
#   'hue': 'Orange',
#   'percent': 0.03693877551020408,
#   'css3': '#ff4500'},
#  {'objectid': 228222,
#   'color': '#644b32',
#   'spectrum': '#59ba4a',
#   'hue': 'Brown',
#   'percent': 0.027482993197278913,
#   'css3': '#556b2f'},
#  {'objectid': 228222,
#   'color': '#afaf96',
#   'spectrum': '#8e5ea7',
#   'hue': 'Green',
#   'percent': 0.016258503401360543,
#   'css3': '#a9a9a9'},
#  {'objectid': 228222,
#   'color': '#7d3219',
#   'spectrum': '#d0577c',
#   'hue': 'Orange',
#   'percent': 0.01619047619047619,
#   'css3': '#8b4513'},
#  {'objectid': 228222,
#   'color': '#fa7d00',
#   'spectrum': '#fba927',
#   'hue': 'Orange',
#   'percent': 0.015714285714285715,
#   'css3': '#ff8c00'},
#  {'objectid': 228222,
#   'color': '#fac84b',
#   'spectrum': '#faa72b',
#   'hue': 'Yellow',
#   'percent': 0.014625850340136054,
#   'css3': '#f4a460'},
#  {'objectid': 228227,
#   'color': '#644b32',
#   'spectrum': '#59ba4a',
#   'hue': 'Brown',
#   'percent': 0.28784313725490196,
#   'css3': '#556b2f'},
#  {'objectid': 228227,
#   'color': '#323232',
#   'spectrum': '#2eb45d',
#   'hue': 'Grey',
#   'percent': 0.19537254901960785,
#   'css3': '#2f4f4f'},
#  {'objectid': 228227,
#   'color': '#191919',
#   'spectrum': '#1eb264',
#   'hue': 'Grey',
#   'percent': 0.17184313725490197,
#   'css3': '#000000'},
#  {'objectid': 228227,
#   'color': '#af7d32',
#   'spectrum': '#f17c4f',
#   'hue': 'Yellow',
#   'percent': 0.11325490196078432,
#   'css3': '#cd853f'},
#  {'objectid': 228227,
#   'color': '#e1e1e1',
#   'spectrum': '#955ba5',
#   'hue': 'Grey',
#   'percent': 0.08619607843137254,
#   'css3': '#dcdcdc'},
#  {'objectid': 228227,
#   'color': '#af967d',
#   'spectrum': '#c25687',
#   'hue': 'Brown',
#   'percent': 0.03937254901960784,
#   'css3': '#bc8f8f'},
#  {'objectid': 228227,
#   'color': '#fafafa',
#   'spectrum': '#955ba5',
#   'hue': 'White',
#   'percent': 0.03811764705882353,
#   'css3': '#fffafa'},
#  {'objectid': 228227,
#   'color': '#967d64',
#   'spectrum': '#b65590',
#   'hue': 'Brown',
#   'percent': 0.024941176470588234,
#   'css3': '#808080'},
#  {'objectid': 228227,
#   'color': '#961919',
#   'spectrum': '#d75776',
#   'hue': 'Orange',
#   'percent': 0.024705882352941175,
#   'css3': '#a52a2a'},
#  {'objectid': 228227,
#   'color': '#c8964b',
#   'spectrum': '#f58843',
#   'hue': 'Yellow',
#   'percent': 0.009568627450980392,
#   'css3': '#cd853f'},
#  {'objectid': 228228,
#   'color': '#323232',
#   'spectrum': '#2eb45d',
#   'hue': 'Grey',
#   'percent': 0.1776068376068376,
#   'css3': '#2f4f4f'},
#  {'objectid': 228228,
#   'color': '#afafaf',
#   'spectrum': '#8c5fa8',
#   'hue': 'Grey',
#   'percent': 0.17532763532763532,
#   'css3': '#a9a9a9'},
#  {'objectid': 228228,
#   'color': '#969696',
#   'spectrum': '#8761aa',
#   'hue': 'Grey',
#   'percent': 0.1390883190883191,
#   'css3': '#a9a9a9'},
#  {'objectid': 228228,
#   'color': '#4b4b4b',
#   'spectrum': '#3db657',
#   'hue': 'Grey',
#   'percent': 0.13675213675213677,
#   'css3': '#2f4f4f'},
#  {'objectid': 228228,
#   'color': '#7d7d7d',
#   'spectrum': '#8362aa',
#   'hue': 'Grey',
#   'percent': 0.12148148148148148,
#   'css3': '#808080'},
#  {'objectid': 228228,
#   'color': '#646464',
#   'spectrum': '#7866ad',
#   'hue': 'Grey',
#   'percent': 0.11339031339031339,
#   'css3': '#696969'},
#  {'objectid': 228228,
#   'color': '#191919',
#   'spectrum': '#1eb264',
#   'hue': 'Grey',
#   'percent': 0.07943019943019942,
#   'css3': '#000000'},
#  {'objectid': 228228,
#   'color': '#c8c8c8',
#   'spectrum': '#8c5fa8',
#   'hue': 'Grey',
#   'percent': 0.043931623931623934,
#   'css3': '#c0c0c0'},
#  {'objectid': 228228,
#   'color': '#e1e1e1',
#   'spectrum': '#955ba5',
#   'hue': 'Grey',
#   'percent': 0.012991452991452991,
#   'css3': '#dcdcdc'},
#  {'objectid': 228229,
#   'color': '#191919',
#   'spectrum': '#1eb264',
#   'hue': 'Grey',
#   'percent': 0.7812280701754386,
#   'css3': '#000000'},
#  {'objectid': 228229,
#   'color': '#966419',
#   'spectrum': '#7fc241',
#   'hue': 'Brown',
#   'percent': 0.07771929824561404,
#   'css3': '#a0522d'},
#  {'objectid': 228229,
#   'color': '#7d4b19',
#   'spectrum': '#6cbd45',
#   'hue': 'Brown',
#   'percent': 0.053567251461988305,
#   'css3': '#8b4513'},
#  {'objectid': 228229,
#   'color': '#af7d32',
#   'spectrum': '#f17c4f',
#   'hue': 'Yellow',
#   'percent': 0.047426900584795324,
#   'css3': '#cd853f'},
#  {'objectid': 228229,
#   'color': '#c89632',
#   'spectrum': '#f79738',
#   'hue': 'Yellow',
#   'percent': 0.03865497076023392,
#   'css3': '#cd853f'},
#  {'objectid': 228229,
#   'color': '#e1af4b',
#   'spectrum': '#f89c35',
#   'hue': 'Yellow',
#   'percent': 0.0012280701754385965,
#   'css3': '#f4a460'},
#  {'objectid': 228229,
#   'color': '#967d7d',
#   'spectrum': '#955ba5',
#   'hue': 'Brown',
#   'percent': 0.00017543859649122806,
#   'css3': '#808080'},
#  {'objectid': 228230,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.8797222222222222,
#   'css3': '#000000'},
#  {'objectid': 228230,
#   'color': '#000019',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.08438888888888889,
#   'css3': '#000000'},
#  {'objectid': 228230,
#   'color': '#4b3219',
#   'spectrum': '#4ab851',
#   'hue': 'Brown',
#   'percent': 0.015111111111111112,
#   'css3': '#556b2f'},
#  {'objectid': 228230,
#   'color': '#c8afc8',
#   'spectrum': '#955ba5',
#   'hue': 'Violet',
#   'percent': 0.007722222222222222,
#   'css3': '#c0c0c0'},
#  {'objectid': 228230,
#   'color': '#644b32',
#   'spectrum': '#59ba4a',
#   'hue': 'Brown',
#   'percent': 0.006055555555555555,
#   'css3': '#556b2f'},
#  {'objectid': 228230,
#   'color': '#fafafa',
#   'spectrum': '#955ba5',
#   'hue': 'White',
#   'percent': 0.002777777777777778,
#   'css3': '#fffafa'},
#  {'objectid': 228230,
#   'color': '#967d64',
#   'spectrum': '#b65590',
#   'hue': 'Brown',
#   'percent': 0.0006111111111111111,
#   'css3': '#808080'},
#  {'objectid': 228230,
#   'color': '#c8af7d',
#   'spectrum': '#e9715f',
#   'hue': 'Brown',
#   'percent': 0.00038888888888888887,
#   'css3': '#d2b48c'},
#  {'objectid': 228230,
#   'color': '#fae196',
#   'spectrum': '#c8d62c',
#   'hue': 'Yellow',
#   'percent': 0.0003333333333333333,
#   'css3': '#f0e68c'},
#  {'objectid': 228230,
#   'color': '#af9664',
#   'spectrum': '#e9715f',
#   'hue': 'Yellow',
#   'percent': 0.0003333333333333333,
#   'css3': '#bdb76b'},
#  {'objectid': 228233,
#   'color': '#4b3232',
#   'spectrum': '#4ab851',
#   'hue': 'Red',
#   'percent': 0.28031372549019606,
#   'css3': '#2f4f4f'},
#  {'objectid': 228233,
#   'color': '#644b32',
#   'spectrum': '#59ba4a',
#   'hue': 'Brown',
#   'percent': 0.2616470588235294,
#   'css3': '#556b2f'},
#  {'objectid': 228233,
#   'color': '#af964b',
#   'spectrum': '#9ecb3b',
#   'hue': 'Yellow',
#   'percent': 0.18384313725490195,
#   'css3': '#cd853f'},
#  {'objectid': 228233,
#   'color': '#969696',
#   'spectrum': '#8761aa',
#   'hue': 'Grey',
#   'percent': 0.09011764705882352,
#   'css3': '#a9a9a9'},
#  {'objectid': 228233,
#   'color': '#966432',
#   'spectrum': '#e46867',
#   'hue': 'Orange',
#   'percent': 0.0868235294117647,
#   'css3': '#a0522d'},
#  {'objectid': 228233,
#   'color': '#7d7d7d',
#   'spectrum': '#8362aa',
#   'hue': 'Grey',
#   'percent': 0.05890196078431373,
#   'css3': '#808080'},
#  {'objectid': 228233,
#   'color': '#646464',
#   'spectrum': '#7866ad',
#   'hue': 'Grey',
#   'percent': 0.02,
#   'css3': '#696969'},
#  {'objectid': 228233,
#   'color': '#963219',
#   'spectrum': '#d75776',
#   'hue': 'Brown',
#   'percent': 0.01835294117647059,
#   'css3': '#8b4513'},
#  {'objectid': 228234,
#   'color': '#fafafa',
#   'spectrum': '#955ba5',
#   'hue': 'White',
#   'percent': 0.34805555555555556,
#   'css3': '#fffafa'},
#  {'objectid': 228234,
#   'color': '#e1e1e1',
#   'spectrum': '#955ba5',
#   'hue': 'Grey',
#   'percent': 0.2846666666666667,
#   'css3': '#dcdcdc'},
#  {'objectid': 228234,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.12588888888888888,
#   'css3': '#000000'},
#  {'objectid': 228234,
#   'color': '#c8c8c8',
#   'spectrum': '#8c5fa8',
#   'hue': 'Grey',
#   'percent': 0.06788888888888889,
#   'css3': '#c0c0c0'},
#  {'objectid': 228234,
#   'color': '#323232',
#   'spectrum': '#2eb45d',
#   'hue': 'Grey',
#   'percent': 0.06666666666666667,
#   'css3': '#2f4f4f'},
#  {'objectid': 228234,
#   'color': '#4b4b4b',
#   'spectrum': '#3db657',
#   'hue': 'Grey',
#   'percent': 0.0656111111111111,
#   'css3': '#2f4f4f'},
#  {'objectid': 228234,
#   'color': '#afafaf',
#   'spectrum': '#8c5fa8',
#   'hue': 'Grey',
#   'percent': 0.04122222222222222,
#   'css3': '#a9a9a9'},
#  {'objectid': 228235,
#   'color': '#323232',
#   'spectrum': '#2eb45d',
#   'hue': 'Grey',
#   'percent': 0.3947747747747748,
#   'css3': '#2f4f4f'},
#  {'objectid': 228235,
#   'color': '#191919',
#   'spectrum': '#1eb264',
#   'hue': 'Grey',
#   'percent': 0.22852852852852854,
#   'css3': '#000000'},
#  {'objectid': 228235,
#   'color': '#644b32',
#   'spectrum': '#59ba4a',
#   'hue': 'Brown',
#   'percent': 0.1215015015015015,
#   'css3': '#556b2f'},
#  {'objectid': 228235,
#   'color': '#afafaf',
#   'spectrum': '#8c5fa8',
#   'hue': 'Grey',
#   'percent': 0.04378378378378378,
#   'css3': '#a9a9a9'},
#  {'objectid': 228235,
#   'color': '#af4b19',
#   'spectrum': '#e86e61',
#   'hue': 'Red',
#   'percent': 0.03633633633633634,
#   'css3': '#a0522d'},
#  {'objectid': 228235,
#   'color': '#7d644b',
#   'spectrum': '#b25593',
#   'hue': 'Yellow',
#   'percent': 0.02966966966966967,
#   'css3': '#696969'},
#  {'objectid': 228235,
#   'color': '#c89664',
#   'spectrum': '#ed7758',
#   'hue': 'Brown',
#   'percent': 0.026366366366366367,
#   'css3': '#bdb76b'},
#  {'objectid': 228235,
#   'color': '#967d4b',
#   'spectrum': '#7fc241',
#   'hue': 'Brown',
#   'percent': 0.025045045045045046,
#   'css3': '#a0522d'},
#  {'objectid': 228235,
#   'color': '#c8af7d',
#   'spectrum': '#e9715f',
#   'hue': 'Brown',
#   'percent': 0.024624624624624624,
#   'css3': '#d2b48c'},
#  {'objectid': 228235,
#   'color': '#af7d64',
#   'spectrum': '#c85783',
#   'hue': 'Brown',
#   'percent': 0.021621621621621623,
#   'css3': '#cd5c5c'},
#  {'objectid': 228236,
#   'color': '#7d6432',
#   'spectrum': '#6cbd45',
#   'hue': 'Yellow',
#   'percent': 0.24857142857142858,
#   'css3': '#a0522d'},
#  {'objectid': 228236,
#   'color': '#644b32',
#   'spectrum': '#59ba4a',
#   'hue': 'Brown',
#   'percent': 0.2273469387755102,
#   'css3': '#556b2f'},
#  {'objectid': 228236,
#   'color': '#323219',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.18741496598639457,
#   'css3': '#2f4f4f'},
#  {'objectid': 228236,
#   'color': '#fafafa',
#   'spectrum': '#955ba5',
#   'hue': 'White',
#   'percent': 0.15136054421768708,
#   'css3': '#fffafa'},
#  {'objectid': 228236,
#   'color': '#af7d4b',
#   'spectrum': '#e9715f',
#   'hue': 'Yellow',
#   'percent': 0.1091156462585034,
#   'css3': '#cd853f'},
#  {'objectid': 228236,
#   'color': '#191919',
#   'spectrum': '#1eb264',
#   'hue': 'Grey',
#   'percent': 0.056598639455782314,
#   'css3': '#000000'},
#  {'objectid': 228236,
#   'color': '#e1e1e1',
#   'spectrum': '#955ba5',
#   'hue': 'Grey',
#   'percent': 0.005782312925170068,
#   'css3': '#dcdcdc'},
#  {'objectid': 228236,
#   'color': '#c8c8af',
#   'spectrum': '#b55592',
#   'hue': 'Green',
#   'percent': 0.004761904761904762,
#   'css3': '#c0c0c0'},
#  {'objectid': 228236,
#   'color': '#e1c8c8',
#   'spectrum': '#c15689',
#   'hue': 'Orange',
#   'percent': 0.0037414965986394557,
#   'css3': '#d8bfd8'},
#  {'objectid': 228236,
#   'color': '#7d7d7d',
#   'spectrum': '#8362aa',
#   'hue': 'Grey',
#   'percent': 0.0022448979591836735,
#   'css3': '#808080'},
#  {'objectid': 228237,
#   'color': '#7d7d7d',
#   'spectrum': '#8362aa',
#   'hue': 'Grey',
#   'percent': 0.16216666666666665,
#   'css3': '#808080'},
#  {'objectid': 228237,
#   'color': '#969696',
#   'spectrum': '#8761aa',
#   'hue': 'Grey',
#   'percent': 0.132,
#   'css3': '#a9a9a9'},
#  {'objectid': 228237,
#   'color': '#646464',
#   'spectrum': '#7866ad',
#   'hue': 'Grey',
#   'percent': 0.13177777777777777,
#   'css3': '#696969'},
#  {'objectid': 228237,
#   'color': '#e1e1e1',
#   'spectrum': '#955ba5',
#   'hue': 'Grey',
#   'percent': 0.12738888888888888,
#   'css3': '#dcdcdc'},
#  {'objectid': 228237,
#   'color': '#4b4b4b',
#   'spectrum': '#3db657',
#   'hue': 'Grey',
#   'percent': 0.10472222222222222,
#   'css3': '#2f4f4f'},
#  {'objectid': 228237,
#   'color': '#c8c8c8',
#   'spectrum': '#8c5fa8',
#   'hue': 'Grey',
#   'percent': 0.10105555555555555,
#   'css3': '#c0c0c0'},
#  {'objectid': 228237,
#   'color': '#afafaf',
#   'spectrum': '#8c5fa8',
#   'hue': 'Grey',
#   'percent': 0.08738888888888889,
#   'css3': '#a9a9a9'},
#  {'objectid': 228237,
#   'color': '#fafafa',
#   'spectrum': '#955ba5',
#   'hue': 'White',
#   'percent': 0.06366666666666666,
#   'css3': '#fffafa'},
#  {'objectid': 228237,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.04516666666666667,
#   'css3': '#000000'},
#  {'objectid': 228237,
#   'color': '#323232',
#   'spectrum': '#2eb45d',
#   'hue': 'Grey',
#   'percent': 0.04466666666666667,
#   'css3': '#2f4f4f'},
#  {'objectid': 228238,
#   'color': '#7d7d7d',
#   'spectrum': '#8362aa',
#   'hue': 'Grey',
#   'percent': 0.20355555555555555,
#   'css3': '#808080'},
#  {'objectid': 228238,
#   'color': '#646464',
#   'spectrum': '#7866ad',
#   'hue': 'Grey',
#   'percent': 0.15766666666666668,
#   'css3': '#696969'},
#  {'objectid': 228238,
#   'color': '#969696',
#   'spectrum': '#8761aa',
#   'hue': 'Grey',
#   'percent': 0.14572222222222223,
#   'css3': '#a9a9a9'},
#  {'objectid': 228238,
#   'color': '#4b4b4b',
#   'spectrum': '#3db657',
#   'hue': 'Grey',
#   'percent': 0.09755555555555556,
#   'css3': '#2f4f4f'},
#  {'objectid': 228238,
#   'color': '#191919',
#   'spectrum': '#1eb264',
#   'hue': 'Grey',
#   'percent': 0.09216666666666666,
#   'css3': '#000000'},
#  {'objectid': 228238,
#   'color': '#afafaf',
#   'spectrum': '#8c5fa8',
#   'hue': 'Grey',
#   'percent': 0.092,
#   'css3': '#a9a9a9'},
#  {'objectid': 228238,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.08744444444444445,
#   'css3': '#000000'},
#  {'objectid': 228238,
#   'color': '#323232',
#   'spectrum': '#2eb45d',
#   'hue': 'Grey',
#   'percent': 0.06438888888888888,
#   'css3': '#2f4f4f'},
#  {'objectid': 228238,
#   'color': '#c8c8c8',
#   'spectrum': '#8c5fa8',
#   'hue': 'Grey',
#   'percent': 0.054,
#   'css3': '#c0c0c0'},
#  {'objectid': 228238,
#   'color': '#fafafa',
#   'spectrum': '#955ba5',
#   'hue': 'White',
#   'percent': 0.0055,
#   'css3': '#fffafa'},
#  {'objectid': 228239,
#   'color': '#191919',
#   'spectrum': '#1eb264',
#   'hue': 'Grey',
#   'percent': 0.888448275862069,
#   'css3': '#000000'},
#  {'objectid': 228239,
#   'color': '#644b32',
#   'spectrum': '#59ba4a',
#   'hue': 'Brown',
#   'percent': 0.0317816091954023,
#   'css3': '#556b2f'},
#  {'objectid': 228239,
#   'color': '#967d64',
#   'spectrum': '#b65590',
#   'hue': 'Brown',
#   'percent': 0.026839080459770116,
#   'css3': '#808080'},
#  {'objectid': 228239,
#   'color': '#7d644b',
#   'spectrum': '#b25593',
#   'hue': 'Yellow',
#   'percent': 0.02436781609195402,
#   'css3': '#696969'},
#  {'objectid': 228239,
#   'color': '#af967d',
#   'spectrum': '#c25687',
#   'hue': 'Brown',
#   'percent': 0.021264367816091954,
#   'css3': '#bc8f8f'},
#  {'objectid': 228239,
#   'color': '#646464',
#   'spectrum': '#7866ad',
#   'hue': 'Grey',
#   'percent': 0.003160919540229885,
#   'css3': '#696969'},
#  {'objectid': 228239,
#   'color': '#7d7d7d',
#   'spectrum': '#8362aa',
#   'hue': 'Grey',
#   'percent': 0.0028735632183908046,
#   'css3': '#808080'},
#  {'objectid': 228239,
#   'color': '#e1c8af',
#   'spectrum': '#e9715f',
#   'hue': 'Orange',
#   'percent': 0.0008620689655172414,
#   'css3': '#f5deb3'},
#  {'objectid': 228239,
#   'color': '#fae1c8',
#   'spectrum': '#ed765a',
#   'hue': 'Yellow',
#   'percent': 0.00022988505747126436,
#   'css3': '#ffe4c4'},
#  {'objectid': 228239,
#   'color': '#c8c8c8',
#   'spectrum': '#8c5fa8',
#   'hue': 'Grey',
#   'percent': 0.00011494252873563218,
#   'css3': '#c0c0c0'},
#  {'objectid': 228240,
#   'color': '#323232',
#   'spectrum': '#2eb45d',
#   'hue': 'Grey',
#   'percent': 0.20935574229691878,
#   'css3': '#2f4f4f'},
#  {'objectid': 228240,
#   'color': '#4b4b4b',
#   'spectrum': '#3db657',
#   'hue': 'Grey',
#   'percent': 0.182296918767507,
#   'css3': '#2f4f4f'},
#  {'objectid': 228240,
#   'color': '#e1e1e1',
#   'spectrum': '#955ba5',
#   'hue': 'Grey',
#   'percent': 0.1242016806722689,
#   'css3': '#dcdcdc'},
#  {'objectid': 228240,
#   'color': '#646464',
#   'spectrum': '#7866ad',
#   'hue': 'Grey',
#   'percent': 0.10918767507002801,
#   'css3': '#696969'},
#  {'objectid': 228240,
#   'color': '#fafafa',
#   'spectrum': '#955ba5',
#   'hue': 'White',
#   'percent': 0.10313725490196078,
#   'css3': '#fffafa'},
#  {'objectid': 228240,
#   'color': '#c8c8c8',
#   'spectrum': '#8c5fa8',
#   'hue': 'Grey',
#   'percent': 0.0727170868347339,
#   'css3': '#c0c0c0'},
#  {'objectid': 228240,
#   'color': '#7d7d7d',
#   'spectrum': '#8362aa',
#   'hue': 'Grey',
#   'percent': 0.06442577030812324,
#   'css3': '#808080'},
#  {'objectid': 228240,
#   'color': '#191919',
#   'spectrum': '#1eb264',
#   'hue': 'Grey',
#   'percent': 0.05047619047619047,
#   'css3': '#000000'},
#  {'objectid': 228240,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.0480672268907563,
#   'css3': '#000000'},
#  {'objectid': 228240,
#   'color': '#afafaf',
#   'spectrum': '#8c5fa8',
#   'hue': 'Grey',
#   'percent': 0.03613445378151261,
#   'css3': '#a9a9a9'},
#  {'objectid': 228243,
#   'color': '#e1e1e1',
#   'spectrum': '#955ba5',
#   'hue': 'Grey',
#   'percent': 0.214,
#   'css3': '#dcdcdc'},
#  {'objectid': 228243,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.16855555555555554,
#   'css3': '#000000'},
#  {'objectid': 228243,
#   'color': '#c8c8c8',
#   'spectrum': '#8c5fa8',
#   'hue': 'Grey',
#   'percent': 0.14394444444444446,
#   'css3': '#c0c0c0'},
#  {'objectid': 228243,
#   'color': '#7d7d7d',
#   'spectrum': '#8362aa',
#   'hue': 'Grey',
#   'percent': 0.13516666666666666,
#   'css3': '#808080'},
#  {'objectid': 228243,
#   'color': '#fafafa',
#   'spectrum': '#955ba5',
#   'hue': 'White',
#   'percent': 0.10977777777777778,
#   'css3': '#fffafa'},
#  {'objectid': 228243,
#   'color': '#969696',
#   'spectrum': '#8761aa',
#   'hue': 'Grey',
#   'percent': 0.10511111111111111,
#   'css3': '#a9a9a9'},
#  {'objectid': 228243,
#   'color': '#afafaf',
#   'spectrum': '#8c5fa8',
#   'hue': 'Grey',
#   'percent': 0.06544444444444444,
#   'css3': '#a9a9a9'},
#  {'objectid': 228243,
#   'color': '#4b4b4b',
#   'spectrum': '#3db657',
#   'hue': 'Grey',
#   'percent': 0.058,
#   'css3': '#2f4f4f'},
#  {'objectid': 228244,
#   'color': '#e1e1e1',
#   'spectrum': '#955ba5',
#   'hue': 'Grey',
#   'percent': 0.26316666666666666,
#   'css3': '#dcdcdc'},
#  {'objectid': 228244,
#   'color': '#c8c8c8',
#   'spectrum': '#8c5fa8',
#   'hue': 'Grey',
#   'percent': 0.15116666666666667,
#   'css3': '#c0c0c0'},
#  {'objectid': 228244,
#   'color': '#646464',
#   'spectrum': '#7866ad',
#   'hue': 'Grey',
#   'percent': 0.12566666666666668,
#   'css3': '#696969'},
#  {'objectid': 228244,
#   'color': '#7d7d7d',
#   'spectrum': '#8362aa',
#   'hue': 'Grey',
#   'percent': 0.12116666666666667,
#   'css3': '#808080'},
#  {'objectid': 228244,
#   'color': '#969696',
#   'spectrum': '#8761aa',
#   'hue': 'Grey',
#   'percent': 0.08738888888888889,
#   'css3': '#a9a9a9'},
#  {'objectid': 228244,
#   'color': '#4b4b4b',
#   'spectrum': '#3db657',
#   'hue': 'Grey',
#   'percent': 0.0816111111111111,
#   'css3': '#2f4f4f'},
#  {'objectid': 228244,
#   'color': '#323232',
#   'spectrum': '#2eb45d',
#   'hue': 'Grey',
#   'percent': 0.04477777777777778,
#   'css3': '#2f4f4f'},
#  {'objectid': 228244,
#   'color': '#afafaf',
#   'spectrum': '#8c5fa8',
#   'hue': 'Grey',
#   'percent': 0.041055555555555553,
#   'css3': '#a9a9a9'},
#  {'objectid': 228244,
#   'color': '#fafafa',
#   'spectrum': '#955ba5',
#   'hue': 'White',
#   'percent': 0.03716666666666667,
#   'css3': '#fffafa'},
#  {'objectid': 228244,
#   'color': '#191919',
#   'spectrum': '#1eb264',
#   'hue': 'Grey',
#   'percent': 0.02422222222222222,
#   'css3': '#000000'},
#  {'objectid': 228252,
#   'color': '#323232',
#   'spectrum': '#2eb45d',
#   'hue': 'Grey',
#   'percent': 0.2534435261707989,
#   'css3': '#2f4f4f'},
#  {'objectid': 228252,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.2503030303030303,
#   'css3': '#000000'},
#  {'objectid': 228252,
#   'color': '#191919',
#   'spectrum': '#1eb264',
#   'hue': 'Grey',
#   'percent': 0.21261707988980716,
#   'css3': '#000000'},
#  {'objectid': 228252,
#   'color': '#c8c8c8',
#   'spectrum': '#8c5fa8',
#   'hue': 'Grey',
#   'percent': 0.10584022038567494,
#   'css3': '#c0c0c0'},
#  {'objectid': 228252,
#   'color': '#4b4b4b',
#   'spectrum': '#3db657',
#   'hue': 'Grey',
#   'percent': 0.07581267217630853,
#   'css3': '#2f4f4f'},
#  {'objectid': 228252,
#   'color': '#afafaf',
#   'spectrum': '#8c5fa8',
#   'hue': 'Grey',
#   'percent': 0.07140495867768595,
#   'css3': '#a9a9a9'},
#  {'objectid': 228252,
#   'color': '#fafafa',
#   'spectrum': '#955ba5',
#   'hue': 'White',
#   'percent': 0.030578512396694214,
#   'css3': '#fffafa'},
#  {'objectid': 228256,
#   'color': '#966432',
#   'spectrum': '#e46867',
#   'hue': 'Orange',
#   'percent': 0.2219047619047619,
#   'css3': '#a0522d'},
#  {'objectid': 228256,
#   'color': '#af967d',
#   'spectrum': '#c25687',
#   'hue': 'Brown',
#   'percent': 0.16577380952380952,
#   'css3': '#bc8f8f'},
#  {'objectid': 228256,
#   'color': '#e1c896',
#   'spectrum': '#ed765a',
#   'hue': 'Yellow',
#   'percent': 0.13214285714285715,
#   'css3': '#deb887'},
#  {'objectid': 228256,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.11196428571428571,
#   'css3': '#556b2f'},
#  {'objectid': 228256,
#   'color': '#4b1900',
#   'spectrum': '#59ba4a',
#   'hue': 'Red',
#   'percent': 0.11172619047619048,
#   'css3': '#800000'},
#  {'objectid': 228256,
#   'color': '#4b3219',
#   'spectrum': '#4ab851',
#   'hue': 'Brown',
#   'percent': 0.07404761904761904,
#   'css3': '#556b2f'},
#  {'objectid': 228256,
#   'color': '#af7d4b',
#   'spectrum': '#e9715f',
#   'hue': 'Yellow',
#   'percent': 0.045059523809523806,
#   'css3': '#cd853f'},
#  {'objectid': 228256,
#   'color': '#7d4b19',
#   'spectrum': '#6cbd45',
#   'hue': 'Brown',
#   'percent': 0.04327380952380953,
#   'css3': '#8b4513'},
#  {'objectid': 228256,
#   'color': '#323232',
#   'spectrum': '#2eb45d',
#   'hue': 'Grey',
#   'percent': 0.03488095238095238,
#   'css3': '#2f4f4f'},
#  {'objectid': 228256,
#   'color': '#191919',
#   'spectrum': '#1eb264',
#   'hue': 'Grey',
#   'percent': 0.025416666666666667,
#   'css3': '#000000'},
#  {'objectid': 228257,
#   'color': '#323232',
#   'spectrum': '#2eb45d',
#   'hue': 'Grey',
#   'percent': 0.22481792717086835,
#   'css3': '#2f4f4f'},
#  {'objectid': 228257,
#   'color': '#191919',
#   'spectrum': '#1eb264',
#   'hue': 'Grey',
#   'percent': 0.15221288515406162,
#   'css3': '#000000'},
#  {'objectid': 228257,
#   'color': '#afafaf',
#   'spectrum': '#8c5fa8',
#   'hue': 'Grey',
#   'percent': 0.13977591036414566,
#   'css3': '#a9a9a9'},
#  {'objectid': 228257,
#   'color': '#4b4b4b',
#   'spectrum': '#3db657',
#   'hue': 'Grey',
#   'percent': 0.10095238095238095,
#   'css3': '#2f4f4f'},
#  {'objectid': 228257,
#   'color': '#c8c8c8',
#   'spectrum': '#8c5fa8',
#   'hue': 'Grey',
#   'percent': 0.09983193277310924,
#   'css3': '#c0c0c0'},
#  {'objectid': 228257,
#   'color': '#969696',
#   'spectrum': '#8761aa',
#   'hue': 'Grey',
#   'percent': 0.07719887955182073,
#   'css3': '#a9a9a9'},
#  {'objectid': 228257,
#   'color': '#646464',
#   'spectrum': '#7866ad',
#   'hue': 'Grey',
#   'percent': 0.06862745098039216,
#   'css3': '#696969'},
#  {'objectid': 228257,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.06605042016806723,
#   'css3': '#000000'},
#  {'objectid': 228257,
#   'color': '#7d7d7d',
#   'spectrum': '#8362aa',
#   'hue': 'Grey',
#   'percent': 0.06549019607843137,
#   'css3': '#808080'},
#  {'objectid': 228257,
#   'color': '#fafafa',
#   'spectrum': '#955ba5',
#   'hue': 'White',
#   'percent': 0.005042016806722689,
#   'css3': '#fffafa'},
#  {'objectid': 228258,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.3308831908831909,
#   'css3': '#000000'},
#  {'objectid': 228258,
#   'color': '#191900',
#   'spectrum': '#2eb45d',
#   'hue': 'Brown',
#   'percent': 0.28507122507122507,
#   'css3': '#000000'},
#  {'objectid': 228258,
#   'color': '#7d6432',
#   'spectrum': '#6cbd45',
#   'hue': 'Yellow',
#   'percent': 0.15373219373219374,
#   'css3': '#a0522d'},
#  {'objectid': 228258,
#   'color': '#190000',
#   'spectrum': '#2eb45d',
#   'hue': 'Black',
#   'percent': 0.09111111111111111,
#   'css3': '#000000'},
#  {'objectid': 228258,
#   'color': '#644b19',
#   'spectrum': '#64bc46',
#   'hue': 'Orange',
#   'percent': 0.06421652421652421,
#   'css3': '#8b4513'},
#  {'objectid': 228258,
#   'color': '#967d4b',
#   'spectrum': '#7fc241',
#   'hue': 'Brown',
#   'percent': 0.048547008547008545,
#   'css3': '#a0522d'},
#  {'objectid': 228258,
#   'color': '#7d6400',
#   'spectrum': '#6ebe44',
#   'hue': 'Green',
#   'percent': 0.013903133903133903,
#   'css3': '#808000'},
#  {'objectid': 228258,
#   'color': '#7d9696',
#   'spectrum': '#7069af',
#   'hue': 'Green',
#   'percent': 0.010427350427350428,
#   'css3': '#778899'},
#  {'objectid': 228258,
#   'color': '#af964b',
#   'spectrum': '#9ecb3b',
#   'hue': 'Yellow',
#   'percent': 0.002108262108262108,
#   'css3': '#cd853f'},
#  {'objectid': 228259,
#   'color': '#964b19',
#   'spectrum': '#e46867',
#   'hue': 'Brown',
#   'percent': 0.3889567430025445,
#   'css3': '#8b4513'},
#  {'objectid': 228259,
#   'color': '#643219',
#   'spectrum': '#59ba4a',
#   'hue': 'Brown',
#   'percent': 0.19440203562340966,
#   'css3': '#8b4513'},
#  {'objectid': 228259,
#   'color': '#af6432',
#   'spectrum': '#e9715f',
#   'hue': 'Orange',
#   'percent': 0.14142493638676845,
#   'css3': '#a0522d'},
#  {'objectid': 228259,
#   'color': '#4b1919',
#   'spectrum': '#4ab851',
#   'hue': 'Red',
#   'percent': 0.11363867684478371,
#   'css3': '#800000'},
#  {'objectid': 228259,
#   'color': '#c87d4b',
#   'spectrum': '#ed7758',
#   'hue': 'Brown',
#   'percent': 0.08188295165394402,
#   'css3': '#cd853f'},
#  {'objectid': 228259,
#   'color': '#191919',
#   'spectrum': '#1eb264',
#   'hue': 'Grey',
#   'percent': 0.05821882951653944,
#   'css3': '#000000'},
#  {'objectid': 228259,
#   'color': '#7d644b',
#   'spectrum': '#b25593',
#   'hue': 'Yellow',
#   'percent': 0.02127226463104326,
#   'css3': '#696969'},
#  {'objectid': 228259,
#   'color': '#e1c8af',
#   'spectrum': '#e9715f',
#   'hue': 'Orange',
#   'percent': 0.00010178117048346055,
#   'css3': '#f5deb3'},
#  {'objectid': 228259,
#   'color': '#c8afaf',
#   'spectrum': '#b55592',
#   'hue': 'Red',
#   'percent': 0.00010178117048346055,
#   'css3': '#c0c0c0'},
#  {'objectid': 228261,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.3650406504065041,
#   'css3': '#556b2f'},
#  {'objectid': 228261,
#   'color': '#191919',
#   'spectrum': '#1eb264',
#   'hue': 'Grey',
#   'percent': 0.2408130081300813,
#   'css3': '#000000'},
#  {'objectid': 228261,
#   'color': '#323219',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.1419512195121951,
#   'css3': '#2f4f4f'},
#  {'objectid': 228261,
#   'color': '#64644b',
#   'spectrum': '#59ba4a',
#   'hue': 'Green',
#   'percent': 0.12601626016260162,
#   'css3': '#696969'},
#  {'objectid': 228261,
#   'color': '#af967d',
#   'spectrum': '#c25687',
#   'hue': 'Brown',
#   'percent': 0.06487804878048781,
#   'css3': '#bc8f8f'},
#  {'objectid': 228261,
#   'color': '#7d7d64',
#   'spectrum': '#6cbd45',
#   'hue': 'Yellow',
#   'percent': 0.06130081300813008,
#   'css3': '#808080'},
#  {'objectid': 228264,
#   'color': '#fafafa',
#   'spectrum': '#955ba5',
#   'hue': 'White',
#   'percent': 0.4492997198879552,
#   'css3': '#fffafa'},
#  {'objectid': 228264,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.27372549019607845,
#   'css3': '#000000'},
#  {'objectid': 228264,
#   'color': '#191919',
#   'spectrum': '#1eb264',
#   'hue': 'Grey',
#   'percent': 0.19428571428571428,
#   'css3': '#000000'},
#  {'objectid': 228264,
#   'color': '#323232',
#   'spectrum': '#2eb45d',
#   'hue': 'Grey',
#   'percent': 0.0826890756302521,
#   'css3': '#2f4f4f'},
#  {'objectid': 228266,
#   'color': '#191919',
#   'spectrum': '#1eb264',
#   'hue': 'Grey',
#   'percent': 0.2511304347826087,
#   'css3': '#000000'},
#  {'objectid': 228266,
#   'color': '#7d4b32',
#   'spectrum': '#c25687',
#   'hue': 'Brown',
#   'percent': 0.16608695652173913,
#   'css3': '#8b4513'},
#  {'objectid': 228266,
#   'color': '#966432',
#   'spectrum': '#e46867',
#   'hue': 'Orange',
#   'percent': 0.1343768115942029,
#   'css3': '#a0522d'},
#  {'objectid': 228266,
#   'color': '#c83232',
#   'spectrum': '#dd5872',
#   'hue': 'Brown',
#   'percent': 0.11634782608695653,
#   'css3': '#b22222'},
#  {'objectid': 228266,
#   'color': '#4b3219',
#   'spectrum': '#4ab851',
#   'hue': 'Brown',
#   'percent': 0.09089855072463768,
#   'css3': '#556b2f'},
#  {'objectid': 228266,
#   'color': '#af7d4b',
#   'spectrum': '#e9715f',
#   'hue': 'Yellow',
#   'percent': 0.06086956521739131,
#   'css3': '#cd853f'},
#  {'objectid': 228266,
#   'color': '#961919',
#   'spectrum': '#d75776',
#   'hue': 'Orange',
#   'percent': 0.06046376811594203,
#   'css3': '#a52a2a'},
#  {'objectid': 228266,
#   'color': '#c8af7d',
#   'spectrum': '#e9715f',
#   'hue': 'Brown',
#   'percent': 0.043130434782608695,
#   'css3': '#d2b48c'},
#  {'objectid': 228266,
#   'color': '#c89664',
#   'spectrum': '#ed7758',
#   'hue': 'Brown',
#   'percent': 0.03982608695652174,
#   'css3': '#bdb76b'},
#  {'objectid': 228266,
#   'color': '#e1c8af',
#   'spectrum': '#e9715f',
#   'hue': 'Orange',
#   'percent': 0.035710144927536235,
#   'css3': '#f5deb3'},
#  {'objectid': 228267,
#   'color': '#fafafa',
#   'spectrum': '#955ba5',
#   'hue': 'White',
#   'percent': 0.38033333333333336,
#   'css3': '#fffafa'},
#  {'objectid': 228267,
#   'color': '#e1e1e1',
#   'spectrum': '#955ba5',
#   'hue': 'Grey',
#   'percent': 0.306,
#   'css3': '#dcdcdc'},
#  {'objectid': 228267,
#   'color': '#c8c8c8',
#   'spectrum': '#8c5fa8',
#   'hue': 'Grey',
#   'percent': 0.0795,
#   'css3': '#c0c0c0'},
#  {'objectid': 228267,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.06533333333333333,
#   'css3': '#000000'},
#  {'objectid': 228267,
#   'color': '#969696',
# ...
#   'css3': '#000000'},
#  {'objectid': 228407,
#   'color': '#646464',
#   'spectrum': '#7866ad',
#   'hue': 'Grey',
#   'percent': 0.17098039215686275,
#   'css3': '#696969'},
#  {'objectid': 228407,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.06696078431372549,
#   'css3': '#556b2f'},
#  {'objectid': 228407,
#   'color': '#fae1e1',
#   'spectrum': '#e76d63',
#   'hue': 'Red',
#   'percent': 0.037941176470588235,
#   'css3': '#ffe4e1'},
#  {'objectid': 228407,
#   'color': '#96967d',
#   'spectrum': '#8e5ea7',
#   'hue': 'Green',
#   'percent': 0.03754901960784314,
#   'css3': '#808080'},
#  {'objectid': 228407,
#   'color': '#e1c8af',
#   'spectrum': '#e9715f',
#   'hue': 'Orange',
#   'percent': 0.032058823529411765,
#   'css3': '#f5deb3'},
#  {'objectid': 228407,
#   'color': '#c8af96',
#   'spectrum': '#e66c64',
#   'hue': 'Brown',
#   'percent': 0.031568627450980394,
#   'css3': '#d2b48c'},
#  {'objectid': 228407,
#   'color': '#643219',
#   'spectrum': '#59ba4a',
#   'hue': 'Brown',
#   'percent': 0.0013725490196078432,
#   'css3': '#8b4513'},
#  {'objectid': 228408,
#   'color': '#643232',
#   'spectrum': '#ae5596',
#   'hue': 'Red',
#   'percent': 0.9170319634703197,
#   'css3': '#8b4513'},
#  {'objectid': 228408,
#   'color': '#4b4b4b',
#   'spectrum': '#3db657',
#   'hue': 'Grey',
#   'percent': 0.047123287671232875,
#   'css3': '#2f4f4f'},
#  {'objectid': 228408,
#   'color': '#af1932',
#   'spectrum': '#d75776',
#   'hue': 'Red',
#   'percent': 0.035799086757990865,
#   'css3': '#b22222'},
#  {'objectid': 228408,
#   'color': '#967d7d',
#   'spectrum': '#955ba5',
#   'hue': 'Brown',
#   'percent': 4.5662100456621006e-05,
#   'css3': '#808080'},
#  {'objectid': 228410,
#   'color': '#e1c896',
#   'spectrum': '#ed765a',
#   'hue': 'Yellow',
#   'percent': 0.24993333333333334,
#   'css3': '#deb887'},
#  {'objectid': 228410,
#   'color': '#646464',
#   'spectrum': '#7866ad',
#   'hue': 'Grey',
#   'percent': 0.21366666666666667,
#   'css3': '#696969'},
#  {'objectid': 228410,
#   'color': '#c8af96',
#   'spectrum': '#e66c64',
#   'hue': 'Brown',
#   'percent': 0.18073333333333333,
#   'css3': '#d2b48c'},
#  {'objectid': 228410,
#   'color': '#967d7d',
#   'spectrum': '#955ba5',
#   'hue': 'Brown',
#   'percent': 0.12366666666666666,
#   'css3': '#808080'},
#  {'objectid': 228410,
#   'color': '#af967d',
#   'spectrum': '#c25687',
#   'hue': 'Brown',
#   'percent': 0.09353333333333333,
#   'css3': '#bc8f8f'},
#  {'objectid': 228410,
#   'color': '#4b4b4b',
#   'spectrum': '#3db657',
#   'hue': 'Grey',
#   'percent': 0.09086666666666667,
#   'css3': '#2f4f4f'},
#  {'objectid': 228410,
#   'color': '#323232',
#   'spectrum': '#2eb45d',
#   'hue': 'Grey',
#   'percent': 0.0476,
#   'css3': '#2f4f4f'},
#  {'objectid': 228413,
#   'color': '#c8c8c8',
#   'spectrum': '#8c5fa8',
#   'hue': 'Grey',
#   'percent': 0.23122222222222222,
#   'css3': '#c0c0c0'},
#  {'objectid': 228413,
#   'color': '#afafaf',
#   'spectrum': '#8c5fa8',
#   'hue': 'Grey',
#   'percent': 0.18638888888888888,
#   'css3': '#a9a9a9'},
#  {'objectid': 228413,
#   'color': '#646464',
#   'spectrum': '#7866ad',
#   'hue': 'Grey',
#   'percent': 0.1497777777777778,
#   'css3': '#696969'},
#  {'objectid': 228413,
#   'color': '#7d7d7d',
#   'spectrum': '#8362aa',
#   'hue': 'Grey',
#   'percent': 0.1485,
#   'css3': '#808080'},
#  {'objectid': 228413,
#   'color': '#969696',
#   'spectrum': '#8761aa',
#   'hue': 'Grey',
#   'percent': 0.07583333333333334,
#   'css3': '#a9a9a9'},
#  {'objectid': 228413,
#   'color': '#4b4b4b',
#   'spectrum': '#3db657',
#   'hue': 'Grey',
#   'percent': 0.058722222222222224,
#   'css3': '#2f4f4f'},
#  {'objectid': 228413,
#   'color': '#323232',
#   'spectrum': '#2eb45d',
#   'hue': 'Grey',
#   'percent': 0.05433333333333333,
#   'css3': '#2f4f4f'},
#  {'objectid': 228413,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.04733333333333333,
#   'css3': '#000000'},
#  {'objectid': 228413,
#   'color': '#e1e1e1',
#   'spectrum': '#955ba5',
#   'hue': 'Grey',
#   'percent': 0.04094444444444444,
#   'css3': '#dcdcdc'},
#  {'objectid': 228413,
#   'color': '#fafafa',
#   'spectrum': '#955ba5',
#   'hue': 'White',
#   'percent': 0.006944444444444444,
#   'css3': '#fffafa'},
#  {'objectid': 228418,
#   'color': '#c8c8c8',
#   'spectrum': '#8c5fa8',
#   'hue': 'Grey',
#   'percent': 0.5355128205128206,
#   'css3': '#c0c0c0'},
#  {'objectid': 228418,
#   'color': '#7d7d7d',
#   'spectrum': '#8362aa',
#   'hue': 'Grey',
#   'percent': 0.10416666666666667,
#   'css3': '#808080'},
#  {'objectid': 228418,
#   'color': '#4b4b4b',
#   'spectrum': '#3db657',
#   'hue': 'Grey',
#   'percent': 0.09987179487179487,
#   'css3': '#2f4f4f'},
#  {'objectid': 228418,
#   'color': '#646464',
#   'spectrum': '#7866ad',
#   'hue': 'Grey',
#   'percent': 0.09647435897435898,
#   'css3': '#696969'},
#  {'objectid': 228418,
#   'color': '#323232',
#   'spectrum': '#2eb45d',
#   'hue': 'Grey',
#   'percent': 0.0714102564102564,
#   'css3': '#2f4f4f'},
#  {'objectid': 228418,
#   'color': '#969696',
#   'spectrum': '#8761aa',
#   'hue': 'Grey',
#   'percent': 0.044743589743589746,
#   'css3': '#a9a9a9'},
#  {'objectid': 228418,
#   'color': '#191919',
#   'spectrum': '#1eb264',
#   'hue': 'Grey',
#   'percent': 0.030705128205128204,
#   'css3': '#000000'},
#  {'objectid': 228418,
#   'color': '#afafaf',
#   'spectrum': '#8c5fa8',
#   'hue': 'Grey',
#   'percent': 0.013012820512820513,
#   'css3': '#a9a9a9'},
#  {'objectid': 228418,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.0041025641025641026,
#   'css3': '#000000'},
#  {'objectid': 228423,
#   'color': '#323219',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.3183030303030303,
#   'css3': '#2f4f4f'},
#  {'objectid': 228423,
#   'color': '#4b4b32',
#   'spectrum': '#4ab851',
#   'hue': 'Green',
#   'percent': 0.19436363636363638,
#   'css3': '#556b2f'},
#  {'objectid': 228423,
#   'color': '#191919',
#   'spectrum': '#1eb264',
#   'hue': 'Grey',
#   'percent': 0.19418181818181818,
#   'css3': '#000000'},
#  {'objectid': 228423,
#   'color': '#64644b',
#   'spectrum': '#59ba4a',
#   'hue': 'Green',
#   'percent': 0.13793939393939394,
#   'css3': '#696969'},
#  {'objectid': 228423,
#   'color': '#7d7d64',
#   'spectrum': '#6cbd45',
#   'hue': 'Yellow',
#   'percent': 0.12006060606060606,
#   'css3': '#808080'},
#  {'objectid': 228423,
#   'color': '#967d4b',
#   'spectrum': '#7fc241',
#   'hue': 'Brown',
#   'percent': 0.024969696969696968,
#   'css3': '#a0522d'},
#  {'objectid': 228423,
#   'color': '#af964b',
#   'spectrum': '#9ecb3b',
#   'hue': 'Yellow',
#   'percent': 0.01006060606060606,
#   'css3': '#cd853f'},
#  {'objectid': 228423,
#   'color': '#afaf96',
#   'spectrum': '#8e5ea7',
#   'hue': 'Green',
#   'percent': 0.00012121212121212121,
#   'css3': '#a9a9a9'},
#  {'objectid': 228426,
#   'color': '#4b4b4b',
#   'spectrum': '#3db657',
#   'hue': 'Grey',
#   'percent': 0.15887005649717514,
#   'css3': '#2f4f4f'},
#  {'objectid': 228426,
#   'color': '#646464',
#   'spectrum': '#7866ad',
#   'hue': 'Grey',
#   'percent': 0.14949152542372882,
#   'css3': '#696969'},
#  {'objectid': 228426,
#   'color': '#7d7d7d',
#   'spectrum': '#8362aa',
#   'hue': 'Grey',
#   'percent': 0.14005649717514124,
#   'css3': '#808080'},
#  {'objectid': 228426,
#   'color': '#323232',
#   'spectrum': '#2eb45d',
#   'hue': 'Grey',
#   'percent': 0.1316949152542373,
#   'css3': '#2f4f4f'},
#  {'objectid': 228426,
#   'color': '#c8c8c8',
#   'spectrum': '#8c5fa8',
#   'hue': 'Grey',
#   'percent': 0.12163841807909605,
#   'css3': '#c0c0c0'},
#  {'objectid': 228426,
#   'color': '#969696',
#   'spectrum': '#8761aa',
#   'hue': 'Grey',
#   'percent': 0.09350282485875706,
#   'css3': '#a9a9a9'},
#  {'objectid': 228426,
#   'color': '#afafaf',
#   'spectrum': '#8c5fa8',
#   'hue': 'Grey',
#   'percent': 0.073954802259887,
#   'css3': '#a9a9a9'},
#  {'objectid': 228426,
#   'color': '#191919',
#   'spectrum': '#1eb264',
#   'hue': 'Grey',
#   'percent': 0.04807909604519774,
#   'css3': '#000000'},
#  {'objectid': 228426,
#   'color': '#e1e1e1',
#   'spectrum': '#955ba5',
#   'hue': 'Grey',
#   'percent': 0.0431638418079096,
#   'css3': '#dcdcdc'},
#  {'objectid': 228426,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.03016949152542373,
#   'css3': '#000000'},
#  {'objectid': 228427,
#   'color': '#191919',
#   'spectrum': '#1eb264',
#   'hue': 'Grey',
#   'percent': 0.5969647696476965,
#   'css3': '#000000'},
#  {'objectid': 228427,
#   'color': '#4b3219',
#   'spectrum': '#4ab851',
#   'hue': 'Brown',
#   'percent': 0.33094850948509485,
#   'css3': '#556b2f'},
#  {'objectid': 228427,
#   'color': '#644b32',
#   'spectrum': '#59ba4a',
#   'hue': 'Brown',
#   'percent': 0.05685636856368564,
#   'css3': '#556b2f'},
#  {'objectid': 228427,
#   'color': '#7d644b',
#   'spectrum': '#b25593',
#   'hue': 'Yellow',
#   'percent': 0.014634146341463415,
#   'css3': '#696969'},
#  {'objectid': 228427,
#   'color': '#967d4b',
#   'spectrum': '#7fc241',
#   'hue': 'Brown',
#   'percent': 0.0005962059620596206,
#   'css3': '#a0522d'},
#  {'objectid': 228437,
#   'color': '#afafaf',
#   'spectrum': '#8c5fa8',
#   'hue': 'Grey',
#   'percent': 0.2415686274509804,
#   'css3': '#a9a9a9'},
#  {'objectid': 228437,
#   'color': '#969696',
#   'spectrum': '#8761aa',
#   'hue': 'Grey',
#   'percent': 0.23427450980392156,
#   'css3': '#a9a9a9'},
#  {'objectid': 228437,
#   'color': '#c8c8c8',
#   'spectrum': '#8c5fa8',
#   'hue': 'Grey',
#   'percent': 0.22133333333333333,
#   'css3': '#c0c0c0'},
#  {'objectid': 228437,
#   'color': '#e1e1e1',
#   'spectrum': '#955ba5',
#   'hue': 'Grey',
#   'percent': 0.09709803921568627,
#   'css3': '#dcdcdc'},
#  {'objectid': 228437,
#   'color': '#7d7d7d',
#   'spectrum': '#8362aa',
#   'hue': 'Grey',
#   'percent': 0.07411764705882352,
#   'css3': '#808080'},
#  {'objectid': 228437,
#   'color': '#646464',
#   'spectrum': '#7866ad',
#   'hue': 'Grey',
#   'percent': 0.06643137254901961,
#   'css3': '#696969'},
#  {'objectid': 228437,
#   'color': '#323232',
#   'spectrum': '#2eb45d',
#   'hue': 'Grey',
#   'percent': 0.025176470588235293,
#   'css3': '#2f4f4f'},
#  {'objectid': 228437,
#   'color': '#4b4b4b',
#   'spectrum': '#3db657',
#   'hue': 'Grey',
#   'percent': 0.025019607843137254,
#   'css3': '#2f4f4f'},
#  {'objectid': 228437,
#   'color': '#fafafa',
#   'spectrum': '#955ba5',
#   'hue': 'White',
#   'percent': 0.014980392156862745,
#   'css3': '#fffafa'},
#  {'objectid': 228438,
#   'color': '#4b3219',
#   'spectrum': '#4ab851',
#   'hue': 'Brown',
#   'percent': 0.44497354497354497,
#   'css3': '#556b2f'},
#  {'objectid': 228438,
#   'color': '#321919',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.37232804232804234,
#   'css3': '#000000'},
#  {'objectid': 228438,
#   'color': '#af7d4b',
#   'spectrum': '#e9715f',
#   'hue': 'Yellow',
#   'percent': 0.05407407407407407,
#   'css3': '#cd853f'},
#  {'objectid': 228438,
#   'color': '#c89664',
#   'spectrum': '#ed7758',
#   'hue': 'Brown',
#   'percent': 0.048624338624338626,
#   'css3': '#bdb76b'},
#  {'objectid': 228438,
#   'color': '#966432',
#   'spectrum': '#e46867',
#   'hue': 'Orange',
#   'percent': 0.04465608465608466,
#   'css3': '#a0522d'},
#  {'objectid': 228438,
#   'color': '#e1c896',
#   'spectrum': '#ed765a',
#   'hue': 'Yellow',
#   'percent': 0.02164021164021164,
#   'css3': '#deb887'},
#  {'objectid': 228438,
#   'color': '#e1af7d',
#   'spectrum': '#ef7a55',
#   'hue': 'Orange',
#   'percent': 0.012222222222222223,
#   'css3': '#deb887'},
#  {'objectid': 228438,
#   'color': '#afaf96',
#   'spectrum': '#8e5ea7',
#   'hue': 'Green',
#   'percent': 0.000582010582010582,
#   'css3': '#a9a9a9'},
#  {'objectid': 228438,
#   'color': '#fac864',
#   'spectrum': '#f9a132',
#   'hue': 'Yellow',
#   'percent': 0.0005291005291005291,
#   'css3': '#f4a460'},
#  {'objectid': 228438,
#   'color': '#c83219',
#   'spectrum': '#e46867',
#   'hue': 'Orange',
#   'percent': 0.00037037037037037035,
#   'css3': '#b22222'},
#  {'objectid': 228439,
#   'color': '#646464',
#   'spectrum': '#7866ad',
#   'hue': 'Grey',
#   'percent': 0.28836158192090394,
#   'css3': '#696969'},
#  {'objectid': 228439,
#   'color': '#4b4b4b',
#   'spectrum': '#3db657',
#   'hue': 'Grey',
#   'percent': 0.2390960451977401,
#   'css3': '#2f4f4f'},
#  {'objectid': 228439,
#   'color': '#7d7d7d',
#   'spectrum': '#8362aa',
#   'hue': 'Grey',
#   'percent': 0.1003954802259887,
#   'css3': '#808080'},
#  {'objectid': 228439,
#   'color': '#e1e1e1',
#   'spectrum': '#955ba5',
#   'hue': 'Grey',
#   'percent': 0.08163841807909604,
#   'css3': '#dcdcdc'},
#  {'objectid': 228439,
#   'color': '#323232',
#   'spectrum': '#2eb45d',
#   'hue': 'Grey',
#   'percent': 0.06531073446327684,
#   'css3': '#2f4f4f'},
#  {'objectid': 228439,
#   'color': '#c8c8c8',
#   'spectrum': '#8c5fa8',
#   'hue': 'Grey',
#   'percent': 0.05887005649717514,
#   'css3': '#c0c0c0'},
#  {'objectid': 228439,
#   'color': '#fafafa',
#   'spectrum': '#955ba5',
#   'hue': 'White',
#   'percent': 0.04418079096045198,
#   'css3': '#fffafa'},
#  {'objectid': 228439,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.0431638418079096,
#   'css3': '#000000'},
#  {'objectid': 228439,
#   'color': '#afafaf',
#   'spectrum': '#8c5fa8',
#   'hue': 'Grey',
#   'percent': 0.03977401129943503,
#   'css3': '#a9a9a9'},
#  {'objectid': 228439,
#   'color': '#969696',
#   'spectrum': '#8761aa',
#   'hue': 'Grey',
#   'percent': 0.0392090395480226,
#   'css3': '#a9a9a9'},
#  {'objectid': 228440,
#   'color': '#644b00',
#   'spectrum': '#64bc46',
#   'hue': 'Brown',
#   'percent': 0.41587786259541987,
#   'css3': '#8b4513'},
#  {'objectid': 228440,
#   'color': '#4b3200',
#   'spectrum': '#59ba4a',
#   'hue': 'Brown',
#   'percent': 0.2683969465648855,
#   'css3': '#8b4513'},
#  {'objectid': 228440,
#   'color': '#af7d4b',
#   'spectrum': '#e9715f',
#   'hue': 'Yellow',
#   'percent': 0.14524173027989823,
#   'css3': '#cd853f'},
#  {'objectid': 228440,
#   'color': '#321900',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.09022900763358778,
#   'css3': '#000000'},
#  {'objectid': 228440,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.05201017811704835,
#   'css3': '#000000'},
#  {'objectid': 228440,
#   'color': '#7d7d7d',
#   'spectrum': '#8362aa',
#   'hue': 'Grey',
#   'percent': 0.019491094147582697,
#   'css3': '#808080'},
#  {'objectid': 228440,
#   'color': '#c89632',
#   'spectrum': '#f79738',
#   'hue': 'Yellow',
#   'percent': 0.005139949109414758,
#   'css3': '#cd853f'},
#  {'objectid': 228440,
#   'color': '#e1af64',
#   'spectrum': '#f6903d',
#   'hue': 'Yellow',
#   'percent': 0.00361323155216285,
#   'css3': '#f4a460'},
#  {'objectid': 228441,
#   'color': '#fafafa',
#   'spectrum': '#955ba5',
#   'hue': 'White',
#   'percent': 0.29058823529411765,
#   'css3': '#fffafa'},
#  {'objectid': 228441,
#   'color': '#4b4b4b',
#   'spectrum': '#3db657',
#   'hue': 'Grey',
#   'percent': 0.1438655462184874,
#   'css3': '#2f4f4f'},
#  {'objectid': 228441,
#   'color': '#e1e1e1',
#   'spectrum': '#955ba5',
#   'hue': 'Grey',
#   'percent': 0.11848739495798319,
#   'css3': '#dcdcdc'},
#  {'objectid': 228441,
#   'color': '#323232',
#   'spectrum': '#2eb45d',
#   'hue': 'Grey',
#   'percent': 0.1165266106442577,
#   'css3': '#2f4f4f'},
#  {'objectid': 228441,
#   'color': '#646464',
#   'spectrum': '#7866ad',
#   'hue': 'Grey',
#   'percent': 0.10067226890756302,
#   'css3': '#696969'},
#  {'objectid': 228441,
#   'color': '#191919',
#   'spectrum': '#1eb264',
#   'hue': 'Grey',
#   'percent': 0.08789915966386555,
#   'css3': '#000000'},
#  {'objectid': 228441,
#   'color': '#c8c8c8',
#   'spectrum': '#8c5fa8',
#   'hue': 'Grey',
#   'percent': 0.06425770308123249,
#   'css3': '#c0c0c0'},
#  {'objectid': 228441,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.033893557422969185,
#   'css3': '#000000'},
#  {'objectid': 228441,
#   'color': '#7d7d7d',
#   'spectrum': '#8362aa',
#   'hue': 'Grey',
#   'percent': 0.024201680672268907,
#   'css3': '#808080'},
#  {'objectid': 228441,
#   'color': '#afafaf',
#   'spectrum': '#8c5fa8',
#   'hue': 'Grey',
#   'percent': 0.0196078431372549,
#   'css3': '#a9a9a9'},
#  {'objectid': 228445,
#   'color': '#000000',
#   'spectrum': '#1eb264',
#   'hue': 'Black',
#   'percent': 0.3129262086513995,
#   'css3': '#000000'},
#  {'objectid': 228445,
#   'color': '#4b3219',
#   'spectrum': '#4ab851',
#   'hue': 'Brown',
#   'percent': 0.22590330788804072,
#   'css3': '#556b2f'},
#  {'objectid': 228445,
#   'color': '#321900',
#   'spectrum': '#3db657',
#   'hue': 'Brown',
#   'percent': 0.14692111959287532,
#   'css3': '#000000'},
#  {'objectid': 228445,
#   'color': '#644b19',
#   'spectrum': '#64bc46',
#   'hue': 'Orange',
#   'percent': 0.12931297709923664,
#   'css3': '#8b4513'},
#  {'objectid': 228445,
#   'color': '#64644b',
#   'spectrum': '#59ba4a',
#   'hue': 'Green',
#   'percent': 0.06900763358778626,
#   'css3': '#696969'},
#  ...]

# %%
import mysql.connector

# %%
connection = mysql.connector.connect(
    host='127.0.0.1',
    user='root',
    password='thisisMaryam07'
)

cursor = connection.cursor()
print("MySQL server established")
# Out:
# MySQL server established

# %%
cursor.execute('CREATE DATABASE IF NOT EXISTS harvard_artifacts;')
cursor.execute("USE harvard_artifacts;")
print("Database ready: harvard_artifacts")
# Out:
# Database ready: harvard_artifacts

# %%
# cursor.execute('DROP DATABASE HARVARD_COINS;')
#cursor.execute('DROP DATABASE harvard_paintings;')
#cursor.execute("USE harvard_paintings;")
#print("Database ready: harvard_paintings")

# %%
cursor.execute("""
CREATE TABLE IF NOT EXISTS artifact_metadata (
  id INT PRIMARY KEY,
  title TEXT,
  culture TEXT,
  period TEXT,
  century TEXT,
  medium TEXT,
  dimensions TEXT,
  description TEXT,
  department TEXT,
  classification TEXT,
  accessionyear INT,
  accessionmethod TEXT
);
""")

cursor.execute("""
CREATE TABLE IF NOT EXISTS artifact_media (
  objectid INT PRIMARY KEY,
  imagecount INT,
  mediacount INT,
  colorcount INT,
  rank_value INT,
  datebegin INT,
  dateend INT,
  CONSTRAINT fk1_id FOREIGN KEY (objectid) REFERENCES artifact_metadata(id)
);
""")

cursor.execute("""
CREATE TABLE IF NOT EXISTS artifact_colors (
  objectid INT,
  color TEXT,
  spectrum TEXT,
  hue TEXT,
  percent REAL,
  css3 TEXT,
  CONSTRAINT fk2_id FOREIGN KEY (objectid) REFERENCES artifact_metadata(id)
);
""")

connection.commit()
print("Tables created successfully")
# Out:
# Tables created successfully

# %% [markdown]
# # DELETE tables before inserting

# %%
# Clear old data before inserting again
cursor.execute("DELETE FROM artifact_colors;")
cursor.execute("DELETE FROM artifact_media;")
cursor.execute("DELETE FROM artifact_metadata;")
connection.commit()

print("Tables emptied Ready for fresh insert.")
# Out:
# Tables emptied Ready for fresh insert.

# %%
insert_metadata = """ 
INSERT INTO artifact_metadata ( id, title, culture, period, century, medium, dimensions, description, 
department, classification, accessionyear, accessionmethod ) 
VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s) 
"""

cursor.executemany(insert_metadata, [(
    r.get('id'), 
    r.get('title'), 
    r.get('culture'), 
    r.get('period'), 
    r.get('century'),
    r.get('medium'), 
    r.get('dimensions'), 
    r.get('description'), 
    r.get('department'),
    r.get('classification'), 
    r.get('accessionyear'), 
    r.get('accessionmethod')
) for r in artifact_metadata])
connection.commit()
print("artifact_metadata inserted")
# Out:
# artifact_metadata inserted

# %%
insert_media = """
INSERT INTO artifact_media (
    objectid, imagecount, mediacount, colorcount, rank_value, datebegin, dateend
) VALUES (%s, %s, %s, %s, %s, %s, %s)
"""

cursor.executemany(insert_media, [(
            r.get('objectid'),
            r.get('imagecount'),
            r.get('mediacount'),
            r.get('colorcount'),
            r.get('rank_value'),  
            r.get('datebegin'),
            r.get('dateend')
        )for r in artifact_media])

connection.commit()
print("artifact_media inserted")
# Out:
# artifact_media inserted

# %%
insert_colors = """
INSERT INTO artifact_colors (
    objectid, color, spectrum, hue, percent, css3
) VALUES (%s, %s, %s, %s, %s, %s)
"""

cursor.executemany(insert_colors,[(
            r.get('objectid'),
            r.get('color'),
            r.get('spectrum'),
            r.get('hue'),
            r.get('percent'),
            r.get('css3')
        )for r in artifact_colors])

connection.commit()
print("artifact_colors inserted")
# Out:
# artifact_colors inserted

# %%
import pandas as pd

# Convert lists to DataFrames
df_metadata = pd.DataFrame(artifact_metadata)
df_media = pd.DataFrame(artifact_media)
df_colors = pd.DataFrame(artifact_colors)

# Save as CSV
df_metadata.to_csv("artifact_metadata.csv", index=False)
df_media.to_csv("artifact_media.csv", index=False)
df_colors.to_csv("artifact_colors.csv", index=False)

# %% [markdown]
# # SQL QUERIES

# %% [markdown]
# ### artifact_metadata Table

# %%
cursor.execute("SELECT DISTINCT century FROM artifact_metadata;")
print(cursor.fetchall())

cursor.execute("SELECT DISTINCT culture FROM artifact_metadata;")
print(cursor.fetchall())

# %% [markdown]
# #### 1. List all artifacts from the 11th century belonging to Byzantine culture.

# %%
cursor.execute(""" 
SELECT id, title, century, culture 
FROM artifact_metadata 
WHERE century LIKE '%11th century%' AND culture LIKE '%Byzantine%'; """) 

results = cursor.fetchall() 
for row in results: 
    print(row)

# %% [markdown]
# #### 2. What are the unique cultures represented in the artifacts?

# %%
cursor.execute("""
    SELECT DISTINCT culture
    FROM artifact_metadata
    WHERE culture IS NOT NULL
    ORDER BY culture;
""")
results = cursor.fetchall()
print("Unique cultures in artifacts:")
for row in results:
    print(row[0])

# %% [markdown]
# #### 3. List all artifacts from the Archaic Period

# %%
cursor.execute("""
SELECT *
FROM artifact_metadata
WHERE period = 'Archaic Period';
""")
results = cursor.fetchall()
print("Artifacts from Archaic Period:")
for row in results:
    print(row)
# Out:
# Artifacts from Archaic Period:

# %% [markdown]
# #### 4. List artifact titles ordered by accession year in descending order

# %%
cursor.execute("""
    SELECT title, accessionyear
    FROM artifact_metadata
    WHERE accessionyear IS NOT NULL
    ORDER BY accessionyear DESC;
""")
results = cursor.fetchall()
print("Artifact titles ordered by accession year (newest first):")
for row in results:
    print(row)

# %% [markdown]
# #### 5. How many artifacts are there per department

# %%
cursor.execute("""
SELECT department, COUNT(*) AS artifact_count
FROM artifact_metadata
GROUP BY department
ORDER BY artifact_count DESC;
""")

results = cursor.fetchall()
print("Number of artifacts per department:")
for department, count in results:
    print(f"{department}: {count}")
# Out:
# Number of artifacts per department:
# Department of Asian Art: 1659
# Department of Paintings, Sculpture & Decorative Arts: 313
# Department of Modern & Contemporary Art: 139
# Department of American Paintings, Sculpture & Decorative Arts: 137
# Department of Islamic & Later Indian Art: 113
# Harvard University Portrait Collection: 108
# Busch-Reisinger Museum: 28
# Department of Ancient and Byzantine Art & Numismatics: 2
# Straus Center for Conservation and Technical Studies: 1

# %% [markdown]
# ### artifact_media Table

# %% [markdown]
# #### 6. Which artifacts have more than 1 image

# %%
cursor.execute("""
SELECT objectid, imagecount, mediacount
FROM artifact_media
WHERE imagecount > 1;
""")

results = cursor.fetchall()
print("Artifacts with more than 1 image:")
for obj_id, imagecount, mediacount in results:
    print(f"Object ID: {obj_id}, Images: {imagecount}, Media Count: {mediacount}")

# %% [markdown]
# #### 7. What is the average rank of all artifacts

# %%
cursor.execute("""
SELECT AVG(rank_value) AS average_rank
FROM artifact_media
WHERE rank_value IS NOT NULL;
""")

result = cursor.fetchone()
print(f"Average rank of all artifacts: {result[0]}")
# Out:
# Average rank of all artifacts: 99373.3668

# %% [markdown]
# #### 8. Which artifacts have a higher colorcount than mediacount

# %%
cursor.execute("""
SELECT objectid, colorcount, mediacount
FROM artifact_media
WHERE colorcount > mediacount;
""")

results = cursor.fetchall()
print("Artifacts where color count is higher than media count:")
for obj_id, colorcount, mediacount in results:
    print(f"Object ID: {obj_id}, Color Count: {colorcount}, Media Count: {mediacount}")

# %% [markdown]
# #### 9. List all artifacts created between 1500 and 1600

# %%
cursor.execute("""
    SELECT title, datebegin, dateend
    FROM artifact_metadata m
    JOIN artifact_media me ON m.id = me.objectid
    WHERE (me.datebegin BETWEEN 1500 AND 1600)
       OR (me.dateend BETWEEN 1500 AND 1600);
""")
results = cursor.fetchall()
print("Artifacts created between 1500 and 1600:")
for row in results:
    print(row)

# %% [markdown]
# #### 10. How many artifacts have no media files

# %%
cursor.execute("""
    SELECT COUNT(*)
    FROM artifact_media
    WHERE mediacount = 0 OR mediacount IS NULL;
""")
no_media_count = cursor.fetchone()[0]
print(f"Artifacts with no media files: {no_media_count}")
# Out:
# Artifacts with no media files: 2498

# %% [markdown]
# ### artifact_colors Table

# %% [markdown]
# #### 11. What are all the distinct hues used in the dataset

# %%
cursor.execute("""
    SELECT DISTINCT hue
    FROM artifact_colors
    WHERE hue IS NOT NULL
    ORDER BY hue;
""")
results = cursor.fetchall()
print("Distinct hues:")
for row in results:
    print(row[0])
# Out:
# Distinct hues:
# Black
# Blue
# Brown
# Green
# Grey
# Orange
# Red
# Violet
# White
# Yellow

# %% [markdown]
# #### 12. What are the top 5 most used colors by frequency

# %%
cursor.execute("""
SELECT color, COUNT(*) AS frequency
FROM artifact_colors
WHERE color IS NOT NULL
GROUP BY color
ORDER BY frequency DESC
LIMIT 5;
""")

results = cursor.fetchall()
print("Top 5 most used colors:")
for color, freq in results:
    print(f"{color}: {freq}")
# Out:
# Top 5 most used colors:
# #323232: 750
# #4b4b4b: 712
# #646464: 658
# #7d7d7d: 648
# #969696: 631

# %% [markdown]
# #### 13. What is the average coverage percentage for each hue

# %%
cursor.execute("""
    SELECT hue, AVG(percent) AS avg_percent
    FROM artifact_colors
    WHERE percent IS NOT NULL
    GROUP BY hue
    ORDER BY avg_percent DESC;
""")
results = cursor.fetchall()
print("Average coverage percentage per hue:")
for hue, avg in results:
    print(f"{hue}: {avg:.2f}%")
# Out:
# Average coverage percentage per hue:
# Orange: 0.16%
# White: 0.15%
# Yellow: 0.15%
# Brown: 0.13%
# Green: 0.12%
# Black: 0.12%
# Grey: 0.11%
# Violet: 0.10%
# Red: 0.09%
# Blue: 0.07%

# %% [markdown]
# #### 14. List all colors used for a given artifact ID

# %%
# Fetch 5 sample artifact IDs
cursor.execute("""
SELECT DISTINCT objectid
FROM artifact_colors
LIMIT 5;
""")

sample_ids = cursor.fetchall()
print("Here are 5 sample artifact IDs to test with:")
for obj_id in sample_ids:
    print(obj_id[0])
# Out:
# Here are 5 sample artifact IDs to test with:
# 1429
# 4586
# 4615
# 4640
# 4728

# %%
# Ask the user for the artifact ID
artifact_id = int(input("Enter the artifact ID: "))

cursor.execute("""
SELECT color, hue, percent, spectrum, css3
FROM artifact_colors
WHERE objectid = %s;
""", (artifact_id,))

results = cursor.fetchall()
print(f"Colors used for artifact ID {artifact_id}:")
for color, hue, percent, spectrum, css3 in results:
    print(f"{color} | Hue: {hue} | Percent: {percent} | Spectrum: {spectrum} | CSS3: {css3}")
# Out:
# Enter the artifact ID:  4728
# Colors used for artifact ID 4728:
# #191919 | Hue: Grey | Percent: 0.3701424501424501 | Spectrum: #1eb264 | CSS3: #000000
# #964b32 | Hue: Orange | Percent: 0.25236467236467236 | Spectrum: #d0577c | CSS3: #a0522d
# #af6432 | Hue: Orange | Percent: 0.21247863247863247 | Spectrum: #e9715f | CSS3: #a0522d
# #323232 | Hue: Grey | Percent: 0.05754985754985755 | Spectrum: #2eb45d | CSS3: #2f4f4f
# #c8644b | Hue: Red | Percent: 0.051168091168091165 | Spectrum: #e46867 | CSS3: #cd5c5c
# #4b3219 | Hue: Brown | Percent: 0.03720797720797721 | Spectrum: #4ab851 | CSS3: #556b2f
# #af7d64 | Hue: Brown | Percent: 0.008205128205128205 | Spectrum: #c85783 | CSS3: #cd5c5c
# #c8afaf | Hue: Red | Percent: 0.005356125356125356 | Spectrum: #b55592 | CSS3: #c0c0c0
# #c8967d | Hue: Grey | Percent: 0.003532763532763533 | Spectrum: #e66c64 | CSS3: #bc8f8f
# #e1c8c8 | Hue: Orange | Percent: 0.0019943019943019944 | Spectrum: #c15689 | CSS3: #d8bfd8

# %% [markdown]
# #### 15. What is the total number of color entries in the dataset

# %%
cursor.execute("""
SELECT COUNT(*) 
FROM artifact_colors;
""")

total_colors = cursor.fetchone()[0]
print(f"Total number of color entries in the dataset: {total_colors}")
# Out:
# Total number of color entries in the dataset: 18463

# %% [markdown]
# ### Join-Based Queries

# %% [markdown]
# #### 16. List artifact titles and hues for all artifacts belonging to the Byzantine culture.

# %%
cursor.execute("""
SELECT m.title, c.hue
FROM artifact_metadata m
JOIN artifact_colors c ON m.id = c.objectid
WHERE m.culture = 'Byzantine';
""")

results = cursor.fetchall()

print("Artifacts from Byzantine culture with their hues:")
for row in results:
    print(f"Title: {row[0]}, Hue: {row[1]}")

# %% [markdown]
# #### 17. List each artifact title with its associated hues.

# %%
cursor.execute("""
SELECT md.title, GROUP_CONCAT(ac.hue SEPARATOR ', ') AS hues
FROM artifact_metadata md
JOIN artifact_colors ac ON md.id = ac.objectid
GROUP BY md.title;
""")

results = cursor.fetchall()
print("Artifact titles with their associated hues:")
for title, hues in results:
    print(f"{title}: {hues}")

# %% [markdown]
# #### 18. Get artifact titles, cultures, and media ranks where the period is not null.

# %%
cursor.execute("""
SELECT md.title, md.culture, am.rank_value
FROM artifact_metadata md
JOIN artifact_media am ON md.id = am.objectid
WHERE md.period IS NOT NULL;
""")

results = cursor.fetchall()
for title, culture, rank in results:
    print(f"{title} | Culture: {culture} | Rank: {rank}")

# %% [markdown]
# #### 19. Find artifact titles ranked in the top 10 that include the color hue "Grey".

# %%
cursor.execute("""
SELECT md.title, am.rank_value, ac.hue
FROM artifact_metadata md
JOIN artifact_media am ON md.id = am.objectid
JOIN artifact_colors ac ON md.id = ac.objectid
WHERE ac.hue LIKE '%Grey%'
ORDER BY am.rank_value ASC
LIMIT 10;
""")

results = cursor.fetchall()
print("Top 10 ranked artifacts with hue 'Grey':")
for title, rank, hue in results:
    print(f"{title} | Rank: {rank} | Hue: {hue}")

# %% [markdown]
# #### 20. How many artifacts exist per classification, and what is the average media count for each?

# %%
cursor.execute("""
SELECT md.classification, 
       COUNT(*) AS artifact_count, 
       AVG(am.mediacount) AS avg_media_count
FROM artifact_metadata md
JOIN artifact_media am ON md.id = am.objectid
GROUP BY md.classification
ORDER BY artifact_count DESC;
""")

results = cursor.fetchall()
print("Artifacts per classification and average media count:")
for classification, count, avg_media in results:
    print(f"{classification}: Count = {count}, Average Media Count = {avg_media:.2f}")
# Out:
# Artifacts per classification and average media count:
# Paintings: Count = 2500, Average Media Count = 0.00

# %% [markdown]
# ### Extra SQL queries

# %% [markdown]
# #### 21. Show artifacts where accession method contains "purchase

# %%
cursor.execute("""
    SELECT title, accessionmethod
    FROM artifact_metadata
    WHERE accessionmethod LIKE '%purchase%';
""")
results = cursor.fetchall()
print("Artifacts with accession method containing 'purchase':")
for row in results:
    print(row)

# %% [markdown]
# #### 22. List all artifacts from a specific department

# %%
department_name = "Coins and Medals"  
cursor.execute("""
    SELECT title, department
    FROM artifact_metadata
    WHERE department = %s;
""", (department_name,))
results = cursor.fetchall()
print(f"Artifacts in department '{department_name}':")
for row in results:
    print(row[0])

# %% [markdown]
# #### 23. Find artifacts that have no description

# %%
cursor.execute("""
    SELECT title
    FROM artifact_metadata
    WHERE description IS NULL OR description = '';
""")
results = cursor.fetchall()
print("Artifacts with no description:")
for row in results:
    print(row[0])

# %% [markdown]
# #### 24. Show artifacts ordered by their object ID

# %%
cursor.execute("""
    SELECT id, title, objectid
    FROM artifact_metadata
    ORDER BY objectid ASC;
""")
results = cursor.fetchall()
print("Artifacts ordered by object ID:")
for row in results:
    print(row)

# %% [markdown]
# #### 25. Count how many artifacts have a non-null period

# %%
cursor.execute("""
    SELECT COUNT(*)
    FROM artifact_metadata
    WHERE period IS NOT NULL;
""")
count = cursor.fetchone()[0]
print(f"Number of artifacts with a defined period: {count}")
